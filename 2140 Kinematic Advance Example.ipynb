# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:fb8cbd79-16d2-4025-9bb4-ef8001945458.png)

# %%
from Libaldomath import *

# %%
A=mparticle(y1=2*R,y2=0,x1=0,x2=2*R,v1=0)

# %%
V2=simplesolve(A.energia('p2')+A.energia('k2')-A.energia('p1')-A.energia('k1'),v2,'positive')
# Out:
# $\displaystyle v_2 =2 \sqrt{R g}$

# %%
B=mparticle(y1=0,y2=R-R*sin(alpha),x1=0,x2=R*cos(alpha) ,v1=V2)

# %%
V3=simplesolve(B.energia('p2')+B.energia('k2')-B.energia('p1')-B.energia('k1'),v2,'pos')
# Out:
# $\displaystyle v_2 =\sqrt{2} \sqrt{R g \left(\sin{\left(\alpha \right)} + 1\right)}$

# %%
C=mparticle(x1=0,y1=R-R*sin(alpha) ,y2=0,v1=V3,a=alpha)

# %%
C.xmax()
# Out:
# 2⋅R⋅(sin(α) + 1)⋅sin(α)⋅cos(α)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *
