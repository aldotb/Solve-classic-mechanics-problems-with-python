# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)

# %%
from lib_Physics import *

# %% [markdown]
# ![image.png](attachment:9501fbff-9c26-4550-bdbf-6d8b485d3b5a.png)

# %%
 m1,m2,m3,N1,N2,N3,R1,R2,R3=symbols('m1 m2 m3 N1 N2 N3 R1 R2 R3')

# %%
B1=mparticle('m1',m=m1,tipo='ball')
B1.add_forza(m*g,-pi/2)
B1.add_forza(N1,pi/6+alpha)
B1.add_forza(-R1,alpha)

# %%
B1.rendervector()

# %%
Fx1=B1.Fx('Fx1')
# Out:
# $\displaystyle Fx1 = N_{1} \cos{\left(\alpha + \frac{\pi}{6} \right)} - R_{1} \cos{\left(\alpha \right)}$

# %%
Fy1=B1.Fy('Fy1')
# Out:
# $\displaystyle Fy1 = N_{1} \sin{\left(\alpha + \frac{\pi}{6} \right)} - R_{1} \sin{\left(\alpha \right)} - g m$

# %%
N1=Fx1.solve('N1')
# Out:
# $\displaystyle N1 = \frac{R_{1} \cos{\left(\alpha \right)}}{\cos{\left(\alpha + \frac{\pi}{6} \right)}}$

# %%
Fy1.set(N1)
# Out:
# $\displaystyle Fy1 = - R_{1} \sin{\left(\alpha \right)} + \frac{R_{1} \sin{\left(\alpha + \frac{\pi}{6} \right)} \cos{\left(\alpha \right)}}{\cos{\left(\alpha + \frac{\pi}{6} \right)}} - g m$

# %%
Fy1.texpand()
# Out:
# $\displaystyle Fy1 = \frac{R_{1} \left(\frac{\sqrt{3} \sin{\left(\alpha \right)}}{2} + \frac{\cos{\left(\alpha \right)}}{2}\right) \cos{\left(\alpha \right)}}{- \frac{\sin{\left(\alpha \right)}}{2} + \frac{\sqrt{3} \cos{\left(\alpha \right)}}{2}} - R_{1} \sin{\left(\alpha \right)} - g m$

# %%
Fy1.expand()
# Out:
# $\displaystyle Fy1 = - R_{1} \sin{\left(\alpha \right)} + \frac{\sqrt{3} R_{1} \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}}{- \sin{\left(\alpha \right)} + \sqrt{3} \cos{\left(\alpha \right)}} + \frac{R_{1} \cos^{2}{\left(\alpha \right)}}{- \sin{\left(\alpha \right)} + \sqrt{3} \cos{\left(\alpha \right)}} - g m$

# %%
Fy1.tsimplify()
# Out:
# $\displaystyle Fy1 = \frac{R_{1}}{2 \cos{\left(\alpha + \frac{\pi}{6} \right)}} - g m$

# %%
R1=Fy1.solve('R1')
# Out:
# $\displaystyle R1 = 2 g m \cos{\left(\alpha + \frac{\pi}{6} \right)}$

# %%
B2=mparticle('m2',tipo='ball')
B2.add_forza(M*g,-pi/2)
B2.add_forza(N2,alpha+2*pi/3)
B2.add_forza(R2,alpha)

# %%
B2.rendervector()

# %%
Fx2=B2.Fx('Fx2')
# Out:
# $\displaystyle Fx2 = - N_{2} \sin{\left(\alpha + \frac{\pi}{6} \right)} + R_{2} \cos{\left(\alpha \right)}$

# %%
Fy2=B2.Fy('Fy2')
# Out:
# $\displaystyle Fy2 = - M g + N_{2} \cos{\left(\alpha + \frac{\pi}{6} \right)} + R_{2} \sin{\left(\alpha \right)}$

# %%
N2=Fx2.solve('N2')
# Out:
# $\displaystyle N2 = \frac{R_{2} \cos{\left(\alpha \right)}}{\sin{\left(\alpha + \frac{\pi}{6} \right)}}$

# %%
Fy2.set(N2)
# Out:
# $\displaystyle Fy2 = - M g + R_{2} \sin{\left(\alpha \right)} + \frac{R_{2} \cos{\left(\alpha \right)} \cos{\left(\alpha + \frac{\pi}{6} \right)}}{\sin{\left(\alpha + \frac{\pi}{6} \right)}}$

# %%
# reducecero = if expr = a*B*C*(a+b+..)*f/g  and expr=0, then (a+b+..) =0
Fy2.reducecero()
# Out:
# $\displaystyle Fy2 = - M g \sin{\left(\alpha + \frac{\pi}{6} \right)} + R_{2} \sin{\left(\alpha \right)} \sin{\left(\alpha + \frac{\pi}{6} \right)} + R_{2} \cos{\left(\alpha \right)} \cos{\left(\alpha + \frac{\pi}{6} \right)}$

# %%
Fy2.tsimplify()
# Out:
# $\displaystyle Fy2 = - M g \sin{\left(\alpha + \frac{\pi}{6} \right)} + \frac{\sqrt{3} R_{2}}{2}$

# %%
R2=Fy2.solve('R2')
# Out:
# $\displaystyle R2 = \frac{2 \sqrt{3} M g \sin{\left(\alpha + \frac{\pi}{6} \right)}}{3}$

# %%
Q=MQ(R1,R2)
# Out:
# $\displaystyle 2 g m \cos{\left(\alpha + \frac{\pi}{6} \right)} = \frac{2 \sqrt{3} M g \sin{\left(\alpha + \frac{\pi}{6} \right)}}{3}$

# %%
Q.simplify()
# Out:
# $\displaystyle 2 m \cos{\left(\alpha + \frac{\pi}{6} \right)} = \frac{2 \sqrt{3} M \sin{\left(\alpha + \frac{\pi}{6} \right)}}{3}$

# %%
# cf(a,b) = a/b, cf(1,2)=1/2 not 0.5
Q.Div(2*sqrt(3)*M*cos(alpha+pi/6)/3)
# Out:
# $\displaystyle \frac{\sqrt{3} m}{M} = \frac{\sin{\left(\alpha + \frac{\pi}{6} \right)}}{\cos{\left(\alpha + \frac{\pi}{6} \right)}}$

# %%
Q.tsimplify()
# Out:
# $\displaystyle \frac{\sqrt{3} m}{M} = \tan{\left(\alpha + \frac{\pi}{6} \right)}$

# %%
Q.texpand()
# Out:
# $\displaystyle \frac{\sqrt{3} m}{M} = \frac{\tan{\left(\alpha \right)} + \frac{\sqrt{3}}{3}}{- \frac{\sqrt{3} \tan{\left(\alpha \right)}}{3} + 1}$

# %%
Q.alone(tan(alpha))
# Out:
# $\displaystyle \tan{\left(\alpha \right)} = \frac{\sqrt{3} \left(- \frac{M}{3} + m\right)}{M + m}$

# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)

# %% [markdown]
# ![image.png](attachment:f15919e7-47c6-4403-8d6e-16e261b813cb.png)

# %%
from lib_Physics import *

# %%
 m1,m2,m3,N1,N2,N3,R1,R2,R3=symbols('m1 m2 m3 N1 N2 N3 R1 R2 R3')

# %%
B1=mparticle('B1',tipo='ball')
B1.add_forza(m1*g,-pi/2)
B1.add_forza(N1,pi/6+alpha)
B1.add_forza(R1,alpha+pi+pi/3)
B1.add_forza(R2,alpha+pi)

# %%
B1.rendervector(alpha=pi/5)

# %%
Fx1=B1.Fx('Fx1')
# Out:
# $\displaystyle Fx1 = N_{1} \cos{\left(\alpha + \frac{\pi}{6} \right)} - R_{1} \cos{\left(\alpha + \frac{\pi}{3} \right)} - R_{2} \cos{\left(\alpha \right)}$

# %%
Fy1=B1.Fy('Fy1')
# Out:
# $\displaystyle Fy1 = N_{1} \sin{\left(\alpha + \frac{\pi}{6} \right)} - R_{1} \sin{\left(\alpha + \frac{\pi}{3} \right)} - R_{2} \sin{\left(\alpha \right)} - g m_{1}$

# %%
N1=Fx1.solve('N1')
# Out:
# $\displaystyle N1 = \frac{R_{1} \cos{\left(\alpha + \frac{\pi}{3} \right)} + R_{2} \cos{\left(\alpha \right)}}{\cos{\left(\alpha + \frac{\pi}{6} \right)}}$

# %%
Fy1.set(N1)
# Out:
# $\displaystyle Fy1 = - R_{1} \sin{\left(\alpha + \frac{\pi}{3} \right)} - R_{2} \sin{\left(\alpha \right)} - g m_{1} + \frac{\left(R_{1} \cos{\left(\alpha + \frac{\pi}{3} \right)} + R_{2} \cos{\left(\alpha \right)}\right) \sin{\left(\alpha + \frac{\pi}{6} \right)}}{\cos{\left(\alpha + \frac{\pi}{6} \right)}}$

# %%
Fy1.reducecero()
# Out:
# $\displaystyle Fy1 = R_{1} \sin{\left(\alpha + \frac{\pi}{6} \right)} \cos{\left(\alpha + \frac{\pi}{3} \right)} - R_{1} \sin{\left(\alpha + \frac{\pi}{3} \right)} \cos{\left(\alpha + \frac{\pi}{6} \right)} - R_{2} \sin{\left(\alpha \right)} \cos{\left(\alpha + \frac{\pi}{6} \right)} + R_{2} \sin{\left(\alpha + \frac{\pi}{6} \right)} \cos{\left(\alpha \right)} - g m_{1} \cos{\left(\alpha + \frac{\pi}{6} \right)}$

# %%
Fy1.tsimplify()
# Out:
# $\displaystyle Fy1 = - \frac{R_{1}}{2} + \frac{R_{2}}{2} - g m_{1} \cos{\left(\alpha + \frac{\pi}{6} \right)}$

# %%
R2=Fy1.solve('R2')
# Out:
# $\displaystyle R2 = R_{1} + 2 g m_{1} \cos{\left(\alpha + \frac{\pi}{6} \right)}$

# %%
B2=mparticle(m=m2)
B2.add_forza(m*g,-pi/2)
B2.add_forza(N2,5*pi/6+alpha)
B2.add_forza(R1,alpha)
B2.add_forza(-R3,alpha+2*pi/3)

# %%
B2.rendervector()

# %%
Fx2=B2.Fx('Fx2')
# Out:
# $\displaystyle Fx2 = - N_{2} \sin{\left(\alpha + \frac{\pi}{3} \right)} + R_{1} \cos{\left(\alpha \right)} + R_{3} \sin{\left(\alpha + \frac{\pi}{6} \right)}$

# %%
Fy2=B2.Fy('Fy2')
# Out:
# $\displaystyle Fy2 = N_{2} \cos{\left(\alpha + \frac{\pi}{3} \right)} + R_{1} \sin{\left(\alpha \right)} - R_{3} \cos{\left(\alpha + \frac{\pi}{6} \right)} - g m$

# %%
N2=Fx2.solve('N2')
# Out:
# $\displaystyle N2 = \frac{R_{1} \cos{\left(\alpha \right)} + R_{3} \sin{\left(\alpha + \frac{\pi}{6} \right)}}{\sin{\left(\alpha + \frac{\pi}{3} \right)}}$

# %%
Fy2.set(N2)
# Out:
# $\displaystyle Fy2 = R_{1} \sin{\left(\alpha \right)} - R_{3} \cos{\left(\alpha + \frac{\pi}{6} \right)} - g m + \frac{\left(R_{1} \cos{\left(\alpha \right)} + R_{3} \sin{\left(\alpha + \frac{\pi}{6} \right)}\right) \cos{\left(\alpha + \frac{\pi}{3} \right)}}{\sin{\left(\alpha + \frac{\pi}{3} \right)}}$

# %%
Fy2.reducecero()
# Out:
# $\displaystyle Fy2 = R_{1} \sin{\left(\alpha \right)} \sin{\left(\alpha + \frac{\pi}{3} \right)} + R_{1} \cos{\left(\alpha \right)} \cos{\left(\alpha + \frac{\pi}{3} \right)} + R_{3} \sin{\left(\alpha + \frac{\pi}{6} \right)} \cos{\left(\alpha + \frac{\pi}{3} \right)} - R_{3} \sin{\left(\alpha + \frac{\pi}{3} \right)} \cos{\left(\alpha + \frac{\pi}{6} \right)} - g m \sin{\left(\alpha + \frac{\pi}{3} \right)}$

# %%
Fy2.tsimplify()
# Out:
# $\displaystyle Fy2 = \frac{R_{1}}{2} - \frac{R_{3}}{2} - g m \sin{\left(\alpha + \frac{\pi}{3} \right)}$

# %%
R3=Fy2.solve('R3')
# Out:
# $\displaystyle R3 = R_{1} - 2 g m \sin{\left(\alpha + \frac{\pi}{3} \right)}$

# %%
B3=mparticle(m=m3)
B3.add_forza(m3*g,-pi/2)
B3.add_forza(-N3,alpha+pi/2)
B3.add_forza(R3,alpha+2*pi/3)
B3.add_forza(R2,alpha+pi/3)

# %%
Fx3=B3.Fx('Fx3')
# Out:
# $\displaystyle Fx3 = N_{3} \sin{\left(\alpha \right)} - \left(R_{1} - 2 g m \sin{\left(\alpha + \frac{\pi}{3} \right)}\right) \sin{\left(\alpha + \frac{\pi}{6} \right)} + \left(R_{1} + 2 g m_{1} \cos{\left(\alpha + \frac{\pi}{6} \right)}\right) \cos{\left(\alpha + \frac{\pi}{3} \right)}$

# %%
Fy3=B3.Fy('Fy3')
# Out:
# $\displaystyle Fy3 = - N_{3} \cos{\left(\alpha \right)} - g m_{3} + \left(R_{1} - 2 g m \sin{\left(\alpha + \frac{\pi}{3} \right)}\right) \cos{\left(\alpha + \frac{\pi}{6} \right)} + \left(R_{1} + 2 g m_{1} \cos{\left(\alpha + \frac{\pi}{6} \right)}\right) \sin{\left(\alpha + \frac{\pi}{3} \right)}$

# %%
N3=Fx3.solve('N3')
# Out:
# $\displaystyle N3 = \sqrt{3} R_{1} - 2 g m \cos{\left(\alpha \right)} - \frac{\sqrt{3} g m}{2 \sin{\left(\alpha \right)}} + 2 g m_{1} \cos{\left(\alpha \right)} - \frac{\sqrt{3} g m_{1}}{2 \sin{\left(\alpha \right)}}$

# %%
Fy3.set(N3)
# Out:
# $\displaystyle Fy3 = - g m_{3} + \left(R_{1} - 2 g m \sin{\left(\alpha + \frac{\pi}{3} \right)}\right) \cos{\left(\alpha + \frac{\pi}{6} \right)} + \left(R_{1} + 2 g m_{1} \cos{\left(\alpha + \frac{\pi}{6} \right)}\right) \sin{\left(\alpha + \frac{\pi}{3} \right)} - \left(\sqrt{3} R_{1} - 2 g m \cos{\left(\alpha \right)} - \frac{\sqrt{3} g m}{2 \sin{\left(\alpha \right)}} + 2 g m_{1} \cos{\left(\alpha \right)} - \frac{\sqrt{3} g m_{1}}{2 \sin{\left(\alpha \right)}}\right) \cos{\left(\alpha \right)}$

# %%
Fy3.reducecero()
# Out:
# $\displaystyle Fy3 = 2 R_{1} \sin{\left(\alpha \right)} \sin{\left(\alpha + \frac{\pi}{3} \right)} - 2 \sqrt{3} R_{1} \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} + 2 R_{1} \sin{\left(\alpha \right)} \cos{\left(\alpha + \frac{\pi}{6} \right)} - 4 g m \sin{\left(\alpha \right)} \sin{\left(\alpha + \frac{\pi}{3} \right)} \cos{\left(\alpha + \frac{\pi}{6} \right)} + 4 g m \sin{\left(\alpha \right)} \cos^{2}{\left(\alpha \right)} + \sqrt{3} g m \cos{\left(\alpha \right)} + 4 g m_{1} \sin{\left(\alpha \right)} \sin{\left(\alpha + \frac{\pi}{3} \right)} \cos{\left(\alpha + \frac{\pi}{6} \right)} - 4 g m_{1} \sin{\left(\alpha \right)} \cos^{2}{\left(\alpha \right)} + \sqrt{3} g m_{1} \cos{\left(\alpha \right)} - 2 g m_{3} \sin{\left(\alpha \right)}$

# %%
Fy3.tsimplify()
# Out:
# $\displaystyle Fy3 = g \left(4 m \sin{\left(\alpha \right)} \cos^{2}{\left(\alpha \right)} - m \sin{\left(3 \alpha \right)} + \sqrt{3} m \cos{\left(\alpha \right)} - 4 m_{1} \sin{\left(\alpha \right)} \cos^{2}{\left(\alpha \right)} + m_{1} \sin{\left(3 \alpha \right)} + \sqrt{3} m_{1} \cos{\left(\alpha \right)} - 2 m_{3} \sin{\left(\alpha \right)}\right)$

# %%
Fy3.reducecero()
# Out:
# $\displaystyle Fy3 = 4 m \sin{\left(\alpha \right)} \cos^{2}{\left(\alpha \right)} - m \sin{\left(3 \alpha \right)} + \sqrt{3} m \cos{\left(\alpha \right)} - 4 m_{1} \sin{\left(\alpha \right)} \cos^{2}{\left(\alpha \right)} + m_{1} \sin{\left(3 \alpha \right)} + \sqrt{3} m_{1} \cos{\left(\alpha \right)} - 2 m_{3} \sin{\left(\alpha \right)}$

# %%
Fy3.tsimplify()
# Out:
# $\displaystyle Fy3 = 4 m \sin{\left(\alpha \right)} \cos^{2}{\left(\alpha \right)} - m \sin{\left(3 \alpha \right)} + \sqrt{3} m \cos{\left(\alpha \right)} - 4 m_{1} \sin{\left(\alpha \right)} \cos^{2}{\left(\alpha \right)} + m_{1} \sin{\left(3 \alpha \right)} + \sqrt{3} m_{1} \cos{\left(\alpha \right)} - 2 m_{3} \sin{\left(\alpha \right)}$

# %%
Fy3.cos2sin(alpha)
# Out:
# $\displaystyle Fy3 = \left(1 - \sin^{2}{\left(\alpha \right)}\right) \left(16 m + 192\right) \sin{\left(\alpha \right)} + \left(1 - \sin^{2}{\left(\alpha \right)}\right) \left(8 m_{1} + 96\right) \sin{\left(\alpha \right)} + \sqrt{15} \left(m + 12\right) \cos{\left(\alpha \right)} + \left(11 m + 132\right) \sin{\left(3 \alpha \right)} + \left(m_{1} + 12\right) \sin{\left(3 \alpha \right)} + \sqrt{15} \left(m_{1} + 12\right) \cos{\left(\alpha \right)} + \left(10 m_{3} + 120\right) \sin{\left(\alpha \right)}$

# %%
Fy3.expand()
# Out:
# $\displaystyle Fy3 = - 16 m \sin^{3}{\left(\alpha \right)} + 16 m \sin{\left(\alpha \right)} + 11 m \sin{\left(3 \alpha \right)} + \sqrt{15} m \cos{\left(\alpha \right)} - 8 m_{1} \sin^{3}{\left(\alpha \right)} + 8 m_{1} \sin{\left(\alpha \right)} + m_{1} \sin{\left(3 \alpha \right)} + \sqrt{15} m_{1} \cos{\left(\alpha \right)} + 10 m_{3} \sin{\left(\alpha \right)} - 288 \sin^{3}{\left(\alpha \right)} + 408 \sin{\left(\alpha \right)} + 144 \sin{\left(3 \alpha \right)} + 24 \sqrt{15} \cos{\left(\alpha \right)}$

# %%
Fy3.texpand()
# Out:
# $\displaystyle Fy3 = 11 m \left(- 4 \sin^{3}{\left(\alpha \right)} + 3 \sin{\left(\alpha \right)}\right) - 16 m \sin^{3}{\left(\alpha \right)} + 16 m \sin{\left(\alpha \right)} + \sqrt{15} m \cos{\left(\alpha \right)} + m_{1} \left(- 4 \sin^{3}{\left(\alpha \right)} + 3 \sin{\left(\alpha \right)}\right) - 8 m_{1} \sin^{3}{\left(\alpha \right)} + 8 m_{1} \sin{\left(\alpha \right)} + \sqrt{15} m_{1} \cos{\left(\alpha \right)} + 10 m_{3} \sin{\left(\alpha \right)} - 864 \sin^{3}{\left(\alpha \right)} + 840 \sin{\left(\alpha \right)} + 24 \sqrt{15} \cos{\left(\alpha \right)}$

# %%
Fy3.expand()
# Out:
# $\displaystyle Fy3 = - 60 m \sin^{3}{\left(\alpha \right)} + 49 m \sin{\left(\alpha \right)} + \sqrt{15} m \cos{\left(\alpha \right)} - 12 m_{1} \sin^{3}{\left(\alpha \right)} + 11 m_{1} \sin{\left(\alpha \right)} + \sqrt{15} m_{1} \cos{\left(\alpha \right)} + 10 m_{3} \sin{\left(\alpha \right)} - 864 \sin^{3}{\left(\alpha \right)} + 840 \sin{\left(\alpha \right)} + 24 \sqrt{15} \cos{\left(\alpha \right)}$

# %%
Fy3.factoriza(sin(alpha))
# Out:
# $\displaystyle Fy3 = \sqrt{15} m \cos{\left(\alpha \right)} + \sqrt{15} m_{1} \cos{\left(\alpha \right)} + \left(- 60 m \sin^{2}{\left(\alpha \right)} + 49 m - 12 m_{1} \sin^{2}{\left(\alpha \right)} + 11 m_{1} + 10 m_{3} - 864 \sin^{2}{\left(\alpha \right)} + 840\right) \sin{\left(\alpha \right)} + 24 \sqrt{15} \cos{\left(\alpha \right)}$

# %%
Fy3.factoriza(cos(alpha))
# Out:
# $\displaystyle Fy3 = \left(\sqrt{15} m + \sqrt{15} m_{1} + 24 \sqrt{15}\right) \cos{\left(\alpha \right)} + \left(- 60 m \sin^{2}{\left(\alpha \right)} + 49 m - 12 m_{1} \sin^{2}{\left(\alpha \right)} + 11 m_{1} + 10 m_{3} - 864 \sin^{2}{\left(\alpha \right)} + 840\right) \sin{\left(\alpha \right)}$

# %%
Fy3.Div(cos(alpha))
# Out:
# $\displaystyle Fy3 = \frac{\left(\sqrt{15} m + \sqrt{15} m_{1} + 24 \sqrt{15}\right) \cos{\left(\alpha \right)} + \left(- 60 m \sin^{2}{\left(\alpha \right)} + 49 m - 12 m_{1} \sin^{2}{\left(\alpha \right)} + 11 m_{1} + 10 m_{3} - 864 \sin^{2}{\left(\alpha \right)} + 840\right) \sin{\left(\alpha \right)}}{\cos{\left(\alpha \right)}}$

# %%
Fy3.tsimplify()
# Out:
# $\displaystyle Fy3 = \frac{\left(\sqrt{15} m + \sqrt{15} m_{1} + 24 \sqrt{15}\right) \cos{\left(\alpha \right)} + \left(60 m \cos^{2}{\left(\alpha \right)} - 11 m + 12 m_{1} \cos^{2}{\left(\alpha \right)} - m_{1} + 10 m_{3} + 864 \cos^{2}{\left(\alpha \right)} - 24\right) \sin{\left(\alpha \right)}}{\cos{\left(\alpha \right)}}$

# %%
Ta=Fy3.solve(tan(alpha))

# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)

# %% [markdown]
# ![image.png](attachment:d677c163-4ec5-4b6b-b59c-ef4752667ddc.png)

# %%
from lib_Physics import *

# %%
fr=symbols('fr')

# %%
P=mparticle()

# %%
P.add_forza(m*g,-pi/2)
P.add_forza(N1,pi/2+alpha,a*sin(alpha),-a*cos(alpha))
P.add_forza(T,-pi/2,b,0)
P.add_forza(fr,alpha,a*sin(alpha),-a*cos(alpha))

# %%
Fx=P.Fx('Fx')
# Out:
# $\displaystyle Fx = - N_{1} \sin{\left(\alpha \right)} + fr \cos{\left(\alpha \right)}$

# %%
fr=Fx.solve('fr')
# Out:
# $\displaystyle fr = N_{1} \tan{\left(\alpha \right)}$

# %%
Fy=P.Fy('Fy')
# Out:
# $\displaystyle Fy = N_{1} \cos{\left(\alpha \right)} - T + fr \sin{\left(\alpha \right)} - g m$

# %%
Fy.set(fr)
# Out:
# $\displaystyle Fy = N_{1} \sin{\left(\alpha \right)} \tan{\left(\alpha \right)} + N_{1} \cos{\left(\alpha \right)} - T - g m$

# %%
N1=Fy.solve('N1')
# Out:
# $\displaystyle N1 = \left(T + g m\right) \cos{\left(\alpha \right)}$

# %%
To=P.To('To')
# Out:
# $\displaystyle To = - T b + a fr$

# %%
To.set(N1,fr)
# Out:
# $\displaystyle To = N_{1} a \tan{\left(\alpha \right)} - T b$

# %%
To.set(N1)
# Out:
# $\displaystyle To = - T b + a \left(T + g m\right) \cos{\left(\alpha \right)} \tan{\left(\alpha \right)}$

# %%
To.expand()
# Out:
# $\displaystyle To = T a \cos{\left(\alpha \right)} \tan{\left(\alpha \right)} - T b + a g m \cos{\left(\alpha \right)} \tan{\left(\alpha \right)}$

# %%
To.simplify()
# Out:
# $\displaystyle To = T a \sin{\left(\alpha \right)} - T b + a g m \sin{\left(\alpha \right)}$

# %%
Q=MQ(sin(alpha),To.solve('sin(alpha)'))
# Out:
# $\displaystyle sin(alpha) = \frac{T b}{a \left(T + g m\right)}$
# $\displaystyle \sin{\left(\alpha \right)} = \frac{T b}{a \left(T + g m\right)}$

# %%
Q.set(g*m,100)
# Out:
# $\displaystyle \sin{\left(\alpha \right)} = \frac{T b}{a \left(T + 100\right)}$

# %%
Q.set(a=cfrac(6,100))
# Out:
# $\displaystyle \sin{\left(\alpha \right)} = \frac{T b}{\frac{3 T}{50} + 6}$

# %%
Q.set(b=cfrac(15,100))
# Out:
# $\displaystyle \sin{\left(\alpha \right)} = \frac{3 T}{20 \left(\frac{3 T}{50} + 6\right)}$

# %%
Q.set(T=25)
# Out:
# $\displaystyle \sin{\left(\alpha \right)} = \frac{1}{2}$
