# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:0a784723-c3de-4993-83f5-1aa45c75957c.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody()
P.add_weight()
P.add_forza(N1,pi/2+alpha)
P.add_forza(fr,alpha)

# %%
Q1=MQ(P.Fx(),m*a)
# Out:
# $\displaystyle Fx =- N_{1} \sin{\left(\alpha \right)} + f_{r} \cos{\left(\alpha \right)}$
# $\displaystyle - N_{1} \sin{\left(\alpha \right)} + f_{r} \cos{\left(\alpha \right)} = a m$

# %%
Q3=MQ(fr,N1*mu)
# Out:
# $\displaystyle f_{r} = N_{1} \mu$

# %%
Q2=MQ(P.Fy(),0)
# Out:
# $\displaystyle Fy =N_{1} \cos{\left(\alpha \right)} + f_{r} \sin{\left(\alpha \right)} - g m$
# $\displaystyle N_{1} \cos{\left(\alpha \right)} + f_{r} \sin{\left(\alpha \right)} - g m = 0$

# %%
a,fr,N1=simplesolve(Q1,Q2,Q3,a,fr,N1)
# Out:
# $\displaystyle a =\frac{g \mu \cos{\left(\alpha \right)}}{\mu \sin{\left(\alpha \right)} + \cos{\left(\alpha \right)}} - \frac{g \sin{\left(\alpha \right)}}{\mu \sin{\left(\alpha \right)} + \cos{\left(\alpha \right)}}$
# $\displaystyle f_r =\frac{g m \mu}{\mu \sin{\left(\alpha \right)} + \cos{\left(\alpha \right)}}$
# $\displaystyle N1 =\frac{g m}{\mu \sin{\left(\alpha \right)} + \cos{\left(\alpha \right)}}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:f294dbc7-0a56-4a18-9c8c-80be8d80bf37.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
Pm=phybody()
Pm.add_weight()
Pm.add_forza(N1,pi/2)
Pm.add_forza(fr,0)

# %%
Q1=MQ(Pm.Fx(),m*a1)
# Out:
# $\displaystyle Fx =f_{r}$
# $\displaystyle f_{r} = a_{1} m$

# %%
Q2=MQ(fr,m*g*mu)
# Out:
# $\displaystyle f_{r} = g m \mu$

# %%
PM=phybody(m=M)
PM.add_weight()
PM.add_forza(N1,-pi/2)
PM.add_forza(N2,pi/2)
PM.add_forza(F,0)
PM.add_forza(fr,pi)

# %%
Q3=MQ(PM.Fx(),M*a2)
# Out:
# $\displaystyle Fx =F - f_{r}$
# $\displaystyle F - f_{r} = M a_{2}$

# %%
Q4=MQ(PM.Fy(),0)
# Out:
# $\displaystyle Fy =- M g - N_{1} + N_{2}$
# $\displaystyle - M g - N_{1} + N_{2} = 0$

# %%
Q5=MQ(N1,m*g)
# Out:
# $\displaystyle N_{1} = g m$

# %%
a1,a2,fr,N1,N2=simplesolve(Q1,Q2,Q3,Q4,Q5,a1,a2,fr,N1,N2)
# Out:
# $\displaystyle a1 =g \mu$
# $\displaystyle a2 =\frac{F - g m \mu}{M}$
# $\displaystyle f_r =g m \mu$
# $\displaystyle N1 =g m$
# $\displaystyle N2 =M g + g m$

# %%
P=phybody(x1=0,x2=L,v1=0,ax=a2-a1,ang=0)

# %%
Q=MQ(P.xpos(t),L)
# Out:
# $\displaystyle \frac{t^{2} \left(- g \mu + \frac{F - g m \mu}{M}\right)}{2} = L$

# %%
Q.alone(t*t)
# Out:
# $\displaystyle t^{2} = - \frac{2 L M}{- F + M g \mu + g m \mu}$

# %%
Q.simplifysigno()
# Out:
# $\displaystyle t^{2} = \frac{2 L M}{F - M g \mu - g m \mu}$

# %%
Q.Rpow()
# Out:
# $\displaystyle t = \frac{\sqrt{2} \sqrt{L} \sqrt{M}}{\sqrt{F - M g \mu - g m \mu}}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:ffa50eb6-3f37-46fc-a9d0-f34ffc552509.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:47df3749-6f08-4757-84c1-dda325614b20.png)

# %%
alpha=atan(cfrac(3,4)) # alpha=37g

# %%
B=phybody(m=12,g=10)
B.add_weight()
B.add_forza(N2,alpha)
B.add_forza(N1,pi)

# %%
# when we haves n equations with n incognites.. maybe we can us simplesolve
N2,N1=simplesolve(B.Fx(),B.Fy())
# Out:
# $\displaystyle Fx =- N_{1} + \frac{4 N_{2}}{5}$
# $\displaystyle Fy =\frac{3 N_{2}}{5} - 120$
# $\displaystyle N2=200$
# $\displaystyle N1=160$

# %%
A=phybody(g=10)
A.add_forza(N2,alpha+pi)
A.add_weight()
A.add_forza(fr,0)
A.add_forza(N3,pi/2)

# %%
Fx=A.Fx()
Fy=A.Fy()
# Out:
# $\displaystyle Fx =f_{r} - 160$
# $\displaystyle Fy =N_{3} - 10 m - 120$

# %%
Fx.set(fr=N3/3)
# Out:
# $\displaystyle Fx =\frac{N_{3}}{3} - 160$

# %%
N3,m=simplesolve(Fx(),Fy())
# Out:
# $\displaystyle N3=480$
# $\displaystyle m=36$
