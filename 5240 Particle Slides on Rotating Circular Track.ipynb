# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
# mu=0

# %% [markdown]
# ![image.png](attachment:d7fc5c1e-36d4-45c9-b137-70e519bfcb17.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody()
x1=x*cos(alpha)
y1=x*sin(alpha)

# %%
P.add_forza(m*g,-pi/2)
P.add_forza(N1,alpha+pi/2)

# %%
Fy=P.Fy('Fy')
# Out:
# $\displaystyle Fy =N_{1} \cos{\left(\alpha \right)} - g m$

# %%
Q1=MQ(Fc,-1*P.Fx())
# Out:
# $\displaystyle F_{c} = N_{1} \sin{\left(\alpha \right)}$

# %%
P.add_forza(Fc,0)

# %%
Q2=MQ(P.fyrelative(alpha),0)
# Out:
# $\displaystyle - F_{c} \sin{\left(\alpha \right)} + N_{1} - g m \cos{\left(\alpha \right)} = 0$

# %%
Q2.subs(Fc,m*w*w*R*sin(alpha))
# Out:
# $\displaystyle N_{1} - R m w^{2} \sin^{2}{\left(\alpha \right)} - g m \cos{\left(\alpha \right)} = 0$

# %%
Q2.alone(N1)
# Out:
# $\displaystyle N_{1} = m \left(R w^{2} \sin^{2}{\left(\alpha \right)} + g \cos{\left(\alpha \right)}\right)$

# %%
Q3=MQ(F,-m*g*sin(alpha)+Fc*cos(alpha))
# Out:
# $\displaystyle F = F_{c} \cos{\left(\alpha \right)} - g m \sin{\left(\alpha \right)}$

# %%
Q3.subs(Fc,m*w*w*R*sin(alpha))
# Out:
# $\displaystyle F = R m w^{2} \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} - g m \sin{\left(\alpha \right)}$

# %% [markdown]
# ![image.png](attachment:53dc594e-0b6e-483f-99d8-77c520d39daa.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody(w1=0,y1=0,y2=R-R*cos(alpha),Io=m*(R*sin(alpha))**2)
x1=x*cos(alpha)
y1=x*sin(alpha)

# %%
P.add_forza(m*g,-pi/2)
P.add_forza(N1,alpha+pi/2)

# %%
En=P.energia('pr','En')
# Out:
# $\displaystyle En =\frac{R^{2} m w_{2}^{2} \sin^{2}{\left(\alpha \right)}}{2} + g m \left(- R \cos{\left(\alpha \right)} + R\right)$

# %%
En.factor()
# Out:
# $\displaystyle En =\frac{R m \left(R w_{2}^{2} \sin^{2}{\left(\alpha \right)} - 2 g \cos{\left(\alpha \right)} + 2 g\right)}{2}$

# %%
En.reducecero()
# Out:
# $\displaystyle En =R w_{2}^{2} \sin^{2}{\left(\alpha \right)} - 2 g \cos{\left(\alpha \right)} + 2 g$

# %%
En.sin2cos(alpha)
# Out:
# $\displaystyle En =R w_{2}^{2} \cdot \left(1 - \cos^{2}{\left(\alpha \right)}\right) - 2 g \cos{\left(\alpha \right)} + 2 g$

# %%
En.expand()
# Out:
# $\displaystyle En =- R w_{2}^{2} \cos^{2}{\left(\alpha \right)} + R w_{2}^{2} - 2 g \cos{\left(\alpha \right)} + 2 g$

# %%
En.solve(cos(alpha))
# Out:
# ⎡         2⋅g ⎤
# ⎢1, -1 - ─────⎥
# ⎢            2⎥
# ⎣        R⋅w₂ ⎦

# %%
aM=MyEq(En.diff(alpha),'aM')
# Out:
# $\displaystyle aM =2 R w_{2}^{2} \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} + 2 g \sin{\left(\alpha \right)}$

# %%
aM.reducecero()
# Out:
# $\displaystyle aM =R w_{2}^{2} \cos{\left(\alpha \right)} + g$

# %%
calpha=aM.solve('cos(alpha)')
# Out:
# $\displaystyle cos(alpha) =- \frac{g}{R w_{2}^{2}}$
