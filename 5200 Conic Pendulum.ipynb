# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:bbd9a499-a921-4f2a-b4cc-24619c335c66.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody()

# %%
P.add_forza(m*g,-pi/2,L*sin(alpha),0)
P.add_forza(T,pi/2+alpha,L*sin(alpha),0)
P.r=L*sin(alpha)

# %%
Fy=P.Fy()
# Out:
# $\displaystyle Fy =T \cos{\left(\alpha \right)} - g m$

# %%
Fx=P.Fx('Fx')
# Out:
# $\displaystyle Fx =- T \sin{\left(\alpha \right)}$

# %%
eR=P.eQmovradial()
# Out:
# $\displaystyle - L m w^{2} \sin{\left(\alpha \right)} = - T \sin{\left(\alpha \right)}$

# %%
eR.simplify()
# Out:
# $\displaystyle L m w^{2} = T$

# %%
T=Fy.solve('T')
# Out:
# $\displaystyle T =\frac{g m}{\cos{\left(\alpha \right)}}$

# %%
eR.set(T)
# Out:
# $\displaystyle L m w^{2} = \frac{g m}{\cos{\left(\alpha \right)}}$

# %%
eR.alone(cos(alpha))
# Out:
# $\displaystyle \cos{\left(\alpha \right)} = \frac{g}{L w^{2}}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:e5604cc8-e032-48a1-8357-0e18dc1616e5.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
Q1=MQ(F,m*ac)
# Out:
# $\displaystyle F = a_{c} m$

# %%
Q1.set(m=dm)
# Out:
# $\displaystyle F = a_{c} dm$

# %%
Q1.set(ac=w*w*r)
# Out:
# $\displaystyle F = dm r w^{2}$

# %%
Q1.set(r=x*sin(alpha))
# Out:
# $\displaystyle F = dm w^{2} x \sin{\left(\alpha \right)}$

# %%
Q1.set(dm=rho*dx)
# Out:
# $\displaystyle F = dx \rho w^{2} x \sin{\left(\alpha \right)}$

# %%
Q2=MQ(T,F*x*cos(alpha))
# Out:
# $\displaystyle T = F x \cos{\left(\alpha \right)}$

# %%
Q2.set(Q1)
# Out:
# $\displaystyle T = dx \rho w^{2} x^{2} \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}$

# %%
Q2.set(rho=m/L)
# Out:
# $\displaystyle T = \frac{dx m w^{2} x^{2} \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}}{L}$

# %%
M1=MyIntg(Q2.R,'M1',var=x,x1=0,x2=L)
# Out:
# $\displaystyle M1=\int\limits_{0}^{L} \frac{m w^{2} x^{2} \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}}{L}\, dx$

# %%
M2=MyEq(-m*g*L*sin(alpha)/2,'M2',var=alpha)
# Out:
# $\displaystyle M2 =- \frac{L g m \sin{\left(\alpha \right)}}{2}$

# %%
M1.doit()
# Out:
#  2    2
# L ⋅m⋅w ⋅sin(α)⋅cos(α)
# ─────────────────────
#           3

# %%
Q3=MQ(M1+M2,0)
# Out:
# $\displaystyle \frac{L^{2} m w^{2} \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}}{3} - \frac{L g m \sin{\left(\alpha \right)}}{2} = 0$

# %%
Q3.factor()
# Out:
# $\displaystyle \frac{L m \left(2 L w^{2} \cos{\left(\alpha \right)} - 3 g\right) \sin{\left(\alpha \right)}}{6} = 0$

# %%
Q3.reducecero()
# Out:
# $\displaystyle 2 L w^{2} \cos{\left(\alpha \right)} - 3 g = 0$

# %%
Q3.alone(cos(alpha))
# Out:
# $\displaystyle \cos{\left(\alpha \right)} = \frac{3 g}{2 L w^{2}}$

# %%
P.add_forza(m*g,-pi/2,L*cos(alpha)/2,L*sin(alpha)/2)
P.add_forza(N1,pi/2)
P.add_forza(fr,0)
P.add_forza(F,pi,L*cos(alpha),L*sin(alpha))

# %%
P.set(fr,N1*mu)

# %%
P.In=m*L*L/12

# %%
Q1=P.eQrotation(L*cos(alpha)/2,L*sin(alpha)/2)
# Out:
# $\displaystyle \frac{L^{2} a_{w} m}{12} = - \frac{L \left(F \sin{\left(\alpha \right)} + N_{1} \mu \sin{\left(\alpha \right)} - N_{1} \cos{\left(\alpha \right)}\right)}{2}$

# %%
dalpha=symbols('d'+'𝛼')
d2alpha=symbols('d2'+'𝛼')

# %%
Q2=MQ(ax,L/2*(-sin(alpha)*dalpha**2+cos(alpha)*d2alpha))
# Out:
# $\displaystyle a_{x} = \frac{L \left(d2𝛼 \cos{\left(\alpha \right)} - d𝛼^{2} \sin{\left(\alpha \right)}\right)}{2}$

# %%
Q3=MQ(ay,-L/2*(cos(alpha)*dalpha**2+sin(alpha)*d2alpha))
# Out:
# $\displaystyle a_{y} = - \frac{L \left(d2𝛼 \sin{\left(\alpha \right)} + d𝛼^{2} \cos{\left(\alpha \right)}\right)}{2}$

# %%
Q4=MQ(ax*m,P.Fx())
# Out:
# $\displaystyle a_{x} m = - F + N_{1} \mu$

# %%
Q4.set(Q2)
# Out:
# $\displaystyle \frac{L m \left(d2𝛼 \cos{\left(\alpha \right)} - d𝛼^{2} \sin{\left(\alpha \right)}\right)}{2} = - F + N_{1} \mu$

# %%
Q5=MQ(ay*m,P.Fy())
# Out:
# $\displaystyle Fy =N_{1} - g m$
# $\displaystyle a_{y} m = N_{1} - g m$

# %%
Q5.set(Q3)
# Out:
# $\displaystyle - \frac{L m \left(d2𝛼 \sin{\left(\alpha \right)} + d𝛼^{2} \cos{\left(\alpha \right)}\right)}{2} = N_{1} - g m$

# %%
N1=Q5.solve('N1')
# Out:
# $\displaystyle N1 =\frac{m \left(- L d2𝛼 \sin{\left(\alpha \right)} - L d𝛼^{2} \cos{\left(\alpha \right)} + 2 g\right)}{2}$

# %%
Q4.set(N1)
# Out:
# $\displaystyle \frac{L m \left(d2𝛼 \cos{\left(\alpha \right)} - d𝛼^{2} \sin{\left(\alpha \right)}\right)}{2} = - F + \frac{m \mu \left(- L d2𝛼 \sin{\left(\alpha \right)} - L d𝛼^{2} \cos{\left(\alpha \right)} + 2 g\right)}{2}$

# %%
F=Q4.solve('F')
# Out:
# $\displaystyle F =\frac{m \left(- L d2𝛼 \mu \sin{\left(\alpha \right)} - L d2𝛼 \cos{\left(\alpha \right)} - L d𝛼^{2} \mu \cos{\left(\alpha \right)} + L d𝛼^{2} \sin{\left(\alpha \right)} + 2 g \mu\right)}{2}$

# %%
Q1.s()
# Out:
# $\displaystyle \frac{L^{2} a_{w} m}{12} = - \frac{L \left(F \sin{\left(\alpha \right)} + N_{1} \mu \sin{\left(\alpha \right)} - N_{1} \cos{\left(\alpha \right)}\right)}{2}$

# %%
Q1.set(N1)
# Out:
# $\displaystyle \frac{L^{2} a_{w} m}{12} = - \frac{L \left(F \sin{\left(\alpha \right)} + \frac{m \mu \left(- L d2𝛼 \sin{\left(\alpha \right)} - L d𝛼^{2} \cos{\left(\alpha \right)} + 2 g\right) \sin{\left(\alpha \right)}}{2} - \frac{m \left(- L d2𝛼 \sin{\left(\alpha \right)} - L d𝛼^{2} \cos{\left(\alpha \right)} + 2 g\right) \cos{\left(\alpha \right)}}{2}\right)}{2}$

# %%
Q1.set(F)
# Out:
# $\displaystyle \frac{L^{2} a_{w} m}{12} = - \frac{L \left(\frac{m \mu \left(- L d2𝛼 \sin{\left(\alpha \right)} - L d𝛼^{2} \cos{\left(\alpha \right)} + 2 g\right) \sin{\left(\alpha \right)}}{2} - \frac{m \left(- L d2𝛼 \sin{\left(\alpha \right)} - L d𝛼^{2} \cos{\left(\alpha \right)} + 2 g\right) \cos{\left(\alpha \right)}}{2} + \frac{m \left(- L d2𝛼 \mu \sin{\left(\alpha \right)} - L d2𝛼 \cos{\left(\alpha \right)} - L d𝛼^{2} \mu \cos{\left(\alpha \right)} + L d𝛼^{2} \sin{\left(\alpha \right)} + 2 g \mu\right) \sin{\left(\alpha \right)}}{2}\right)}{2}$

# %%
Q1.factor()
# Out:
# $\displaystyle \frac{L^{2} a_{w} m}{12} = \frac{L m \left(2 L d2𝛼 \mu \sin^{2}{\left(\alpha \right)} + 2 L d𝛼^{2} \mu \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} - L d𝛼^{2} \sin^{2}{\left(\alpha \right)} - L d𝛼^{2} \cos^{2}{\left(\alpha \right)} - 4 g \mu \sin{\left(\alpha \right)} + 2 g \cos{\left(\alpha \right)}\right)}{4}$

# %%
Q1.simplify()
# Out:
# $\displaystyle \frac{L a_{w}}{12} = - \frac{L d2𝛼 \mu \cos{\left(2 \alpha \right)}}{4} + \frac{L d2𝛼 \mu}{4} + \frac{L d𝛼^{2} \mu \sin{\left(2 \alpha \right)}}{4} - \frac{L d𝛼^{2}}{4} - g \mu \sin{\left(\alpha \right)} + \frac{g \cos{\left(\alpha \right)}}{2}$

# %%
Q1.Mul(12)
# Out:
# $\displaystyle L a_{w} = - 3 L d2𝛼 \mu \cos{\left(2 \alpha \right)} + 3 L d2𝛼 \mu + 3 L d𝛼^{2} \mu \sin{\left(2 \alpha \right)} - 3 L d𝛼^{2} - 12 g \mu \sin{\left(\alpha \right)} + 6 g \cos{\left(\alpha \right)}$

# %%
Q1.factor()
# Out:
# $\displaystyle L a_{w} = 3 \left(- L d2𝛼 \mu \cos{\left(2 \alpha \right)} + L d2𝛼 \mu + L d𝛼^{2} \mu \sin{\left(2 \alpha \right)} - L d𝛼^{2} - 4 g \mu \sin{\left(\alpha \right)} + 2 g \cos{\left(\alpha \right)}\right)$

# %%
Q1.Div(L)
# Out:
# $\displaystyle a_{w} = \frac{3 \left(- L d2𝛼 \mu \cos{\left(2 \alpha \right)} + L d2𝛼 \mu + L d𝛼^{2} \mu \sin{\left(2 \alpha \right)} - L d𝛼^{2} - 4 g \mu \sin{\left(\alpha \right)} + 2 g \cos{\left(\alpha \right)}\right)}{L}$

# %%
Q1.expand()
# Out:
# $\displaystyle a_{w} = - 3 d2𝛼 \mu \cos{\left(2 \alpha \right)} + 3 d2𝛼 \mu + 3 d𝛼^{2} \mu \sin{\left(2 \alpha \right)} - 3 d𝛼^{2} - \frac{12 g \mu \sin{\left(\alpha \right)}}{L} + \frac{6 g \cos{\left(\alpha \right)}}{L}$

# %%
Q1.texpand()
# Out:
# $\displaystyle a_{w} = - 3 d2𝛼 \mu \left(2 \cos^{2}{\left(\alpha \right)} - 1\right) + 3 d2𝛼 \mu + 6 d𝛼^{2} \mu \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} - 3 d𝛼^{2} - \frac{12 g \mu \sin{\left(\alpha \right)}}{L} + \frac{6 g \cos{\left(\alpha \right)}}{L}$

# %%
Q1.subs(cos(alpha)**2,1-sin(alpha)**2)
# Out:
# $\displaystyle a_{w} = - 3 d2𝛼 \mu \left(1 - 2 \sin^{2}{\left(\alpha \right)}\right) + 3 d2𝛼 \mu + 6 d𝛼^{2} \mu \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} - 3 d𝛼^{2} - \frac{12 g \mu \sin{\left(\alpha \right)}}{L} + \frac{6 g \cos{\left(\alpha \right)}}{L}$

# %%
Q1.setL(d2alpha)
# Out:
# $\displaystyle d2𝛼 = - 3 d2𝛼 \mu \left(1 - 2 \sin^{2}{\left(\alpha \right)}\right) + 3 d2𝛼 \mu + 6 d𝛼^{2} \mu \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} - 3 d𝛼^{2} - \frac{12 g \mu \sin{\left(\alpha \right)}}{L} + \frac{6 g \cos{\left(\alpha \right)}}{L}$

# %%
Q1.Mul(L)
# Out:
# $\displaystyle L d2𝛼 = 3 L \left(2 d2𝛼 \mu \sin^{2}{\left(\alpha \right)} + d𝛼^{2} \mu \sin{\left(2 \alpha \right)} - d𝛼^{2}\right) - 12 g \mu \sin{\left(\alpha \right)} + 6 g \cos{\left(\alpha \right)}$

# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)

# %% [markdown]
# ![image.png](attachment:4d4fbb96-4dd1-4822-b06c-0ed10552ef26.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody()
