# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:14a1dc27-1cee-4cf5-8399-b2c48e167980.png)

# %%
P=mparticle(x1=0,x2=100,y1=0,y2=10,a=pi/4,g=10)

# %% [markdown]
# ![image.png](attachment:b321fa5f-b932-4e83-a9df-dbcf84813b7c.png)

# %%
# why include 'all' in bellow function..??  because the eq have t^2... and you know neerd...
simplesolve(P.xpos()-100,P.ypos()-10,'all')
# Out:
# [{t: -3⋅√2, v₁: -100/3}, {t: 3⋅√2, v₁: 100/3}]

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:9c462a3d-d5d3-47ae-a54e-bbd67a74fe90.png)

# %%
from Libaldomath import *

# %%
A=mparticle(x1=0,y1=0,y2=0,v1=15,a=pi/4,g=10)

# %%
t1=A.tfly()

# %%
B=A.xmax()

# %%
C=mparticle(x1=0,x2=25-B)

# %%
v=simplesolve(C.xpos(t1)-(25-B))
# Out:
# $\displaystyle v_1 =\frac{5 \sqrt{2}}{6}$

# %% [markdown]
# ![imagen.png](attachment:eeb75532-411b-48cb-9ed6-02fac770b047.png)

# %% [markdown]
# ![imagen.png](attachment:1ed052e8-d59d-48ab-9762-6cd4fd824153.png)

# %%
from Libaldomath import *

# %%
A=mparticle(x1=0,y1=12,v1=V,a=0,g=10)

# %%
A.ypos()
# Out:
#         2
# 12 - 5⋅t

# %%
A.xpos()
# Out:
# V⋅t

# %%
B=mparticle(x1=0,x2=0,y1=0,v1=2*V,a=pi/2,g=10)

# %%
B.ypos()
# Out:
#            2
# 2⋅V⋅t - 5⋅t

# %%
Q=MQ(B.ypos(),A.ypos())
# Out:
# $\displaystyle 2 V t - 5 t^{2} = 12 - 5 t^{2}$

# %%
Q.Add(5*t*t)
# Out:
# $\displaystyle 2 V t = 12$

# %%
Q.Div(2)
# Out:
# $\displaystyle V t = 6$

# %%
A.xpos()
# Out:
# V⋅t

# %%
Q2=MQ(L,6)
# Out:
# $\displaystyle L = 6$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:5a329e76-5a50-4ae0-bd62-76097fa23f26.png)

# %%
from Libaldomath import *

# %%
P=mparticle(a=alpha,x1=0,y1=0,y2=0,v1=V)

# %%
Q1=MyEq(2*t1-P.tfly(),'Q1')
# Out:
# $\displaystyle Q1 =- \frac{2 V \sin{\left(\alpha \right)}}{g} + 2 t_{1}$

# %%
t1=Q1.solve('t1')
# Out:
# $\displaystyle t1 =\frac{V \sin{\left(\alpha \right)}}{g}$

# %%
Q2=MyEq(P.xpos(t1)-P.ypos(t1),'Q2')
# Out:
# $\displaystyle Q2 =- \frac{V^{2} \sin^{2}{\left(\alpha \right)}}{2 g} + \frac{V^{2} \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}}{g}$

# %%
Q2.reducecero()
# Out:
# $\displaystyle Q2 =- \sin{\left(\alpha \right)} + 2 \cos{\left(\alpha \right)}$

# %%
alpha=Q2.solve('alpha')
# Out:
# $\displaystyle α =\operatorname{atan}{\left(2 \right)}$

# %% [markdown]
#  ![line.png](attachment:c4ed1b8c-1944-4eed-a22e-277e691998f4.png)

# %% [markdown]
#  ![km20.png](attachment:f1f24234-0ae8-491e-9d8c-93060b8b690e.png)

# %%
from Libaldomath import *   # run this to reset all variables
from lib_Mechanics import *

# %%
# working whit Ball A alone
A=phybody(g=10,x1=0,y1=0,y2=H,ang=pi/2,ac=0,v1=V)

# %%
Q1=MyEq(A.ymax()-H,'Q1')
# Out:
# $\displaystyle Q1 =- H + \frac{V^{2}}{20}$

# %%
V1=Q1.solve('V','1')
# Out:
# $\displaystyle V =2 \sqrt{5} \sqrt{H}$

# %%
A=phybody(g=10,x1=0,y1=0,ang=pi/2,ac=0,v1=V1)

# %%
B=phybody(g=10,x1=0,y1=H ,ang=pi/2,ac=0,v1=0)

# %%
Q=MyEq(A.ypos()-B.ypos(),'Q1')
# Out:
# $\displaystyle Q1 =2 \sqrt{5} \sqrt{H} t - H$

# %%
Q.solve(t)
# Out:
# √5⋅√H
# ─────
#   10

# %%
B.ypos(Q.solve(t))
# Out:
# 3⋅H
# ───
#  4

# %% [markdown]
#  ![line.png](attachment:c4ed1b8c-1944-4eed-a22e-277e691998f4.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *
