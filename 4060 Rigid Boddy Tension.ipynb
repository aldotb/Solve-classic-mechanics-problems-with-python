# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:93f9a5d8-e670-49b9-b6f6-d9422a94db95.png)

# %%
m0,T0=symbols('m0 T0')
P0=phybody(m=m0)

# %%
P0.add_weight()
P0.add_forza(T0,pi/2)

# %%
Q1=MQ(P0.Fy(),m0*a)
# Out:
# $\displaystyle Fy =T_{0} - g m_{0}$
# $\displaystyle T_{0} - g m_{0} = a m_{0}$

# %%
P2=phybody(m=m2)

# %%
P2.add_forza(T0,0)
P2.add_forza(T1,pi)

# %%
Q2=MQ(P2.Fx(),m2*a)
# Out:
# $\displaystyle Fx =2 T_{0} - T_{1}$
# $\displaystyle 2 T_{0} - T_{1} = a m_{2}$

# %%
P1=phybody(m=m1)
P1.add_forza(T1,0)

# %%
Q3=MQ(P1.Fx(),m1*a)
# Out:
# $\displaystyle Fx =T_{1}$
# $\displaystyle T_{1} = a m_{1}$

# %%
T0,T1,a=simplesolve(Q1,Q2,Q3,T0,T1,a)
# Out:
# $\displaystyle T0 =\frac{- g m_{0} m_{1} - g m_{0} m_{2}}{2 m_{0} - m_{1} - m_{2}}$
# $\displaystyle T1 =- \frac{2 g m_{0} m_{1}}{2 m_{0} - m_{1} - m_{2}}$
# $\displaystyle a =- \frac{2 g m_{0}}{2 m_{0} - m_{1} - m_{2}}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:2cb0d7e1-f66b-438e-b4a8-e73be2a488dc.png)

# %%
m0,T0=symbols('m0 T0')
P0=phybody(m=m0)

# %%
P0.add_weight()
P0.add_forza(T0,pi/2)

# %%
Q1=MQ(P0.Fy(),m0*a)
# Out:
# $\displaystyle Fy =T_{0} - g m_{0}$
# $\displaystyle T_{0} - g m_{0} = a m_{0}$

# %%
P2=phybody(m=m2)

# %%
P2.add_forza(T0,0)
P2.add_forza(T1,pi)
P2.add_weight()
P2.add_forza(fr2,pi)
P2.add_forza(N2,pi/2)

# %%
Q2=MQ(P2.Fx(),m2*a)
# Out:
# $\displaystyle Fx =T_{0} - T_{1} - fr_{2}$
# $\displaystyle T_{0} - T_{1} - fr_{2} = a m_{2}$

# %%
P1=phybody(m=m1)
P1.add_forza(T1,0)
P1.add_weight()
P1.add_forza(fr1,pi)
P1.add_forza(N1,pi/2)

# %%
Q3=MQ(P1.Fx(),m1*a)
# Out:
# $\displaystyle Fx =T_{1} - fr_{1}$
# $\displaystyle T_{1} - fr_{1} = a m_{1}$

# %%
T0,T1,a=simplesolve(Q1,Q2,Q3,T0,T1,a,fr1=m1*g*mu,fr2=m2*g*mu)
# Out:
# $\displaystyle T0 =\frac{g m_{0} m_{1} \mu - g m_{0} m_{1} + g m_{0} m_{2} \mu - g m_{0} m_{2}}{m_{0} - m_{1} - m_{2}}$
# $\displaystyle T1 =\frac{g m_{0} m_{1} \mu - g m_{0} m_{1}}{m_{0} - m_{1} - m_{2}}$
# $\displaystyle a =\frac{- g m_{0} + g m_{1} \mu + g m_{2} \mu}{m_{0} - m_{1} - m_{2}}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:5150def2-2d50-4f40-85ef-4837e9dea6d1.png)

# %%
A=phybody(m=Ma)

# %%
A.add_weight()
A.add_forza(N1,pi/2+alpha)
A.add_forza(T,alpha)
A.add_forza(fr,alpha+pi)

# %%
A.set(fr,N1*mu)

# %%
Q1=MQ(A.fyrelative(alpha),0)
# Out:
# $\displaystyle - M_{a} g \cos{\left(\alpha \right)} + N_{1} = 0$

# %%
N1=Q1.solve('N1')
# Out:
# $\displaystyle N1 =M_{a} g \cos{\left(\alpha \right)}$

# %%
A.set(N1)

# %%
Q2=MQ(A.fxrelative(alpha),Ma*a1)
# Out:
# $\displaystyle - M_{a} g \mu \cos{\left(\alpha \right)} - M_{a} g \sin{\left(\alpha \right)} + T = M_{a} a_{1}$

# %%
T=Q2.solve('T')
# Out:
# $\displaystyle T =M_{a} \left(a_{1} + g \mu \cos{\left(\alpha \right)} + g \sin{\left(\alpha \right)}\right)$

# %%
A.set(T)

# %%
Mb=symbols('Mb')
B=phybody(m=Mb)

# %%
B.add_weight()
B.add_forza(T/2,pi/2)

# %%
Q3=MQ(B.Fy(),-Mb*2*a1)
# Out:
# $\displaystyle Fy =\frac{M_{a} \left(a_{1} + g \mu \cos{\left(\alpha \right)} + g \sin{\left(\alpha \right)}\right)}{2} - Mb g$
# $\displaystyle \frac{M_{a} \left(a_{1} + g \mu \cos{\left(\alpha \right)} + g \sin{\left(\alpha \right)}\right)}{2} - Mb g = - 2 Mb a_{1}$

# %%
Q3.alone(a1)
# Out:
# $\displaystyle a_{1} = \frac{g \left(- M_{a} \mu \cos{\left(\alpha \right)} - M_{a} \sin{\left(\alpha \right)} + 2 Mb\right)}{M_{a} + 4 Mb}$
