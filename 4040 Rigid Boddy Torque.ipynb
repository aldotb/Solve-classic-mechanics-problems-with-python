# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:1aff9d9f-deba-4293-979a-f03ddf9d26bb.png)

# %%
alpha=atan(cfrac(3,4)) # alpha=37g

# %%
P=phybody()
P.add_forza(N1,0,0,3*L)
P.add_forza(600,-pi/2,2*L,2*L)
P.add_forza(N2,pi/2,4*L,0)
P.add_forza(fr,pi,4*L,0)

# %%
P=phybody()
P.add(m*g,-pi/2,L*cos(alpha)/2,L*sin(alpha)/2)

# %%
To=P.To()
# Out:
# $\displaystyle To =0$

# %%
To.reducecero()
# Out:
# $\displaystyle To =3 N_{1} - 4 N_{2} + 1200$

# %%
Fx=P.Fx()
Fy=P.Fy()
# Out:
# $\displaystyle Fx =N_{1} - f_{r}$
# $\displaystyle Fy =N_{2} - 600$

# %%
N1,N2,fr=simplesolve(To,Fx,Fy)
# Out:
# $\displaystyle N1=400$
# $\displaystyle N2=600$
# $\displaystyle fr=400$

# %%
Fx.subs(fr,N2*mu)
# Out:
# $\displaystyle Fx =N_{1} - N_{2} \mu$

# %%
R=MyEq(fr-N2*mu,'R')
# Out:
# $\displaystyle R =- N_{2} \mu + f_{r}$

# %%
Fy=P.Fy()
# Out:
# $\displaystyle Fy =N_{2} - 600$

# %%
N2,N1,fr,mu=simplesolve(To,Fy,Fx,R)
# Out:
# $\displaystyle N2 =600$
# $\displaystyle N1 =400$
# $\displaystyle f_r =400$
# $\displaystyle 𝜇 =\frac{2}{3}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:4577997c-c800-4a83-9948-f0d17f0bdcc5.png)

# %%
A=phybody()
A.add_forza(m1*g,-pi/2,-2*R,0)
A.add_forza(T1,0,0,R)

# %%
B=phybody()
B.add_forza(T1,pi,0,4*R)
B.add_forza(T2,0,0,R)

# %%
C=phybody()
C.add_forza(T2,pi,0,3*R)
C.add_forza(m2*g,-pi/2,3*R,0)

# %%
At=A.To('At')
Bt=B.To('Bt')
Ct=C.To('Ct')
# Out:
# $\displaystyle At =- R T_{1} + 2 R g m_{1}$
# $\displaystyle Bt =4 R T_{1} - R T_{2}$
# $\displaystyle Ct =3 R T_{2} - 3 R g m_{2}$

# %%
T1,T2,m2=simplesolve(At,Bt,Ct,T1,T2,m2)
# Out:
# $\displaystyle T1=2 g m_{1}$
# $\displaystyle T2=8 g m_{1}$
# $\displaystyle m2=8 m_{1}$
