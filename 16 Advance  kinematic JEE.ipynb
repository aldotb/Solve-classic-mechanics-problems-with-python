# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![da_200.png](attachment:7f52af1d-2b0c-4f54-9578-af4fe48d905a.png)

# %%
from physic_lib2 import * # run this to reset all variables
reset_ee(e1,e2,e3,e4,e5)

# %%
P=mparticle(y1=0,a=pi/4)
e1=e1Q(H-P.y_max())
# Out:
# $\displaystyle e1 =H - \frac{v^{2}}{4 g}$

# %%
v=e1.solveR(v,'v')
# Out:
# $\displaystyle v =2 \sqrt{H g}$

# %%
e2=e2Q(h-P.y_pos())
# Out:
# $\displaystyle e2 =\frac{g t^{2}}{2} + h - \frac{\sqrt{2} t v}{2}$

# %%
t1,t2=e2.solve(t,'t')
# Out:
# $\displaystyle t1 =\frac{\sqrt{2} \left(v - \sqrt{- 4 g h + v^{2}}\right)}{2 g}$
# $\displaystyle t2 =\frac{\sqrt{2} \left(v + \sqrt{- 4 g h + v^{2}}\right)}{2 g}$

# %%
T=MyEq(t2-t1,'T')
# Out:
# $\displaystyle T =- \frac{\sqrt{2} \left(v - \sqrt{- 4 g h + v^{2}}\right)}{2 g} + \frac{\sqrt{2} \left(v + \sqrt{- 4 g h + v^{2}}\right)}{2 g}$

# %%
T.simplify()
# Out:
# $\displaystyle T =\frac{\sqrt{- 8 g h + 2 v^{2}}}{g}$

# %%
T.upgrade(v)
# Out:
# $\displaystyle T =\frac{\sqrt{8 H g - 8 g h}}{g}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![da_300.png](attachment:81aa74aa-0db5-43e6-9c51-7799df75c82f.png)

# %%
from physic_lib2 import * # run this to reset all variables
reset_ee(e1,e2,e3,e4,e5)

# %%
a,V,A,B,t=symbols('a v A B t')

# %%
V1=MyEq(1/(A-v*B),'V',var2=v,ktype='I')
# Out:
# $\displaystyle V =\int \frac{1}{A - B v}\, dv$

# %%
V1.doitI()
# Out:
# $\displaystyle V =- \frac{\log{\left(- A + B v \right)}}{B}$

# %%
e2=e2Q(V1-t)
# Out:
# $\displaystyle e2 =- t - \frac{\log{\left(- A + B v \right)}}{B}$

# %%
v=e2.solve(v,'v')
# Out:
# $\displaystyle v =\frac{A}{B} + \frac{e^{- B t}}{B}$

# %%
#velocity terminal will be maximun velocity or when acc=0 and v not 0
e3=e3Q(A-V*B)
Vt=e3.solve(V,'V_t')
# Out:
# $\displaystyle e3 =A - B v$
# $\displaystyle V_t =\frac{A}{B}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![da_400.png](attachment:2b1a224e-d320-4880-800d-7600fe955383.png)

# %%
from physic_lib2 import * # run this to reset all variables
reset_ee(e1,e2,e3,e4,e5)

# %%
v,alpha,t,x,g=symbols('v alpha t x g')

# %%
P=mparticle(x1=0,y1=0,v=v,a=alpha,ac=0,g=g)

# %% [markdown]
# ![eQ_trayec.png](attachment:61d93ab7-3872-4d6f-b27b-bd6358b8c622.png)

# %%
e1=e1Q(40-P.eQ_trayec(x))
# Out:
# $\displaystyle e1 =\frac{g x^{2}}{2 v^{2} \cos^{2}{\left(\alpha \right)}} - x \tan{\left(\alpha \right)} + 40$

# %%
e1.set(x,30)
# Out:
# $\displaystyle e1 =\frac{450 g}{v^{2} \cos^{2}{\left(\alpha \right)}} - 30 \tan{\left(\alpha \right)} + 40$

# %%
e1.set(g,10)
# Out:
# $\displaystyle e1 =- 30 \tan{\left(\alpha \right)} + 40 + \frac{4500}{v^{2} \cos^{2}{\left(\alpha \right)}}$

# %%
e1.Div(10)
# Out:
# $\displaystyle e1 =- 3 \tan{\left(\alpha \right)} + 4 + \frac{450}{v^{2} \cos^{2}{\left(\alpha \right)}}$

# %%
v2=e1.solve(v*v,'v2')
# Out:
# $\displaystyle v2 =\frac{450}{\left(3 \tan{\left(\alpha \right)} - 4\right) \cos^{2}{\left(\alpha \right)}}$

# %%
v2.opemat_deno('etx')
# Out:
# 450/(3*sin(alpha)*cos(alpha) - 4*cos(alpha)**2)

# %% [markdown]
#  ![get_deno.png](attachment:b7c243f0-7a89-4245-aa60-86e4d5ebeb57.png)

# %%
#  v will by minimun if v*v is minimun and denominator of upper v Eq is maximun 
fa=MyEq(v2.get_deno(),'fa')
# Out:
# $\displaystyle fa =3 \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} - 4 \cos^{2}{\left(\alpha \right)}$

# %%
fa.opematsec('s')
# Out:
# 3*sin(2*alpha)/2 - 2*cos(2*alpha) - 2

# %%
fa.reduFac()
# Out:
# $\displaystyle fa =3 \sin{\left(2 \alpha \right)} - 4 \cos{\left(2 \alpha \right)} - 4$

# %%
dfa=fa.diff(alpha,'dfa')
# Out:
# $\displaystyle dfa =8 \sin{\left(2 \alpha \right)} + 6 \cos{\left(2 \alpha \right)}$

# %%
dfa.Div(cos(2*alpha))
# Out:
# $\displaystyle dfa =\frac{8 \sin{\left(2 \alpha \right)}}{\cos{\left(2 \alpha \right)}} + 6$

# %%
dfa.tsimplify()
# Out:
# $\displaystyle dfa =8 \tan{\left(2 \alpha \right)} + 6$

# %%
dfa.solve(tan(2*alpha))
# Out:
# -3/4

# %%
v2.s()
# Out:
# $\displaystyle v2 =\frac{450}{3 \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} - 4 \cos^{2}{\left(\alpha \right)}}$

# %%
T3=MyTriang(cat1=3,cat2=1)

# %%
v2.upTriang(alpha,T3)
# Out:
# $\displaystyle v2 =900$

# %%
V1=300;V1
# Out:
# 300

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![da_500.png](attachment:4c83ce58-83f6-46c5-acda-4cd6f33d39ce.png)

# %%
from physic_lib2 import * # run this to reset all variables
reset_ee(e1,e2,e3,e4,e5)

# %%
v,alpha,g,a,h,R,x=symbols('v alpha g a h R x')

# %%
P=mparticle(x1=0,y1=h,v=rpow(2*a*g),a=alpha,ac=0,g=g,y2=0,x2=R)

# %%
Y=MyEq(P.eQ_trayec(x),'Y')
# Out:
# $\displaystyle Y =x \tan{\left(\alpha \right)} - \frac{x^{2}}{4 a \cos^{2}{\left(\alpha \right)}}$

# %%
Y.reduFac() # beacue X is max when Y(x)=0
# Out:
# $\displaystyle Y =- 4 a \cos^{2}{\left(\alpha \right)} \tan{\left(\alpha \right)} + x$

# %%
X=Y.solve(x,'X',kope='x') # X max... in func alpha and Xdiff(alpha)=0 get alpha to X max
# Out:
# $\displaystyle X =4 a \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}$

# %%
dx=X.diff(alpha,'dx')
# Out:
# $\displaystyle dx =- 4 a \sin^{2}{\left(\alpha \right)} + 4 a \cos^{2}{\left(\alpha \right)}$

# %%
dx.Div(kpow(cos(alpha),2))
# Out:
# $\displaystyle dx =- \frac{4 a \sin^{2}{\left(\alpha \right)}}{\cos^{2}{\left(\alpha \right)}} + 4 a$

# %%
dx.tsimplify()
# Out:
# $\displaystyle dx =4 a \left(1 - \tan^{2}{\left(\alpha \right)}\right)$

# %%
dx.solve(alpha)
# Out:
# [-pi/4, pi/4]

# %%
Xm=MyEq(P.x_max(),'X_m')
# Out:
# $\displaystyle X_m =2 a \left(\sqrt{\sin^{2}{\left(\alpha \right)} + \frac{h}{a}} + \sin{\left(\alpha \right)}\right) \cos{\left(\alpha \right)}$

# %%
Xm.set(alpha,pi/4)
# Out:
# $\displaystyle X_m =\sqrt{2} a \left(\sqrt{\frac{1}{2} + \frac{h}{a}} + \frac{\sqrt{2}}{2}\right)$

# %%
Xm.simplify()
# Out:
# $\displaystyle X_m =a \left(\sqrt{\frac{a + 2 h}{a}} + 1\right)$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![da_600.png](attachment:0d68f7da-b724-405d-91e1-acd5777af8fb.png)

# %%
from physic_lib2 import * # run this to reset all variables
reset_ee(e1,e2,e3,e4,e5)

# %%
v,g=symbols('v g')

# %%
P=mparticle(x1=0,x2=100,y1=frs(1,10),y2=0,v=v,g=10 ,a=0,ac=0)

# %%
e1=e1Q(P.x_max()-100,kope='r')
# Out:
# $\displaystyle e1 =\frac{\sqrt{2} v}{10} - 100$

# %%
V=e1.solve(v,'V',kope='v')
# Out:
# $\displaystyle V =707.106781186548$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![da_700.png](attachment:6a1504de-5478-4c98-82ce-ef5dc9fea471.png)

# %%
from physic_lib2 import * # run this to reset all variables
reset_ee(e1,e2,e3,e4,e5)

# %%
v,h,b,n,R,t=symbols('v h b n R t')

# %%
P=mparticle(x1=0,y1=h*n,x2=R,y2=0,v=v,a=0,ac=0)

# %%
t1=csolve(v*t-n*b,t,'t_1')
# Out:
# $\displaystyle t_1 =\frac{b n}{v}$

# %%
Y=MyEq(P.y_pos(t1),'Y')
# Out:
# $\displaystyle Y =- \frac{b^{2} g n^{2}}{2 v^{2}} + h n$

# %%
Y.reduFac()
# Out:
# $\displaystyle Y =- b^{2} g n + 2 h v^{2}$

# %%
n1=Y.solve(n,'n')
# Out:
# $\displaystyle n =\frac{2 h v^{2}}{b^{2} g}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![da_800.png](attachment:80a8f5ec-357f-4c4a-8ae6-7f1970c88254.png)

# %%
from physic_lib2 import * # run this to reset all variables
reset_ee(e1,e2,e3,e4,e5)

# %%
v,L,H,h,g,alpha,t1,t2=symbols('v L H h g alpha t1 t2')

# %%
# Creating mparticle object and set all
P1=mparticle(x1=0,x2=0,y1=H,y2=h,a=pi/2,v=0,ac=0)
P2=mparticle(x1=0,x2=L,y1=H,y2=h,a=0,v=v,ac=0)
P3=mparticle(x1=0,x2=L,y1=0,y2=h,a=alpha,v=v,ac=0)
e0=e0Q(H-h-P1.y_pos(t1))
e1=e1Q(L-P2.x_pos(t1))
e2=e2Q(H-h-P3.y_pos(t2))
e3=e3Q(L-P3.x_pos(t2))
e4=e4Q(t2-2*t1)
# Out:
# $\displaystyle e0 =\frac{g t_{1}^{2}}{2} - h$
# $\displaystyle e1 =L - t_{1} v$
# $\displaystyle e2 =H + \frac{g t_{2}^{2}}{2} - h - t_{2} v \sin{\left(\alpha \right)}$
# $\displaystyle e3 =L - t_{2} v \cos{\left(\alpha \right)}$
# $\displaystyle e4 =- 2 t_{1} + t_{2}$

# %%
v=upgradeList(e0,e1,e2,e3,e4,v,t1,t2,andsolve=['v',e1])
# Out:
# $\displaystyle e0 =\frac{g t_{1}^{2}}{2} - h$
# $\displaystyle e2 =H - \frac{L t_{2} \sin{\left(\alpha \right)}}{t_{1}} + \frac{g t_{2}^{2}}{2} - h$
# $\displaystyle e3 =\frac{L \left(t_{1} - t_{2} \cos{\left(\alpha \right)}\right)}{t_{1}}$
# $\displaystyle e4 =- 2 t_{1} + t_{2}$
# $\displaystyle v =\frac{L}{t_{1}}$

# %%
t1=upgradeList(e0,e1,e2,e3,e4,v,t1,t2,andsolve=['t1',e4])
# Out:
# $\displaystyle e0 =\frac{g t_{2}^{2}}{8} - h$
# $\displaystyle e2 =H - 2 L \sin{\left(\alpha \right)} + \frac{g t_{2}^{2}}{2} - h$
# $\displaystyle e3 =L \left(1 - 2 \cos{\left(\alpha \right)}\right)$
# $\displaystyle v =\frac{2 L}{t_{2}}$
# $\displaystyle t1 =\frac{t_{2}}{2}$

# %%
t2=e0.solveR(t2,'t2')
# Out:
# $\displaystyle t2 =2 \sqrt{2} \sqrt{\frac{h}{g}}$

# %%
upgrade(e0,e1,e2,e3,e4,t2,v,t1)
# Out:
# $\displaystyle e2 =H - 2 L \sin{\left(\alpha \right)} + 3 h$
# $\displaystyle e3 =L \left(1 - 2 \cos{\left(\alpha \right)}\right)$
# $\displaystyle v =\frac{\sqrt{2} L}{2 \sqrt{\frac{h}{g}}}$
# $\displaystyle t1 =\sqrt{2} \sqrt{\frac{h}{g}}$
# $\displaystyle e1 =L - t_{1} v$
# $\displaystyle e4 =- 2 t_{1} + t_{2}$
# $\displaystyle t2 =2 \sqrt{2} \sqrt{\frac{h}{g}}$

# %%
alpha=e3.solve(alpha,'alpha',korden=0)
# Out:
# $\displaystyle α =\frac{\pi}{3}$

# %%
alpha.s();t1.s();t2.s();v.s()
# Out:
# $\displaystyle α =\frac{\pi}{3}$
# $\displaystyle t1 =\sqrt{2} \sqrt{\frac{h}{g}}$
# $\displaystyle t2 =2 \sqrt{2} \sqrt{\frac{h}{g}}$
# $\displaystyle v =\frac{\sqrt{2} L}{2 \sqrt{\frac{h}{g}}}$
