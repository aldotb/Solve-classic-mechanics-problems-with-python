# %%
from Libaldomath import *
from lib_MyVec import *

# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)

# %% [markdown]
# ![image.png](attachment:56fcf1d6-9c2f-4d8c-a948-d9e029636bb9.png)

# %%
v1=MyVector(1,1,0)
v2=MyVector(2,1,0)
v3=MyVector(-1,-1,0)
v4=MyVector(1,-1,0)

# %%
(v1+v2)+(v3+v4)
# Out:
# (3) i_N

# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)

# %%
from Libaldomath import *
from lib_MyVec import *

# %% [markdown]
# ![image.png](attachment:7a835d51-68e3-488c-a196-4d0f0c8d223b.png)

# %%
A=MyVector(x,10,0)
B=MyVector(x,0,0)
C=MyVector(x,-10,0)

# %%
Q=MQ(A.module,26)
# Out:
# $\displaystyle \sqrt{x^{2} + 100} = 26$

# %%
x1,x2=Q.solve(x)
# Out:
# $\displaystyle x1=-24$
# $\displaystyle x2=24$

# %%
A=MyVector(x1,10,0)
B=MyVector(x1,0,0)
C=MyVector(x1,-10,0)

# %%
R=MyVector(A+(B+C))

# %%
R.module
# Out:
# 72

# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)

# %%
from Libaldomath import *
from lib_MyVec import *

# %% [markdown]
# ![image.png](attachment:0bee994e-86b9-4f94-9883-cd07597f79bb.png)

# %%
y=x*tan(pi/3)

# %%
A=MyVector(x,y,0)
B=MyVector(1+x,y,0)
C=MyVector(-(3-x),y,0)

# %%
Q=MQ(2,A.module)
# Out:
# $\displaystyle 2 = 2 \sqrt{x^{2}}$

# %%
x1,x2=Q.solve(x)
# Out:
# $\displaystyle x1=-1$
# $\displaystyle x2=1$

# %%
x=1
y=x*tan(pi/3)
A=MyVector(x,y,0)
B=MyVector(1+x,y,0)
C=MyVector(-(3-x),y,0)

# %%
R=MyVector(A+(B+C))

# %%
R.module
# Out:
# 2⋅√7

# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)

# %%
from Libaldomath import *
from lib_MyVec import *

# %% [markdown]
# ![image.png](attachment:d40aa6ea-5505-4dc3-9f92-4ae67cea685a.png)

# %% [markdown]
# ![image.png](attachment:25f3a66a-aaca-4c55-9990-ceb5396a356c.png)

# %%
Q1=MQ(A,C+3*x)
Q2=MQ(3*x,C+B)
# Out:
# $\displaystyle A = C + 3 x$
# $\displaystyle 3 x = B + C$

# %%
Q1.Substrac(Q2)
# Out:
# $\displaystyle A - 3 x = - B + 3 x$

# %%
Q1.Add(3*x+B)
# Out:
# $\displaystyle A + B = 6 x$

# %%
Q1.Div(6)
# Out:
# $\displaystyle \frac{A}{6} + \frac{B}{6} = x$

# %%
# the m,n = 1/6
m=cfrac(1,6)
n=cfrac(1,6)
m+n
# Out:
#   1
# 2⋅─
#   6

# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)
