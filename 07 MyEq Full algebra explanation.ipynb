# %%
from sympy import symbols
from libaldo_math2 import *
from lib_MyEq import *
from libaldo_show import *
from IPython.display import display, Math
init_printing()

# %% [markdown]
# ![line.png](attachment:line.png)

# %% [markdown]
#  ![sympya.png](attachment:7143d7b2-2ed9-45fe-9edc-17f64890a2e7.png)

# %% [markdown]
# ![imagen.png](attachment:26dd79e2-d4b7-422d-9be7-d06d4de9cc6d.png)

# %%
# MyEq id a class to manage algegra equation
x,y,z,alpha=symbols('x y z alpha')

# %%
V=MyEq(x*x+y/z+z/5,'V')
# Out:
# $\displaystyle V =x^{2} + \frac{y}{z} + \frac{z}{5}$

# %% [markdown]
# ![imagen.png](attachment:af747f48-88e5-415d-bc79-1e86fd9ff275.png)

# %%
e1=MyEq(((x+y)*(x-y)-x*x)/y+z*x+z*y,'e1')
# Out:
# $\displaystyle e1 =x z + y z + \frac{- x^{2} + \left(x - y\right) \left(x + y\right)}{y}$

# %% [markdown]
# ![imagen.png](attachment:e2bc9c97-7edc-4066-9075-e6c8ed5a4d6d.png)

# %%
e1.s()  #show..
# Out:
# $\displaystyle e1 =x z + y z + \frac{- x^{2} + \left(x - y\right) \left(x + y\right)}{y}$

# %%
e1() # value
# Out:
#                2
#             - x  + (x - y)⋅(x + y)
# x⋅z + y⋅z + ──────────────────────
#                       y

# %%
e1.Add(5*z) # summ
# Out:
#                      2
#                   - x  + (x - y)⋅(x + y)
# x⋅z + y⋅z + 5⋅z + ──────────────────────
#                             y

# %%
e1.simplify()
# Out:
# $\displaystyle e1 =x z + y z - y + 5 z$

# %%
e1.factor()
# Out:
# $\displaystyle e1 =x z + y z - y + 5 z$

# %%
e1.factorSec(z)
# Out:
# $\displaystyle e1 =- y + z \left(x + y + 5\right)$

# %%
e1.all_type()
# Out:
# $\displaystyle e1 =- y + z \left(x + y + 5\right)$
# $\displaystyle Monomie=\;\text{False}\;Polynomie\;=\;\text{True}\;$
# $\displaystyle Is\;Add=\;\text{True}\;Is\;Mul=\;\text{False}\;$

# %%
allType(e1())
# Out:
# $\displaystyle - y + z \left(x + y + 5\right)\;$
# $\displaystyle Is\;Polynomie\;=\;\text{True}\;$
# $\displaystyle Is\;Symbols=\;\text{False}\;$
# $\displaystyle Is\;Number=\;\text{False}\;$
# $\displaystyle Is\;Real=\;\text{False}\;$
# $\displaystyle Is\;Integer=\;\text{False}\;$
# $\displaystyle Is\;Even=\;\text{False}\;$
# $\displaystyle Is\;Odd=\;\text{False}\;$
# $\displaystyle Is\;Monomie=\;\text{False}\;$
# $\displaystyle Is\;Add=\;\text{True}\;$
# $\displaystyle Is\;Mul=\;\text{False}\;$
# $\displaystyle Is\;Pow=\;\text{False}\;$
# $\displaystyle Is\;Pow2=\;\text{False}\;$
# $\displaystyle Is\;Root=\;\text{False}\;$

# %%
x,y,z,alpha=symbols('x y z alpha')
e1=e1Q(x*x+y*y+z)  # short form to crete MyEq e1Q...e2Q.... e12Q...
# Out:
# $\displaystyle e1 =x^{2} + y^{2} + z$

# %%
e2=e2Q(y-3*z+100)
# Out:
# $\displaystyle e2 =y - 3 z + 100$

# %%
# solve...
y=e2.solve(y,'y')
# Out:
# $\displaystyle y =3 z - 100$

# %%
# remember e1
e1.s()
# Out:
# $\displaystyle e1 =x^{2} + y^{2} + z$

# %%
# y in e1..??
e1.upgrade(y)
# Out:
# $\displaystyle e1 =x^{2} + z + \left(3 z - 100\right)^{2}$

# %%
e1.upgrade(y)
# Out:
# $\displaystyle e1 =x^{2} + z + \left(3 z - 100\right)^{2}$

# %%
e1.expand()
# Out:
# $\displaystyle e1 =x^{2} + 9 z^{2} - 599 z + 10000$

# %%
e1.solve(x)  # hummmmm   I fuck...g want only one ... then..
# Out:
# ⎡    ________________________     ________________________⎤
# ⎢   ╱      2                     ╱      2                 ⎥
# ⎣-╲╱  - 9⋅z  + 599⋅z - 10000 , ╲╱  - 9⋅z  + 599⋅z - 10000 ⎦

# %%
e1.solveR(x)
# Out:
#    ________________________
#   ╱      2
# ╲╱  - 9⋅z  + 599⋅z - 10000

# %%
x=e1.solveR(x,'x') # when include strin in the end.. create a new MyEq if not return value
# Out:
# $\displaystyle x =\sqrt{- 9 z^{2} + 599 z - 10000}$

# %%
x(z=1)
# Out:
# √9410⋅ⅈ
