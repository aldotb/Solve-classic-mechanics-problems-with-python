# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %% [markdown]
# ![image.png](attachment:4f8831e2-3c94-4327-845e-6bd5f0309db2.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody(x1=0,y1=0,v1=v,x2=R*cos(alpha),y2=R-R*sin(alpha))

# %%
P.add_weight()
P.add_forza(N1,pi/2+alpha)

# %%
Q1=MQ(m*v*v/R,P.fxrelative(alpha+pi/2) )
# Out:
# $\displaystyle \frac{m v^{2}}{R} = N_{1} - g m \cos{\left(\alpha \right)}$

# %%
P.energia('kp')
# Out:
#                          2       2
#                       m⋅v    m⋅v₂
# g⋅m⋅(-R⋅sin(α) + R) - ──── + ─────
#                        2       2
