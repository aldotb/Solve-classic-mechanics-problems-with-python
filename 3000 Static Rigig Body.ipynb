# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![p010a.png](attachment:84dd77b8-dc1a-40fa-bec3-d24cbe7e32d3.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody()

# %%
P.add_forza(F1,0)
P.add_forza(N1,pi/2)
P.add_forza(m*g,-pi/2)
P.add_forza(fr,pi)

# %%
Fx=Fx=P.Fx()
# Out:
# $\displaystyle Fx =F_{1} - f_{r}$

# %%
Fy=P.Fy()
# Out:
# $\displaystyle Fy =N_{1} - g m$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ## Working whit two Physic object

# %% [markdown]
# ![p030.png](attachment:cb818d1a-58af-4268-8868-b88a55f9a371.png)

# %%
P1=phybody(m=m1)
P1.add_forza(N1,pi/2)
P1.add_weight() # equivalnet to P1.add_forza(m1*g,-pi/2)
P1.add_forza(fr,pi)
P1.add_forza(T,alpha)

# %%
P2=phybody(m=m2)
P2.add_weight() # equivalnet to P1.add_forza(m2*g,-pi/2)
P2.add_forza(T,pi/2)

# %% [markdown]
# ![imagen.png](attachment:94d9202d-b1a3-42c1-87ae-64b197451e85.png)

# %%
# from P2
Fy=P2.Fy()
# Out:
# $\displaystyle Fy =T - g m_{2}$

# %%
T=Fy.solve('T')
# Out:
# $\displaystyle T =g m_{2}$

# %%
# from P1

# %%
Fx=P1.Fx()
# Out:
# $\displaystyle Fx =T \cos{\left(\alpha \right)} - f_{r}$

# %%
Fx.set(T)
# Out:
# $\displaystyle Fx =- f_{r} + g m_{2} \cos{\left(\alpha \right)}$

# %%
Fx.subs(fr,N1*mu)
# Out:
# $\displaystyle Fx =- N_{1} \mu + g m_{2} \cos{\left(\alpha \right)}$

# %%
Fy=P1.Fy()
# Out:
# $\displaystyle Fy =N_{1} + T \sin{\left(\alpha \right)} - g m$

# %%
Fy.set(T)
# Out:
# $\displaystyle Fy =N_{1} - g m + g m_{2} \sin{\left(\alpha \right)}$

# %%
N1=Fy.solve('N1')
# Out:
# $\displaystyle N1 =g \left(m - m_{2} \sin{\left(\alpha \right)}\right)$

# %%
Fx.set(N1)
# Out:
# $\displaystyle Fx =g m_{2} \cos{\left(\alpha \right)} - g \mu \left(m - m_{2} \sin{\left(\alpha \right)}\right)$

# %%
mu=Fx.solve('mu')
# Out:
# $\displaystyle 𝜇 =\frac{m_{2} \cos{\left(\alpha \right)}}{m - m_{2} \sin{\left(\alpha \right)}}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ## Working whit torque and adding forze whit x,y position neccesary for torque calculus

# %% [markdown]
# ![p040.png](attachment:e5e14786-609c-4624-9f31-b722b272a11d.png)

# %%
P=phybody()

# %%
P.add_forza(R,alpha)
P.add_forza(2*W,pi/6,L/4,0)
P.add_forza(W,pi/2,L,0)
P.add_forza(500,-pi/2,L/2,0)

# %%
T=P.To()
# Out:
# $\displaystyle To =\frac{5 L W}{4} - 250 L$

# %%
W=T.solve('W')
# Out:
# $\displaystyle W =200$

# %% [markdown]
#  ![line.png](attachment:bab74f7c-ed56-4f3d-a005-4595cf8b00bd.png)

# %% [markdown]
# ## More torque super easy sample... more advance come real nerd problems solve

# %% [markdown]
# ![p050.png](attachment:8530bde1-25bc-4fa3-88a9-7ec9492e5927.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody()

# %%
# Add several Forces in one step 
P.addF((R1,pi/2,0,0),(3*10,-pi/2,b,0),(6*10,-pi/2,2*b,0),(R2,pi/2,3*b,0))

# %%
T1=P.To()
# Out:
# $\displaystyle To =3 R_{2} b - 150 b$

# %%
T2=P.To(3*b,0)
# Out:
# $\displaystyle To =- 3 R_{1} b + 120 b$

# %%
R1,R2=simplesolves(T1,T2,R1,R2)
# Out:
# $\displaystyle R2=50$
# $\displaystyle R1=40$

# %% [markdown]
# ![line.png](attachment:780cf68b-4f54-492b-93ed-11fd0e92482b.png)

# %% [markdown]
# ![E800.png](attachment:982785f9-436c-4eab-b36b-e4005e89cb77.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![imagen.png](attachment:8f931a18-34d2-4ece-91f3-cb81d8074ec7.png)

# %%
L=get_hipo(a/2,a/2);L
# Out:
#     1
#     ─
#     2
# ⎛ 2⎞
# ⎜a ⎟
# ⎜──⎟
# ⎝2 ⎠

# %%
alpha=pi/6+pi/4;alpha
# Out:
# 5⋅π
# ───
#  12

# %%
P1=mparticle()
P1.add_geoforza(Rx,a/2,pi/6,pi-pi/6)
P1.add_geoforza(Ry,a/2,pi/6,pi/6)
P1.add_geoforza(M*g,L,alpha,-pi/2-alpha)

# %%
Fy=FyQ(P1,kope='s')
# Out:
# $\displaystyle Fy =- M g + \frac{\sqrt{3} R_{y}}{2}$

# %%
Fx=FxQ(P1,kope='s')
# Out:
# $\displaystyle Fx =- R_{x} + \frac{R_{y}}{2}$

# %%
P2=mparticle()
P2.addF((Rx,0),(Ry,-pi/2),(m*g,-pi/2),(fr,pi),(Nm,pi/2))

# %%
Fy2=FyQ(P2)
# Out:
# $\displaystyle Fy =Nm - R_{y} - g m$

# %%
Nm=Fy2.solve(Nm,'Nm')
# Out:
# $\displaystyle Nm =R_{y} + g m$

# %%
Fx2=FxQ(P2,'Fx2')
# Out:
# $\displaystyle Fx2 =R_{x} - fr$

# %%
Fx2.set(fr,Nm*mu)
# Out:
# $\displaystyle Fx2 =R_{x} - \mu \left(R_{y} + g m\right)$

# %%
mu=Fx2.solve(mu,'mu')
# Out:
# $\displaystyle mu =\frac{R_{x}}{R_{y} + g m}$

# %%
#  EASY FOR YOU.... yes you right.. 
#  a little sample that what comes later

# %% [markdown]
# ![line.png](attachment:780cf68b-4f54-492b-93ed-11fd0e92482b.png)

# %% [markdown]
# ![imagen.png](attachment:817e226a-efc2-49b9-87a0-2315b4976744.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
alpha=pi/4
P=mparticle(v1=0,y1=L,y2=h,x1=0,x2=L-h)
P.addF((m*g,-pi/2),(Nm,pi/2-alpha))

# %%
Fry=FryQ(P,-alpha,kope='s')
# Out:
# $\displaystyle Fry =Nm - \frac{\sqrt{2} g m}{2}$

# %%
Nm=Fry.solve(Nm,'Nm')
# Out:
# $\displaystyle Nm =\frac{\sqrt{2} g m}{2}$

# %%
Frx=FrxQ(P,-alpha,kope='s')
# Out:
# $\displaystyle Frx =\frac{\sqrt{2} g m}{2}$

# %%
(L-h)/sin(pi/4)
# Out:
# sqrt(2)*(L - h)

# %%
Wo=MyEq(Frx*(L-h)/sin(pi/4),'Wo',Pobj=P,ktype='Ph')
# Out:
# $\displaystyle Wo =g m \left(L - h\right)$

# %%
Ent=EtQ(P)
# Out:
# $\displaystyle E_t =- L g m + g h m + \frac{m v_{2}^{2}}{2}$

# %%
e1=e1Q(Ent-Wo)
# Out:
# $\displaystyle e1 =- L g m + g h m - g m \left(L - h\right) + \frac{m v_{2}^{2}}{2}$

# %%
e1.reduFac()
# Out:
# $\displaystyle e1 =- 4 L g + 4 g h + v_{2}^{2}$

# %%
V2=e1.solveR(v2,'V2')
# Out:
# $\displaystyle V2 =2 \sqrt{g \left(L - h\right)}$

# %%
 
P2=mparticle(v1=V2.ksym,v2=0,y1=h,y2=0,x1=L-h,x2=L)
fr=MyEq(Nm*mu,'fr',Pobj=P2,ktype='Ph')
P2.addF((m*g,-pi/2),(Nm,pi/2-alpha),(fr,pi-alpha))
# Out:
# $\displaystyle fr =\frac{\sqrt{2} g m \mu}{2}$

# %%
 
Frx2=FrxQ(P2,-alpha,kope='s')
# Out:
# $\displaystyle Frx =\frac{\sqrt{2} g m \left(1 - \mu\right)}{2}$

# %%
Wo2=MyEq(Frx2*h/sin(pi/4),'Wo2',Pobj=P2,ktype='Ph')
# Out:
# $\displaystyle Wo2 =g h m \left(1 - \mu\right)$

# %%
Ent2=EtQ(P2)
# Out:
# $\displaystyle E_t =- g h m - 2 g m \left(L - h\right)$

# %%
e2=e2Q(Ent2-Wo2)
# Out:
# $\displaystyle e2 =- g h m \left(1 - \mu\right) - g h m - 2 g m \left(L - h\right)$

# %%
h=e2.solve(h,'h')
# Out:
# $\displaystyle h =\frac{2 L}{\mu}$

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %% [markdown]
# ![p010.png](attachment:a2596691-eaf7-43d3-9257-40c140afc15d.png)

# %% [markdown]
# # Variable declared in lib_physic2 from Atb
# m,m1,m2,m3,m4,M,g,x,x1,x2,y,y1,y2,X,Y,a,a1,a2,a3,v,v1,v2, w,w1,w2,aw,aw1,aw2,
# F,F1,F2,Rx,Ry,r,r1,r2,R,ax,ay ,mu,mu1,mu2,fr,fr1,fr2,N1,N2,Nm, L,L1,L2,h,h1,h2,b,H
# alpha,tetha,ac,at,alpha1,alpha2,t,vx,vy,vxy,Po,Ti,I_n,a_w,Fc,a_c,a_t,aw,ax,ay,Io
# T,T1,T2,t1,t2,t3 ,K,X1,X2,X0,d,W,P ,mu,Nm,fr,alpha,L,h,x,y,R,rho,z,z1,z2,A,p=
# xo,yo,zo,beta ,yp,xp,pp

# %%
# Steep 1 : Creating sympy variables  Not neccesary but....
m,g,mu,N1,F1,fr,alpha=symbols('m g mu N1 F1 fr alpha') # mass. grav mu Normal Forza frozz

# %%
# Steep 2 : Creating physic object P 
P=mparticle()

# %% [markdown]
# ![p010a.png](attachment:84dd77b8-dc1a-40fa-bec3-d24cbe7e32d3.png)

# %%
# Steep 3 : 
# function P.add_forza(value,angle respect x axis, pos x , pos y) default  pos x and y = 0 
P.add_forza(m*g,-pi/2) # adding weight
P.add_forza(F1,0) # adding F1
P.add_forza(N1,pi/2) # adding N1
P.add_forza(fr,pi) # adding fr

# %% [markdown]
# ![add_forza.png](attachment:59b0805c-5438-4f37-8d71-860a4c7154dc.png)

# %%
# Steep 3 :  short way to add forzas 
# function P.addF = P.add_forza() but.....
P=mparticle()
P.addF((m*g,-pi/2),(F1,0), (N1,pi/2) ,(fr,pi) )

# %%
# Now our first basic function that we can applied 
# to this type physic problem...

# %%
# mparticle class have predeterminade value .. se bellow
# main value m=m, g=g
# Positio x1=x1 ,x2=x2,y1=y1,y2=y2, a=a(angle) r=r,r1=r1,r2=r2
# Velocity and accel (xy)   v1=v1,v2=v2,v=v,vx=vx,vy=vy,vxy=vxy ac=ac a_t=a_t,ax=ax,ay=ay
# Circular Vel and acc (w alpha)   w=w, aw=aw,w1=w1,w2=w2,
# Forza, Nor, Fr, Iner etc..   I_n=m*r*r, ,mu=mu, Nm=Nm etc...

# %% [markdown]
# ![PMechanic.png](attachment:7d21cbac-4614-4e0f-bfc1-d34508f6c5fd.png)

# %%
P.x_res() # get Summatory Forzas X like simple value:
# Out:
# F1 - fr

# %%
P.y_res() # get Summatory Forzas Y:
# Out:
# N1 - g*m

# %%
P.xy_res() # get Summatory Forzas in the sytem:
# Out:
# sqrt((F1 - fr)**2 + (N1 - g*m)**2)

# %%
P.simple_ac() # get acceleration in x ... F=m*a:
# Out:
# (F1 - fr)/m

# %%
P.simple_ac('y')  # get acceleration in y... F=m*a:
# Out:
# (N1 - g*m)/m

# %% [markdown]
# ![aa1.png](attachment:d9179db6-710d-446f-aa02-6d1923acbc3f.png)

# %% [markdown]
# ![aa2.png](attachment:bf051e9a-764b-4daf-9226-72fa832dcdc7.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
#  ![p020.png](attachment:c2916d27-6817-486b-878a-e2ffb5accddf.png)

# %%
from physic_lib2 import *

# %%
m,g,mu,fr,F=symbols('m g mu f_r F') # Creating physic object P
P=mparticle()

# %% [markdown]
# ### we will solve first symbilic and then applied data

# %%
# adding forzas
P.add_forza(m*g,-pi/2)  # weight  
P.add_forza(Nm,pi/2) # normal
P.add_forza(F,pi)  
P.add_forza(fr,0) # f rozz

# %%
P.x_res() # SFx=0
# Out:
# -F + f_r

# %%
P.y_res() # SFy=0
# Out:
# Nm - g*m

# %%
# we will take advenge from MyEq explained in Totorial No 000 and call superclassic sFx and sFy
Fx=FxQ(P)  # Fx= sum of all xForces and create Fx MyEq
Fy=FyQ(P)
# Out:
# $\displaystyle Fx =- F + f_{r}$
# $\displaystyle Fy =Nm - g m$

# %%
Nm=Fy.solve(Nm,'Nm')
Fx.set(fr,Nm*mu)
# Out:
# $\displaystyle Nm =g m$
# $\displaystyle Fx =- F + g m \mu$

# %%
F=Fx.solve(F,'F') # when MyEq.solve(var,  add a string then return a new MyEq else the valu
# Out:
# $\displaystyle F =g m \mu$

# %%
# changed value in F..??
F(m=20,g=10,mu=0.2)
# Out:
# 40.0000000000000

# %% [markdown]
# ![ToEq.png](attachment:194c9d4c-4cbf-4624-90e6-87ec04d883fe.png)

# %%
# maybe upper explanation is confused by for now follow my game... more advance explain

# %% [markdown]
# ![MyEq1.png](attachment:30993b62-da12-4b8c-bbff-cc09cddb0585.png)

# %%
# later I have a great solution

# %% [markdown]
# ![mess1.png](attachment:fccfbeb0-8e64-4ae7-89a8-b9f6ea0d5897.png)

# %%
# Ok now I have show you and  explain to you some graeat class usefull Equation algebrate func..

# %% [markdown]
# ![MyEq1.png](attachment:68a7da35-e40a-441e-a5d9-34985d1e115e.png)

# %%
# My dear crazyand and misunderstood genius  Friend ..  
# if  from now on and until the end of this notebook you understand 
# everything that I am going to explain, you will not have any problem understanding the rest 
# of course  you need know physics, Okkkkkkkkkkkkkkkkkk

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ## Working whit two Physic object

# %% [markdown]
# ![p030.png](attachment:cb818d1a-58af-4268-8868-b88a55f9a371.png)

# %%
from physic_lib2 import *

# %% [markdown]
# ![imagen.png](attachment:94d9202d-b1a3-42c1-87ae-64b197451e85.png)

# %%
# fisrt P2 because in P2 solve T1 and send to P1....
P2=mparticle()
P2.add_forza(m2*g,-pi/2)
P2.add_forza(T1,pi/2)
# two upper line will be replaced by... P2.add_forza((m2*g,-pi/2),(T1,pi/2)) ok...
Fy2=FyQ(P2)
# Out:
# $\displaystyle Fy =T_{1} - g m_{2}$

# %%
T1=Fy2.solve(T1,'T1')  # from Fy2  solve T1 and put T2 as name
# Out:
# $\displaystyle T1 =g m_{2}$

# %%
# Now P1
P1=mparticle()
P1.addF((m1*g,-pi/2),(N1,pi/2),(fr,pi),(T1,alpha))

# %%
Fy=FyQ(P1)
Fx=FxQ(P1)
# Out:
# $\displaystyle Fy =N_{1} - g m_{1} + g m_{2} \sin{\left(\alpha \right)}$
# $\displaystyle Fx =- fr + g m_{2} \cos{\left(\alpha \right)}$

# %%
# changuin fr in Fx with set..
Fx.set(fr,N1*mu)
# Out:
# $\displaystyle Fx =- N_{1} \mu + g m_{2} \cos{\left(\alpha \right)}$

# %%
# noe solve N1 and re puto in Fy... see how..
N1=Fx.solve(N1,'N1')
# Out:
# $\displaystyle N1 =\frac{g m_{2} \cos{\left(\alpha \right)}}{\mu}$

# %%
# Ok create again Fy to get new N1 value
Fy=FyQ(P1)
# Out:
# $\displaystyle Fy =- g m_{1} + g m_{2} \sin{\left(\alpha \right)} + \frac{g m_{2} \cos{\left(\alpha \right)}}{\mu}$

# %%
# finally...
mu=Fy.solve(mu,'mu')
# Out:
# $\displaystyle mu =\frac{m_{2} \cos{\left(\alpha \right)}}{m_{1} - m_{2} \sin{\left(\alpha \right)}}$

# %%
# testin  some values....
mu(m1=10,m2=3,alpha=pi/3)
# Out:
# 3/(20 - 3*sqrt(3))

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ## Working whit torque and adding forze whit x,y position neccesary for torque calculus

# %% [markdown]
# ![p040.png](attachment:e5e14786-609c-4624-9f31-b722b272a11d.png)

# %%
from physic_lib2 import *# run this to reset all variables

# %%
# decrared sympy variables neccesary '''  we ahve it  was declared but....
g,W,L,Rx,Ry =symbols('g W L Rx Ry ') # is better Rx+Ry instead R because ww not know  alpha

# %%
# Creating physic object P  
P=mparticle()

# %%
# adding forza.. this time we will includedd x,y cordinate posss  B is (0,0)
P.addF((Rx,0,0,0),(Ry,pi/2,0,0),(2*W,pi/6,L/4,0),(500,-pi/2,L/2,0),(W,pi/2,L,0))

# %% [markdown]
# ![ToEq.png](attachment:d896a45e-f276-4373-99e3-cfabb171ee95.png)

# %%
# take note that Fx answer.. later you will know why..
Fx=FxQ(P)
# Out:
# $\displaystyle Fx =Rx + \sqrt{3} W$

# %%
To=ToQ(P) # Torque in (0,0)
# Out:
# $\displaystyle To =- \frac{5 L W}{4} + 250 L$

# %%
W=To.solve(W,'W')
# Out:
# $\displaystyle W =200$

# %%
# see now upfate Fx.  when we solve some variable that depend P try to change all
Fx=FxQ(P)
# Out:
# $\displaystyle Fx =Rx + 200 \sqrt{3}$

# %%
Rx=Fx.solve(Rx,'Rx')
# Out:
# $\displaystyle Rx =- 200 \sqrt{3}$

# %%
Fy=FyQ(P)
# Out:
# $\displaystyle Fy =Ry - 100$

# %%
Rx=Fy.solve(Ry,'Ry')
# Out:
# $\displaystyle Ry =100$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
#  again

# %% [markdown]
# ![aa2.png](attachment:dff2bedb-de11-4400-a6a6-2c236b29645c.png)

# %% [markdown]
#  ![line.png](attachment:bab74f7c-ed56-4f3d-a005-4595cf8b00bd.png)

# %% [markdown]
# ## More torque super easy sample... more advance come real nerd problems solve

# %% [markdown]
# ![p050.png](attachment:8530bde1-25bc-4fa3-88a9-7ec9492e5927.png)

# %%
from physic_lib2 import *

# %%
# declared sympy variables neccesary
b,R1,R2 =symbols('b R1 R2') # is better Rx+Ry instead R because ww not know  alpha

# %%
# Creating physic object P  
P=mparticle()

# %% [markdown]
# ![p050.png](attachment:58e080b7-067c-4d26-b044-5789fc5ad37d.png)

# %%
# adding forza.. this time we will includedd x,y cordinate posss  B is (0,0)
P.addF((R1,pi/2,0,0),(3*10,-pi/2,b,0),(6*10,-pi/2,2*b,0),(R2,pi/2,3*b,0))

# %%
# find R2 using MyEq Torque = 0 in A
ToA=ToQ(P) # default Name is 'To' but now we need applied torquer in two point..see bellow
# Out:
# $\displaystyle To =- 3 R_{2} b + 150 b$

# %%
R2=ToA.solve(R2,'R2')
# Out:
# $\displaystyle R2 =50$

# %%
ToB=MyEq(P.torque(3*b,0),'ToB')  # also torque in B equal cero
# Out:
# $\displaystyle ToB =- 3 R_{1} b + 120 b$

# %%
R1=ToB.solve(R1,'R1')
# Out:
# $\displaystyle R1 =40$

# %% [markdown]
#  ![line.png](attachment:712d3bef-e50c-4a7c-8cf0-e821b5deacd5.png)

# %% [markdown]
# ## working whit acceleration

# %%
# before we will try to understand mparticle()  class.....

# %% [markdown]
# ![p06b.png](attachment:f5f61532-f6bc-47d4-b3b4-63456420a3ec.png)

# %% [markdown]
# ![p06a.png](attachment:c8f23e8e-4d22-45a5-b2bc-7e97638c1901.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
# first declaring variable
F1,m,g=symbols('F1 m g',positive=True)
# In advance we will include positive True in order to solve root equations 
# also is better use F1 because F is used in several libraries...

# %%
P=mparticle(m=m) # now we declaring internal mass for used in other algoritm

# %%
P.add_forza(F1,0)
# see ress x
P.x_res()
# Out:
# F1

# %%
# Finding acceleration
P.simple_ac()
# Out:
# F1/m

# %% [markdown]
# ![line.png](attachment:45701cc5-f726-4d8e-9794-91655efa6529.png)

# %% [markdown]
# #### Finding default acceleration into Physic mparticle object class()...

# %% [markdown]
# ![p060.png](attachment:2dc62571-f14f-4de1-a2f0-5c5b73e2816b.png)

# %%
# first declaring al  variable including Normals and F reaction between mass

# %% [markdown]
# ![p061.png](attachment:541a4414-14b8-442d-9aa9-35cb935f2361.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %% [markdown]
# ![imagen.png](attachment:e9a6b102-56da-4a6c-873d-a3ca44bc79f5.png)

# %%
# fr1 solution
fr1=MyEq(4*m*g*mu,'fr1')
# Out:
# $\displaystyle fr1 =4 g m \mu$

# %%
# fr2 solution
fr2=MyEq(m*g*mu,'fr2')
# Out:
# $\displaystyle fr2 =g m \mu$

# %%
# solve without mparticle  only simple addin , substrac..etc Eq...
e1=e1Q(F1-fr1-R-4*m*a)# Fx=Mass*AccX.. in MyEq an sympy  Fx-Nass*Accx is the nomeclatu...
# Out:
# $\displaystyle e1 =- F_{1} - R - 4 a m + 4 g m \mu$

# %%
R=e1.solve(R,'R')
# Out:
# $\displaystyle R =- F_{1} - 4 a m + 4 g m \mu$

# %%
e2=e2Q(R-fr2-m*a)
# Out:
# $\displaystyle e2 =- F_{1} - 5 a m + 3 g m \mu$

# %%
a=e2.solve(a,'a')
# Out:
# $\displaystyle a =\frac{- F_{1} + 3 g m \mu}{5 m}$

# %% [markdown]
#  ![line.png](attachment:38b560be-acbc-444a-a236-500b3be97bbe.png)

# %%
# I   a feeling that you want something more complicated because te esta picando el * .see

# %% [markdown]
# ![E800.png](attachment:18392616-9ccc-43c4-bc90-0745662b9bba.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
L,M,m,h,N1,fr,mu,F1,Rx,Ry,g,a  =symbols('L M m h N1 fr mu F1 Rx Ry g a')

# %% [markdown]
# ![add_f.png](attachment:7fb1573b-caa4-4ac8-8078-79782e229637.png)

# %% [markdown]
# ![E800a.png](attachment:d1d2861d-4966-4e30-9ee8-8cd34e26c0eb.png)

# %%
P=mparticle()

# %%
# adding Rx Ry
P.add_forza(Rx,0) # default x=0, y=0
P.add_forza(Ry,pi/2) # default x=0, y=0

# %%
# adding F1, distance from (0,0)= a/4,angle dis= pi/6, angle F1 with Radio = pi/2
P.add_geoforza(F1,L/2,pi/6,pi/2)

# %% [markdown]
# ![hipo.png](attachment:1424a57f-1298-45d4-8dc2-4ecdd34774fd.png)

# %%
# add weight 
Rc=MyEq(get_hipo(L/2,L/2),'Rc')
# Out:
# $\displaystyle Rc =\frac{\sqrt{2} \sqrt{L^{2}}}{2}$

# %%
# humm  somethin is bad... haa ok again
Rc=MyEq(get_hipo(L/2,L/2),'Rc',kope='r')
# Out:
# $\displaystyle Rc =\frac{\sqrt{2} L}{2}$

# %%
# angle Rc with x axis   = aa
aa=pi/6+pi/4

# %%
# angle M with Rc axis   = -aa-pi/2.. then
P.add_geoforza(M*g,L*rpow(2,2)/2,aa,-aa-pi/2)

# %%
To=ToQ(P)
# Out:
# $\displaystyle To =\frac{F_{1} L}{2} - \frac{\sqrt{2} L M g \left(- \frac{\sqrt{2}}{4} + \frac{\sqrt{6}}{4}\right)}{2}$

# %%
F1=To.solve(F1,'F1')
# Out:
# $\displaystyle F1 =\frac{M g \left(-1 + \sqrt{3}\right)}{2}$

# %%
Fy=FyQ(P)
Fx=FxQ(P)
# Out:
# $\displaystyle Fy =- M g + \frac{\sqrt{3} M g \left(-1 + \sqrt{3}\right)}{4} + Ry$
# $\displaystyle Fx =- \frac{M g \left(-1 + \sqrt{3}\right)}{4} + Rx$

# %%
Rx=Fx.solve(Rx,'Rx')
Ry=Fy.solve(Ry,'Ry')
# Out:
# $\displaystyle Rx =\frac{M g \left(-1 + \sqrt{3}\right)}{4}$
# $\displaystyle Ry =\frac{M g \left(1 + \sqrt{3}\right)}{4}$

# %% [markdown]
# ![line.png](attachment:780cf68b-4f54-492b-93ed-11fd0e92482b.png)

# %% [markdown]
# ![E800.png](attachment:982785f9-436c-4eab-b36b-e4005e89cb77.png)

# %% [markdown]
# ![imagen.png](attachment:8f931a18-34d2-4ece-91f3-cb81d8074ec7.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
L=get_hipo(a/2,a/2,kope='r');L
# Out:
# sqrt(2)*a/2

# %%
alpha=pi/6+pi/4;alpha
# Out:
# 5*pi/12

# %%
P1=mparticle()
P1.add_geoforza(Rx,a/2,pi/6,pi-pi/6)
P1.add_geoforza(Ry,a/2,pi/6,pi/6)
P1.add_geoforza(M*g,L,alpha,-pi/2-alpha)

# %%
Fy=FyQ(P1,kope='s')
# Out:
# $\displaystyle Fy =- M g + \frac{\sqrt{3} R_{y}}{2}$

# %%
Fx=FxQ(P1,kope='s')
# Out:
# $\displaystyle Fx =- R_{x} + \frac{R_{y}}{2}$

# %%
P2=mparticle()
P2.addF((Rx,0),(Ry,-pi/2),(m*g,-pi/2),(fr,pi),(Nm,pi/2))

# %%
Fy2=FyQ(P2)
# Out:
# $\displaystyle Fy =Nm - R_{y} - g m$

# %%
Nm=Fy2.solve(Nm,'Nm')
# Out:
# $\displaystyle Nm =R_{y} + g m$

# %%
Fx2=FxQ(P2,'Fx2')
# Out:
# $\displaystyle Fx2 =R_{x} - fr$

# %%
Fx2.set(fr,Nm*mu)
# Out:
# $\displaystyle Fx2 =R_{x} - \mu \left(R_{y} + g m\right)$

# %%
mu=Fx2.solve(mu,'mu')
# Out:
# $\displaystyle mu =\frac{R_{x}}{R_{y} + g m}$

# %%
#  EASY FOR YOU.... yes you right.. 
#  a little sample that what comes later

# %% [markdown]
# ![line.png](attachment:780cf68b-4f54-492b-93ed-11fd0e92482b.png)

# %% [markdown]
# ![imagen.png](attachment:817e226a-efc2-49b9-87a0-2315b4976744.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
alpha=pi/4
P=mparticle(v1=0,y1=L,y2=h,x1=0,x2=L-h)
P.addF((m*g,-pi/2),(Nm,pi/2-alpha))

# %%
Fry=FryQ(P,-alpha,kope='s')
# Out:
# $\displaystyle Fry =Nm - \frac{\sqrt{2} g m}{2}$

# %%
Nm=Fry.solve(Nm,'Nm')
# Out:
# $\displaystyle Nm =\frac{\sqrt{2} g m}{2}$

# %%
Frx=FrxQ(P,-alpha,kope='s')
# Out:
# $\displaystyle Frx =\frac{\sqrt{2} g m}{2}$

# %%
(L-h)/sin(pi/4)
# Out:
# sqrt(2)*(L - h)

# %%
Wo=MyEq(Frx*(L-h)/sin(pi/4),'Wo',Pobj=P,ktype='Ph')
# Out:
# $\displaystyle Wo =g m \left(L - h\right)$

# %%
Ent=EtQ(P)
# Out:
# $\displaystyle E_t =- L g m + g h m + \frac{m v_{2}^{2}}{2}$

# %%
e1=e1Q(Ent-Wo)
# Out:
# $\displaystyle e1 =- L g m + g h m - g m \left(L - h\right) + \frac{m v_{2}^{2}}{2}$

# %%
e1.reduFac()
# Out:
# $\displaystyle e1 =- 4 L g + 4 g h + v_{2}^{2}$

# %%
V2=e1.solveR(v2,'V2')
# Out:
# $\displaystyle V2 =2 \sqrt{g \left(L - h\right)}$

# %%
 
P2=mparticle(v1=V2.ksym,v2=0,y1=h,y2=0,x1=L-h,x2=L)
fr=MyEq(Nm*mu,'fr',Pobj=P2,ktype='Ph')
P2.addF((m*g,-pi/2),(Nm,pi/2-alpha),(fr,pi-alpha))
# Out:
# $\displaystyle fr =\frac{\sqrt{2} g m \mu}{2}$

# %%
 
Frx2=FrxQ(P2,-alpha,kope='s')
# Out:
# $\displaystyle Frx =\frac{\sqrt{2} g m \left(1 - \mu\right)}{2}$

# %%
Wo2=MyEq(Frx2*h/sin(pi/4),'Wo2',Pobj=P2,ktype='Ph')
# Out:
# $\displaystyle Wo2 =g h m \left(1 - \mu\right)$

# %%
Ent2=EtQ(P2)
# Out:
# $\displaystyle E_t =- g h m - 2 g m \left(L - h\right)$

# %%
e2=e2Q(Ent2-Wo2)
# Out:
# $\displaystyle e2 =- g h m \left(1 - \mu\right) - g h m - 2 g m \left(L - h\right)$

# %%
h=e2.solve(h,'h')
# Out:
# $\displaystyle h =\frac{2 L}{\mu}$

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *
from lib_Mechanics import *
