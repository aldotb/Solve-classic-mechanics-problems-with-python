# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:a94c3a17-686f-4da4-9745-b7a280c60375.png)

# %%
from Libaldomath import *

# %%
T=mparticle(x1=0,x2=L,ac=0,a=0,v1=v)

# %%
Q1=MQ(T.xpos(8),L)
Q2=MQ(T.xpos(48),L+160)
# Out:
# $\displaystyle 8 v_{1} = L$
# $\displaystyle 48 v_{1} = L + 160$

# %%
Q2.Substrac(Q1)
# Out:
# $\displaystyle 40 v_{1} = 160$

# %%
Q2.alone(v1) # see my other repository yo understan MyEq or MQ....
# Out:
# $\displaystyle v_{1} = 4$

# %%
Q1(v1=4)
# Out:
# $\displaystyle 32 = L$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:c26ab47d-7825-4e54-81c5-02d14b90f86e.png)

# %%
from Libaldomath import *

# %%
A=mparticle(v1=V,x1=0)
B=mparticle(v1=2*V,x1=0)
C=mparticle(v1=-3*V/2,x1=900)

# %% [markdown]
# ![image.png](attachment:96763cee-56ad-432a-b7e9-d7e62c7028b2.png)

# %%
Q1=MQ(B.xpos(10),(A.xpos(10)+C.xpos(10))/2)
# Out:
# $\displaystyle 20 V = 450 - \frac{5 V}{2}$

# %%
Q1.alone(V)
# Out:
# $\displaystyle V = 20$

# %% [markdown]
# # ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:bcca1cdc-a2bf-41e7-9ca0-99dc6048553a.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:582d9982-b293-4724-a23d-3e35a074f9bc.png)

# %%
P=mparticle(x1=0,x2=1000,v1=V,v2=3*V,ac=ac)

# %%
Q1=MQ(P.xpos(10),1000)
# Out:
# $\displaystyle 20 V = 1000$

# %%
Q1.alone(V)
# Out:
# $\displaystyle V = 50$

# %%
V=simplesolve(P.xpos(10)-1000)
# Out:
# $\displaystyle V =50$

# %%
P.xacel(V=50)
# Out:
# 10

# %%
P=mparticle(x1=0,v1=0,v2=50,ac=10)

# %%
Q2=MQ(P.xvel(t),50)
# Out:
# $\displaystyle 10 t = 50$

# %%
Q2.alone(t)
# Out:
# $\displaystyle t = 5$

# %%
P.xpos(5)
# Out:
# 125.000000000000

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:71ee3f0c-243d-4de9-888a-6256e7d4fde7.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:1983cd5b-049a-4d82-adfa-64c13d9a7947.png)

# %%
P=mparticle(g=10,a=pi/2,y1=0,v1=V)

# %%
Q1=MQ(P.ypos(T),H/2) # equation 1
# Out:
# $\displaystyle 5 T^{2} + T V = \frac{H}{2}$

# %%
Q2=MQ(P.yvel(T),10*sqrt(2)) # equation 2
# Out:
# $\displaystyle 10 T + V = 10 \sqrt{2}$

# %%
Q3=MQ(P.ymax(),H) # equation 2
# Out:
# $\displaystyle \frac{V^{2}}{20} = H$

# %%
H1,T1,V1,H2,T2,H2=simplesolve(Q1,Q2,Q3) # again see my Algebra repository.....
# Out:
# $\displaystyle H1 =\frac{20}{3}$
# $\displaystyle T1 =- \frac{2 \sqrt{3}}{3} + \sqrt{2}$
# $\displaystyle V1 =\frac{20 \sqrt{3}}{3}$
# $\displaystyle H2 =\frac{20}{3}$
# $\displaystyle T2 =\frac{2 \sqrt{3}}{3} + \sqrt{2}$
# $\displaystyle V2 =- \frac{20 \sqrt{3}}{3}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:c5c300a1-f295-402d-b278-b80d1d02148e.png)

# %%
from Libaldomath import *

# %%
A=mparticle(v1=0,a=pi/2,y1=H,g=10)
B=mparticle(v1=-4,a=pi/2,y1=H+7,g=10)

# %% [markdown]
# ![image.png](attachment:6d925fb6-0aea-4e74-8202-339bc73eff8a.png)

# %%
t=simplesolve(B.ypos()-A.ypos()-3)
# Out:
# $\displaystyle t =1$

# %% [markdown]
# ![image.png](attachment:72146ff3-3172-4383-89a5-6e88e3d99a10.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:613bcd8f-2412-4b2e-9057-8bb87ad1f0f6.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:884af1e5-0ec1-4dc8-9b3d-52bd410cab6f.png)

# %%
A=mparticle(y1=60,g=-10,a=pi/2,v1=V)

# %%
V,t=simplesolve(A.ypos()-35,A.yvel()+3*V/2,positive='t')
# Out:
# $\displaystyle V =20$
# $\displaystyle t =5$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:613bcd8f-2412-4b2e-9057-8bb87ad1f0f6.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:e4b0ad49-4045-41d4-9c4a-fc10f0e5a47e.png)

# %%
A=mparticle(x1=0,y1=0,v1=30,a=pi/2,g=0)

# %%
B=mparticle(x1=10,y1=0,v1=20,g=0,a=pi-pi/6)

# %%
P1=Point2D(A.xpos(),A.ypos())

# %%
P2=Point2D(B.xpos(),B.ypos())

# %%
L=MyEq(P1.distance(P2),'L',var=t) # MyEq is a class to total mange equation type expr(expr) = 0
                                 #  L= MyEq(mat expr,'name',var=(default x))
# Out:
# $\displaystyle L =\sqrt{400 t^{2} + \left(10 \sqrt{3} t - 10\right)^{2}}$

# %%
L.simplify()
# Out:
# $\displaystyle L =10 \sqrt{4 t^{2} + \left(\sqrt{3} t - 1\right)^{2}}$

# %%
dL=L.diff('dL')
# Out:
# $\displaystyle dL =\frac{10 \cdot \left(4 t + \sqrt{3} \left(\sqrt{3} t - 1\right)\right)}{\sqrt{4 t^{2} + \left(\sqrt{3} t - 1\right)^{2}}}$

# %%
dL.reducecero()
# Out:
# $\displaystyle dL =7 t - \sqrt{3}$

# %%
dL.solve(t)
# Out:
# √3
# ──
# 7

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:e781f0d4-c34e-4db3-9ac3-f78300d18f43.png)

# %%
from Libaldomath import *

# %%
P=mparticle(x1=0,y1=200,y2=0,v1=10,ac=-0.5,g=9.8,a=-pi/6)

# %%
t1=P.tfly()
t1
# Out:
# 5.89890152956825

# %%
P.xpos(t1,'float')
# Out:
# 42.38672597640419

# %%
P.xvel(t1,'float')
# Out:
# 5.710803273060263

# %%
P.yvel(t1,'float')
# Out:
# 52.80923498976883

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ## A body is thrown upward, in a vertical direction, with an initial speed of 98 m/s from the roof of a building 100 m high. Take g=9.8 m/s2. Find:
#
#     The maximum height that the body reaches measured from the ground
#     The time it takes until it reaches the ground.
#     The speed upon reaching the ground

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody(y1=100,g=9.8,v1=98,ang=pi/2,y2=0)

# %%
P.ymax()
# Out:
# 590

# %%
P.ypos()
# Out:
#        2
# - 4.9⋅t  + 98⋅t + 100

# %%
P.tfly()
# Out:
# 20.9730653540980

# %%
P.yvel(20.9)
# Out:
# -106.820000000000

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)
