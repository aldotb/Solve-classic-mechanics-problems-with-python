# %%
import sys
sys.path.insert(0, 'C:/Libaldo/')
from Libaldomath import *
from lib_MyVector import *

# %% [markdown]
# ![imagen.png](attachment:97e26c59-f828-4303-8162-a3e265496a3e.png)

# %%
x1=symbols('x1', positive=True)

# %%
A=MyVector(x1,0,0)

# %%
B=A.rotate(alpha)

# %%
R=MyEq(cf((A+B).module,(A-B).module),'R')
# Out:
# $\displaystyle R = \frac{\sqrt{x_{1}^{2} \sin^{2}{\left(\alpha \right)} + \left(x_{1} \cos{\left(\alpha \right)} + x_{1}\right)^{2}}}{\sqrt{x_{1}^{2} \sin^{2}{\left(\alpha \right)} + \left(- x_{1} \cos{\left(\alpha \right)} + x_{1}\right)^{2}}}$

# %%
R.expand()
# Out:
# $\displaystyle R = \frac{\sqrt{x_{1}^{2} \sin^{2}{\left(\alpha \right)} + x_{1}^{2} \cos^{2}{\left(\alpha \right)} + 2 x_{1}^{2} \cos{\left(\alpha \right)} + x_{1}^{2}}}{\sqrt{x_{1}^{2} \sin^{2}{\left(\alpha \right)} + x_{1}^{2} \cos^{2}{\left(\alpha \right)} - 2 x_{1}^{2} \cos{\left(\alpha \right)} + x_{1}^{2}}}$

# %%
R.simplify()
# Out:
# $\displaystyle R = \frac{\sqrt{\cos{\left(\alpha \right)} + 1}}{\sqrt{1 - \cos{\left(\alpha \right)}}}$

# %%
R.Rationalize(1+cos(alpha))
# Out:
# $\displaystyle R = \frac{\cos{\left(\alpha \right)} + 1}{\sin{\left(\alpha \right)}}$

# %%
beta=symbols('beta')
R.set(alpha,2*beta)
# Out:
# $\displaystyle R = \frac{\cos{\left(2 \beta \right)} + 1}{\sin{\left(2 \beta \right)}}$

# %%
R.texpand()
# Out:
# $\displaystyle R = \frac{\cos{\left(\beta \right)}}{\sin{\left(\beta \right)}}$

# %%
R.tsimplify()
# Out:
# $\displaystyle R = \frac{1}{\tan{\left(\beta \right)}}$

# %% [markdown]
# ![imagen.png](attachment:8caa78ce-ca1f-406a-b3e4-a27f0f8a7ab3.png)

# %%
import sys
sys.path.insert(0, 'C:/Libaldo/')
from Libaldomath import *
from lib_MyVector import *

# %% [markdown]
# ![imagen.png](attachment:1ec32d04-d3f8-47ec-91a6-45d05a4b37b6.png)

# %%
V1=MyVector(dire=(-2,-1,0),F=5*sqrt(5))
V2=MyVector(dire=(0,1,0),F=15) 
V3=MyVector(dire=(-4,3,0),F=50) 
V4=MyVector(dire=(2,2,0),F=80*sqrt(2))

# %%
simplify((V1+V2+V3+V4).module)
# Out:
# 30*sqrt(17)

# %% [markdown]
# ![imagen.png](attachment:8caa78ce-ca1f-406a-b3e4-a27f0f8a7ab3.png)

# %%
import sys
sys.path.insert(0, 'C:/Libaldo/')
from Libaldomath import *
from lib_MyVector import *

# %% [markdown]
# ![imagen.png](attachment:eb691588-894a-4540-9aeb-44da3b0d403b.png)

# %%
def solvevector(vector,*args):
    vec1=[vector.components[i] for i in range(3)]
    for data in args:
        vec1.append(data)
    return simplesolve(*vec1)

# %%
alpha=atan(cf(1,3))
P=MyVector(3,0,0)
S=MyVector(s*sin(alpha),s*cos(alpha),0) 
q=2*sqrt(10)
Q=MyVector(-q*cos(alpha),-q*sin(alpha),0)

# %%
vector.components[0]
# Out:
# 3*m - sqrt(10)*n*s/10 - 18

# %%
e1=MyEq(vector.components[1],'e1')
# Out:
# $\displaystyle e1 = - \frac{3 \sqrt{10} n s}{10} - 6$

# %%
e1.solve(n*s)
# Out:
# -2*sqrt(10)

# %%
e2=MyEq(vector.components[0],'e2')
# Out:
# $\displaystyle e2 = 3 m - \frac{\sqrt{10} n s}{10} - 18$

# %%
e2.set(n*s,-2*sqrt(10))
# Out:
# $\displaystyle e2 = 3 m - 16$

# %%
m=e2.solve('m')
# Out:
# $\displaystyle m = \frac{16}{3}$

# %% [markdown]
# ![imagen.png](attachment:8caa78ce-ca1f-406a-b3e4-a27f0f8a7ab3.png)

# %%
import sys
sys.path.insert(0, 'C:/Libaldo/')
from Libaldomath import *
from lib_MyVector import *

# %% [markdown]
# ![imagen.png](attachment:a52f37b6-81a6-4059-b094-8a81744dedc2.png)

# %%
A=MyVector(0,-L,L)
B=MyVector(-L,-L,L)

# %%
cf(rsimplify((A+B).module),rsimplify((A-B).module))
# Out:
# 3

# %% [markdown]
# ![imagen.png](attachment:8caa78ce-ca1f-406a-b3e4-a27f0f8a7ab3.png)

# %%
import sys
sys.path.insert(0, 'C:/Libaldo/')
from Libaldomath import *
from lib_MyVector import *

# %% [markdown]
# ![imagen.png](attachment:8215de03-1d29-40d5-b6b8-83e23d459a2b.png)

# %%
A=MyVector(2,-4,-1)
B=MyVector(0,2,8)

# %%
C=A.cross(B)

# %%
C.s()
# Out:
# $\displaystyle \left( -30, \  -16, \  4\right)$

# %%
C.unit_vector.s()
# Out:
# $\displaystyle \left( - \frac{15 \sqrt{293}}{293}, \  - \frac{8 \sqrt{293}}{293}, \  \frac{2 \sqrt{293}}{293}\right)$
