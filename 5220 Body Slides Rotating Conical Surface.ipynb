# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
# mu=0

# %% [markdown]
# ![image.png](attachment:5b53b83f-b31d-4b90-a1b3-3017eb77d4f0.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody()
x1=x*cos(alpha)
y1=x*sin(alpha)

# %%
P.add_forza(m*g,-pi/2,x1,y1)
P.add_forza(N1,alpha+pi/2,x1,y1)

# %%
Fy=P.Fy()
# Out:
# $\displaystyle Fy =N_{1} \cos{\left(\alpha \right)} - g m$

# %%
eR=P.eQmovradial()
# Out:
# $\displaystyle - m r w^{2} = - N_{1} \sin{\left(\alpha \right)}$

# %%
eR.simplify()
# Out:
# $\displaystyle m r w^{2} = N_{1} \sin{\left(\alpha \right)}$

# %%
eR.set(r=x1)
# Out:
# $\displaystyle m w^{2} x \cos{\left(\alpha \right)} = N_{1} \sin{\left(\alpha \right)}$

# %%
eR.set(N1=Fy.solve(N1))
# Out:
# $\displaystyle m w^{2} x \cos{\left(\alpha \right)} = \frac{g m \sin{\left(\alpha \right)}}{\cos{\left(\alpha \right)}}$

# %%
eR.alone(x)
# Out:
# $\displaystyle x = \frac{g \sin{\left(\alpha \right)}}{w^{2} \cos^{2}{\left(\alpha \right)}}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
# mu != 0

# %% [markdown]
# ![image.png](attachment:aed01f58-008b-4fd8-ac75-af16acb1929d.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody()
x1=x*cos(alpha)
y1=x*sin(alpha)

# %%
P.add_forza(m*g,-pi/2,x1,y1)
P.add_forza(N1,alpha+pi/2,x1,y1)
P.add_forza(fr,alpha+pi,x1,y1)

# %%
Fy=P.Fy()
# Out:
# $\displaystyle Fy =N_{1} \cos{\left(\alpha \right)} - f_{r} \sin{\left(\alpha \right)} - g m$

# %%
P.set(fr,N1*mu)

# %%
Fy=P.Fy()
# Out:
# $\displaystyle Fy =- N_{1} \mu \sin{\left(\alpha \right)} + N_{1} \cos{\left(\alpha \right)} - g m$

# %%
eR=P.eQmovradial()
# Out:
# $\displaystyle - m r w^{2} = - N_{1} \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)$

# %%
eR.simplify()
# Out:
# $\displaystyle r w^{2} = \frac{N_{1} \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{m}$

# %%
eR.set(r=x1)
# Out:
# $\displaystyle w^{2} x \cos{\left(\alpha \right)} = \frac{N_{1} \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{m}$

# %%
eR.set(N1=Fy.solve(N1))
# Out:
# $\displaystyle w^{2} x \cos{\left(\alpha \right)} = \frac{g \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{- \mu \sin{\left(\alpha \right)} + \cos{\left(\alpha \right)}}$

# %%
eR.alone(x)
# Out:
# $\displaystyle x = \frac{2 g \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{w^{2} \left(- \mu \sin{\left(2 \alpha \right)} + \cos{\left(2 \alpha \right)} + 1\right)}$

# %%
eR.texpand()
# Out:
# $\displaystyle x = \frac{2 g \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{w^{2} \left(- 2 \mu \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} + 2 \cos^{2}{\left(\alpha \right)}\right)}$

# %%
eR.subs((cos(alpha))**2,(1-sin(alpha)**2))
# Out:
# $\displaystyle x = \frac{2 g \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{w^{2} \left(- 2 \mu \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} - 2 \sin^{2}{\left(\alpha \right)} + 2\right)}$

# %%
eR.factor()
# Out:
# $\displaystyle x = - \frac{g \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{w^{2} \left(\mu \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} + \sin^{2}{\left(\alpha \right)} - 1\right)}$

# %%
eR.subs((sin(alpha))**2,(1-cos(alpha)**2))
# Out:
# $\displaystyle x = - \frac{g \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{w^{2} \left(\mu \sin{\left(\alpha \right)} \cos{\left(\alpha \right)} - \cos^{2}{\left(\alpha \right)}\right)}$

# %%
eR.factor()
# Out:
# $\displaystyle x = \frac{g \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{w^{2} \left(- \mu \sin{\left(\alpha \right)} + \cos{\left(\alpha \right)}\right) \cos{\left(\alpha \right)}}$

# %%
Fxy=P.fxrelative(alpha,'Fxy')
# Out:
# $\displaystyle Fxy =- N_{1} \mu - g m \sin{\left(\alpha \right)}$

# %%
Fxy.set(N1=Fy.solve(N1))
# Out:
# $\displaystyle Fxy =- \frac{g m \mu}{- \mu \sin{\left(\alpha \right)} + \cos{\left(\alpha \right)}} - g m \sin{\left(\alpha \right)}$
