# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:a83c9682-cea9-4d13-bb59-975df2bf1d68.png)

# %%
# MQ(eqution1,equation2).. create.. equation1=equation2 ,,,
Q1=MQ(m1*a,T1)
Q2=MQ(m2*a,T2-T1)
Q3=MQ(m3*a,F-T2)
# Out:
# $\displaystyle a m_{1} = T_{1}$
# $\displaystyle a m_{2} = - T_{1} + T_{2}$
# $\displaystyle a m_{3} = F - T_{2}$

# %%
# simplesolve try to solve possible vrariables from parameters enter 
# parameters can be.. expretion hta is equal to cero maby...m1*a-T1, or type MyEq or type MQ
# if not include wich variable we can get.. try to solve all but 
# you know what happend if solve more variable that number of eq.... see below..
simplesolve(Q1,Q2,Q3)
# Out:
# $\displaystyle m1 =m_{1}$
# $\displaystyle a =a$
# $\displaystyle T1 =a m_{1}$
# $\displaystyle m2 =m_{2}$
# $\displaystyle T2 =a \left(m_{1} + m_{2}\right)$
# $\displaystyle m3 =m_{3}$
# $\displaystyle F =a \left(m_{1} + m_{2} + m_{3}\right)$
# [m1, a, a*m1, m2, a*(m1 + m2), m3, a*(m1 + m2 + m3)]

# %%
# sinplesolve.. whit 3 input.. and get 3 output solutions.. see correct form...
T1,T2,a=simplesolve(Q1,Q2,Q3,T1,T2,a)
# Out:
# $\displaystyle T1 =\frac{F m_{1}}{m_{1} + m_{2} + m_{3}}$
# $\displaystyle T2 =\frac{F m_{1} + F m_{2}}{m_{1} + m_{2} + m_{3}}$
# $\displaystyle a =\frac{F}{m_{1} + m_{2} + m_{3}}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:fef9bb79-9275-4e14-ab8f-ab5cbd57f37c.png)

# %%
Q1=MQ(m1*a,fr)
Q2=MQ(fr,m1*g*mu)
Q3=MQ(m2*a,F-fr)
# Out:
# $\displaystyle a m_{1} = f_{r}$
# $\displaystyle f_{r} = g m_{1} \mu$
# $\displaystyle a m_{2} = F - f_{r}$

# %%
a,fr,F=simplesolve(Q1,Q2,Q3,a,fr,F)
# Out:
# $\displaystyle a =g m_{1} \mu + g m_{2} \mu$
# $\displaystyle f_r =g \mu$
# $\displaystyle F =g m_{1} \mu$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:dfdeeee6-b82c-40d9-a4c8-15098cdaec66.png)

# %%
P=mparticle()
P.add_forza(m*g,-pi/2)
P.add_forza(F,alpha)
P.add_forza(N1,pi/2)
P.add_forza(fr,pi)

# %%
Fy=P.Fy()
# Out:
# $\displaystyle Fy =F \sin{\left(\alpha \right)} + N_{1} - g m$

# %%
# a)
N1=Fy.solve(N1)
# Out:
# $\displaystyle N1 =- F \sin{\left(\alpha \right)} + g m$

# %%
Fx=P.Fx()
# Out:
# $\displaystyle Fx =F \cos{\left(\alpha \right)} - f_{r}$

# %%
Fx.subs(fr,N1*mu)
# Out:
# $\displaystyle Fx =F \cos{\left(\alpha \right)} - \mu \left(- F \sin{\left(\alpha \right)} + g m\right)$

# %%
Q1=MQ(m*a,Fx)
# Out:
# $\displaystyle a m = F \cos{\left(\alpha \right)} - \mu \left(- F \sin{\left(\alpha \right)} + g m\right)$

# %%
a=Q1.solve(a)
# Out:
# $\displaystyle a =\frac{F \mu \sin{\left(\alpha \right)} + F \cos{\left(\alpha \right)} - g m \mu}{m}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:edc4c75c-bb88-4a89-abff-a4895b106f21.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![image.png](attachment:9e6b4a0a-b251-4f1d-bbdf-5f6284de0d7f.png)

# %%
P=mparticle()

# %%
P.add_forza(F,alpha)
P.add_forza(N1,alpha+pi/2)
P.add_forza(m*g,-pi/2)

# %%
Fr=P.Fx_relative(alpha,'Fr')
# Out:
# $\displaystyle Fr =F - g m \sin{\left(\alpha \right)}$

# %%
F=Fr.solve('F',g=10,m=10)
# Out:
# $\displaystyle F =100 \sin{\left(\alpha \right)}$

# %%
F=Fx.solve('F')
# Out:
# $\displaystyle F =100 \sin{\left(\alpha \right)}$

# %%
F(alpha=asin(cfrac(6,9)))
# Out:
#     6
# 100⋅─
#     9

# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)
