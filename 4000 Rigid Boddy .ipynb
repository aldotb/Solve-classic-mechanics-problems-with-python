# %%
from Libaldomath import *

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:e3ef3083-5873-41e4-9bf2-57e9e67a6933.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
alpha=atan(cfrac(3,4))
P=phybody(m=0.8,g=10)
P.add_weight()
P.add_forza(N1,alpha)
P.add_forza(T,pi)

# %%
Fx=P.Fx() 
Fy=P.Fy()
# Out:
# $\displaystyle Fx =\frac{4 N_{1}}{5} - T$
# $\displaystyle Fy =\frac{3 N_{1}}{5} - 8$

# %%
N1=Fx.solve('N1')
# Out:
# $\displaystyle N1 =\frac{5 T}{4}$

# %%
Fy.set(N1)
# Out:
# $\displaystyle Fy =\frac{3 T}{4} - 8$

# %%
T=Fy.solve('T')
# Out:
# $\displaystyle T =\frac{32}{3}$

# %%
N1.set(T)
# Out:
# $\displaystyle N1 =\frac{40}{3}$

# %%
#  mayby.... the same again 
from Libaldomath import *
from lib_Mechanics import *
alpha=atan(cfrac(3,4))
P=phybody(m=0.8,g=10)
P.add_weight()
P.add_forza(N1,alpha)
P.add_forza(T,pi)
Fx=P.Fx() 
Fy=P.Fy()
# Out:
# $\displaystyle Fx =\frac{4 N_{1}}{5} - T$
# $\displaystyle Fy =\frac{3 N_{1}}{5} - 8$

# %%
# but compose answer
T,N1=simplesolve(Fx,Fy,T,N1)
# Out:
# $\displaystyle T=\frac{32}{3}$
# $\displaystyle N1=\frac{40}{3}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:81136f75-2d22-41a1-a734-59c24a9d1562.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:9e6b4a0a-b251-4f1d-bbdf-5f6284de0d7f.png)

# %%
P=phybody()

# %%
P.add_forza(F,alpha)
P.add_forza(N1,alpha+pi/2)
P.add_weight()

# %%
Fr=P.fx_relative(alpha,'Fr')
# Out:
# $\displaystyle Fr =F - g m \sin{\left(\alpha \right)}$

# %%
F=Fr.solve('F',g=10,m=10)
# Out:
# $\displaystyle F =100 \sin{\left(\alpha \right)}$

# %%
Fx=P.x_res_relative(alpha,'Fx')
# Out:
# $\displaystyle Fx =F - g m \sin{\left(\alpha \right)}$

# %%
Fx.subs(m*g,100)
# Out:
# $\displaystyle Fx =F - 100 \sin{\left(\alpha \right)}$

# %%
F=Fx.solve('F')
# Out:
# $\displaystyle F =100 \sin{\left(\alpha \right)}$

# %%
F(alpha=asin(cfrac(6,9)))
# Out:
#     6
# 100⋅─
#     9

# %% [markdown]
# ![image.png](attachment:69312e3e-a571-4b54-86eb-d4caa01a02c2.png)
