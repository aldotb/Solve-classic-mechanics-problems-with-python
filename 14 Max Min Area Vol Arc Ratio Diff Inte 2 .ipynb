# %% [markdown]
# ![imagen.png](attachment:da34385c-b2b4-46cd-9c17-bc980eb9ea08.png)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %%
from physic_lib2 import * # run this to reset all variables
reset_eq(e1,e2,e3,e4)

# %% [markdown]
#  ![mn2.png](attachment:aad62cb4-dd5b-4a8e-b5f3-dd5f586ce785.png)

# %%
e2=e2Q(120-2*y-2*x)
# Out:
# $\displaystyle e2 =- 2 x - 2 y + 120$

# %%
A=MyEq(x*y,'A',var2=x,ktype='F')
# Out:
# $\displaystyle A_{(x)} =x y$

# %%
A.set(y,e2.solve(y))
# Out:
# $\displaystyle A_{(x)} =x \left(60 - x\right)$

# %%
x=csolve(A.diff(x),x,'x') # from A solve x if  Diff(A)=0  maximun teorema
# Out:
# $\displaystyle x =30$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![mn3.png](attachment:939fa826-8099-48b1-8793-57b8a5001b90.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
# recta equation
# y=m*x+b ,y=x*(y2-y1)/(x2-x1)+b = eQrec(x1,y1,x2,y2,x) return y then...
eQrec(x1=a,y1=0,x2=0,y2=b,var2=x)
# Out:
# b*(a - x)/a

# %%
L=MyEq(eQrec(x1=a,y1=0,x2=0,y2=b,var2=x),'L',var2=x)
# Out:
# $\displaystyle L =\frac{b \left(a - x\right)}{a}$

# %%
e1(2-L(x=1))
# Out:
# $\displaystyle e1 =2 - \frac{b \left(a - 1\right)}{a}$

# %%
b=e1.solve(b,'b')
# Out:
# $\displaystyle b =\frac{2 a}{a - 1}$

# %%
A=MyEq(a*b/2,'A')
# Out:
# $\displaystyle A =\frac{a^{2}}{a - 1}$

# %%
M=A.diff(a,'M')
# Out:
# $\displaystyle M =- \frac{a^{2}}{\left(a - 1\right)^{2}} + \frac{2 a}{a - 1}$

# %%
a=M.solve(a,'a',korden=1)
# Out:
# $\displaystyle a =2$

# %%
b.upgrade(a)
# Out:
# $\displaystyle b =4$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![mn4.png](attachment:75ed8587-60a3-4de3-b4ee-f17a4cb23bed.png)

# %%
from physic_lib2 import *

# %%
T=MyEq(get_hipo(5,x)/2+(6-x)/4,'T')
# Out:
# $\displaystyle T =- \frac{x}{4} + \frac{\sqrt{x^{2} + 25}}{2} + \frac{3}{2}$

# %%
Tm=T.diff(x,'Tm')
# Out:
# $\displaystyle Tm =\frac{x}{2 \sqrt{x^{2} + 25}} - \frac{1}{4}$

# %%
Tm.solve(x)
# Out:
# 5*sqrt(3)/3

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![mn5.png](attachment:2272e8bc-59d7-424a-be43-e1a99b19322b.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
G=get_hipo(h,r)
A=MyEq(pi*r*G,'A')
# Out:
# $\displaystyle A =\pi r \sqrt{h^{2} + r^{2}}$

# %%
e1((H-h)/r-H/R)
# Out:
# $\displaystyle e1 =- \frac{H}{R} + \frac{H - h}{r}$

# %%
h=e1.solve(h,'h')
# Out:
# $\displaystyle h =\frac{H \left(R - r\right)}{R}$

# %%
A.upgrade(h)
# Out:
# $\displaystyle A =\pi r \sqrt{\frac{H^{2} \left(R - r\right)^{2}}{R^{2}} + r^{2}}$

# %%
At=A.diff(r,'At')
# Out:
# $\displaystyle At =\frac{\pi r \left(\frac{H^{2} \left(- 2 R + 2 r\right)}{2 R^{2}} + r\right)}{\sqrt{\frac{H^{2} \left(R - r\right)^{2}}{R^{2}} + r^{2}}} + \pi \sqrt{\frac{H^{2} \left(R - r\right)^{2}}{R^{2}} + r^{2}}$

# %%
At.reduFac()
# Out:
# $\displaystyle At =H^{2} R^{2} - 3 H^{2} R r + 2 H^{2} r^{2} + 2 R^{2} r^{2}$

# %%
At.factorSec(r*r)
# Out:
# $\displaystyle At =H^{2} R^{2} - 3 H^{2} R r + r^{2} \left(2 H^{2} + 2 R^{2}\right)$

# %%
r=At.solve(r,'r',korden=1)
# Out:
# $\displaystyle r =\frac{H R \left(3 H + \sqrt{H^{2} - 8 R^{2}}\right)}{4 H^{2} + 4 R^{2}}$

# %%
r.set(H=3,R=1)
# Out:
# $\displaystyle r =\frac{3}{4}$

# %%
h.set(H=3,R=1,r=frs(3,4))
# Out:
# $\displaystyle h =\frac{3}{4}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![mn6.png](attachment:7ef0dffd-aaab-4ca1-98c1-5ee703504806.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %% [markdown]
#  ![mn6a.png](attachment:e799af65-3abf-4834-9103-0c8b3301316d.png)

# %%
x=MyEq(h*R/(rpow(h*h-R*R)),'x')
# Out:
# $\displaystyle x =\frac{R h}{\sqrt{- R^{2} + h^{2}}}$

# %%
Vo=MyEq(x*x*pi*h/3,'Vo')
# Out:
# $\displaystyle Vo =\frac{\pi R^{2} h^{3}}{- 3 R^{2} + 3 h^{2}}$

# %%
Vm= Vo.diff(h,'Vm')
# Out:
# $\displaystyle Vm =- \frac{6 \pi R^{2} h^{4}}{\left(- 3 R^{2} + 3 h^{2}\right)^{2}} + \frac{3 \pi R^{2} h^{2}}{- 3 R^{2} + 3 h^{2}}$

# %%
Vm.reduFac()
# Out:
# $\displaystyle Vm =- 3 R^{2} + h^{2}$

# %%
h=Vm.solveR(h,'h',kope='r')
# Out:
# $\displaystyle h =\sqrt{3} R$

# %%
x.upgrade(h,kope='-')
# Out:
# $\displaystyle x =\frac{\sqrt{6} R}{2}$

# %%
Vo.upgrade(h,x)
# Out:
# $\displaystyle Vo =\frac{\sqrt{3} \pi R^{3}}{2}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![mn7.png](attachment:4cbb7e11-67a8-4943-b43b-6b8d444833a5.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
Vo=MyEq(pi*r*r*h,'Vo')
L=MyEq(2*2*pi*r+h,L)
e1(1000-Vo)
# Out:
# $\displaystyle Vo =\pi h r^{2}$
# $\displaystyle L =h + 4 \pi r$
# $\displaystyle e1 =\pi h r^{2} - 1000$

# %%
h=e1.solve(h,'h')
# Out:
# $\displaystyle h =\frac{1000}{\pi r^{2}}$

# %%
L.upgrade(h)
# Out:
# $\displaystyle L =4 \pi r + \frac{1000}{\pi r^{2}}$

# %%
Lc=L.diff(r,'Lc')
# Out:
# $\displaystyle Lc =4 \pi - \frac{2000}{\pi r^{3}}$

# %%
r=Lc.solve(r,'r',korden=0,kope='N')
# Out:
# $\displaystyle r =3.70018484153678$

# %%
h.upgrade(r,kope='N')
# Out:
# $\displaystyle h =23.2489470301925$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![mn8.png](attachment:f7c0ca71-bbec-43e2-9a4f-8176d69c26af.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
x1,y1,x2,y2,x3,y3=1,1,1,2,2,2
P1=Point2D(x1,y1) # From geometry sympy Library  P1=Point2D(x,y)
P2=Point2D(x2,y2)
P3=Point2D(x3,y3)    # To create Line see below geometry sympy proc
L=Line(2*x + -y + b) # From geometry sympy Library  L=Line(a*x + b*y + c)

# %%
D1=Pow(P1.distance(L),2)
D2=Pow(P2.distance(L),2)
D3=Pow(P3.distance(L),2)
Ls=MyEq(D1+D2+D3,'Ls')
# Out:
# $\displaystyle Ls =\frac{b^{2}}{5} + \left(- \frac{b}{5} - \frac{2}{5}\right)^{2} + \left(- \frac{b}{5} - \frac{1}{5}\right)^{2} + \left(\frac{2 b}{5} + \frac{2}{5}\right)^{2} + \left(\frac{2 b}{5} + \frac{4}{5}\right)^{2}$

# %%
Ls.opemat('esf')
# Out:
# $\displaystyle Ls =\frac{3 b^{2} + 6 b + 5}{5}$

# %%
dL=Ls.diff(b,'dL')
# Out:
# $\displaystyle dL =\frac{6 b}{5} + \frac{6}{5}$

# %%
b=dL.solve(b,'b')
# Out:
# $\displaystyle b =-1$

# %% [markdown]
#  ![mn8b.png](attachment:6a16e3c8-fd95-4ea8-946f-e20a953116df.png)

# %%
L=Line(m*x-y+0) # From geometry sympy Library  L=Line(a*x + b*y + c)

# %%
D1=Pow(P1.distance(L),2)
D2=Pow(P2.distance(L),2)
D3=Pow(P3.distance(L),2)
S2=MyEq(D1+D2+D3,'S2',kope='es')
# Out:
# $\displaystyle S2 =\frac{6 m^{2} - 14 m + 9}{m^{2} + 1}$

# %%
dS=S2.diff(m,'dS')
# Out:
# $\displaystyle dS =- \frac{2 m \left(6 m^{2} - 14 m + 9\right)}{\left(m^{2} + 1\right)^{2}} + \frac{12 m - 14}{m^{2} + 1}$

# %%
dS.reduFac()
# Out:
# $\displaystyle dS =14 m^{2} - 6 m - 14$

# %%
m=dS.solve(m,'m',korden=1,kope='N')
# Out:
# $\displaystyle m =1.23698721880545$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![imagen.png](attachment:d265a09b-2847-4f63-bea9-7b49e5b102ba.png)

# %% [markdown]
# ![imagen.png](attachment:38eb0168-a5d3-4dca-9256-46eaa27f7f92.png)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:38f45cd6-0072-4130-bc99-e1b49fb61f0f.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
Area_func(1+(6*x-x*x)/9,0,cota=[0,5])
# Out:
# $\displaystyle Area =- \int\limits_{0}^{5} 0\, dx + \int\limits_{0}^{5} \left(- \frac{x^{2}}{9} + \frac{2 x}{3} + 1\right)\, dx$
# $\displaystyle Area =\frac{235}{27}$

# %% [markdown]
#  ![id2.png](attachment:f4ba0a83-beea-44e1-9287-72d0b9d9008e.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
Area_func(log(x),1,cota=[0,exp(1)])
# Out:
# $\displaystyle Area =- \int\limits_{0}^{e} \log{\left(x \right)}\, dx + \int\limits_{0}^{e} 1\, dx$
# $\displaystyle Area =e$

# %% [markdown]
#  ![id3.png](attachment:1ffcf5da-43d3-4d7f-a840-fc0b24f7cc79.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
y1=2*x/5+2/5
y2=(x-2)**2/9-1
Area_func(y1,y2,cota=[-1,4])
# Out:
# $\displaystyle Area =- \int\limits_{-1}^{4} \left(\frac{\left(x - 2\right)^{2}}{9} - 1\right)\, dx + \int\limits_{-1}^{4} \left(\frac{2 x}{5} + 0.4\right)\, dx$
# $\displaystyle Area =8.7037037037037$

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
# check my func frs(a,b) = a/b but not decimal answer
 
y1=2*x/5+frs(2,5)
y2=(x-2)**2/9-1
Area_func(y1,y2,cota=[-1,4])
# Out:
# $\displaystyle Area =- \int\limits_{-1}^{4} \left(\frac{\left(x - 2\right)^{2}}{9} - 1\right)\, dx + \int\limits_{-1}^{4} \left(\frac{2 x}{5} + \frac{2}{5}\right)\, dx$
# $\displaystyle Area =\frac{235}{27}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![id4.png](attachment:e07a5458-8e44-4625-9b22-5d9074ee3693.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
 
y1=2-x/2+1
y2=0
Area_func(y1,y2,cota=[-2,4])
# Out:
# $\displaystyle Area =- \int\limits_{-2}^{4} 0\, dx + \int\limits_{-2}^{4} \left(3 - \frac{x}{2}\right)\, dx$
# $\displaystyle Area =15$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![id5.png](attachment:5666f421-cf94-416e-94e7-c393295d9619.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
 
y1=x/3+1
y2=5-x
y3=x**2/2-2*x+1

# %%
a1=Area_func(y1,y3,cota=[0,3])
# Out:
# $\displaystyle Area =- \int\limits_{0}^{2 - \sqrt{2}} \left(\frac{x^{2}}{2} - 2 x + 1\right)\, dx + \int\limits_{0}^{2 - \sqrt{2}} \left(\frac{x}{3} + 1\right)\, dx - \int\limits_{2 - \sqrt{2}}^{3} \left(\frac{x^{2}}{2} - 2 x + 1\right)\, dx + \int\limits_{2 - \sqrt{2}}^{3} \left(\frac{x}{3} + 1\right)\, dx$
# $\displaystyle Area =6$

# %%
a2=Area_func(y2,y3,cota=[3,4])
# Out:
# $\displaystyle Area =- \int\limits_{\sqrt{2} + 2}^{4} \left(\frac{x^{2}}{2} - 2 x + 1\right)\, dx - \int\limits_{3}^{\sqrt{2} + 2} \left(\frac{x^{2}}{2} - 2 x + 1\right)\, dx + \int\limits_{3}^{\sqrt{2} + 2} \left(5 - x\right)\, dx + \int\limits_{\sqrt{2} + 2}^{4} \left(5 - x\right)\, dx$
# $\displaystyle Area =\frac{4}{3}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![id6.png](attachment:a0453061-4640-44f4-a75c-7fe8439c4ea2.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
x1=y*y
x2=2-y

# %%
Area_func(x1,x2,var=y,cota=[1,-2])
# Out:
# $\displaystyle Area =- \int\limits_{-2}^{1} \left(2 - y\right)\, dy + \int\limits_{-2}^{1} y^{2}\, dy$
# $\displaystyle Area =- \frac{9}{2}$

# %% [markdown]
# ![imagen.png](attachment:63d1104a-c6a1-49e7-8cb1-241fd8716a64.png)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![id7.png](attachment:1bb2a691-b6e2-44de-9e10-7b7053e987c8.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
V=MyEq(pi*y*y,'V',var2=x,x1=1,x2=4,ktype='I')
# Out:
# $\displaystyle V =\int\limits_{1}^{4} \pi y^{2}\, dx$

# %%
y=MyEq(rpow(x),'y')
# Out:
# $\displaystyle y =\sqrt{x}$

# %%
V.upgrade(y)
# Out:
# $\displaystyle V =\int\limits_{1}^{4} \pi x\, dx$

# %%
V.doitI()
# Out:
# $\displaystyle V =\frac{15 \pi}{2}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![id8.png](attachment:ec065ec6-6ca3-42c2-bdd1-f72b08c2fd1b.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %%
y=MyEq(2-x,'y')
V=MyEq(pi*y*y,'V',var2=x,x1=0,x2=2,ktype='I')
# Out:
# $\displaystyle y =2 - x$
# $\displaystyle V =\int\limits_{0}^{2} \pi \left(2 - x\right)^{2}\, dx$

# %%
V.doitI()
# Out:
# $\displaystyle V =\frac{8 \pi}{3}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![id9.png](attachment:37915de5-3c50-4792-a9c1-c82ef803d8e5.png)

# %%
from physic_lib2 import *

# %%
y2=kpow(x,2)
y1=rpow(x)

# %%
get_intersec_2func(y1,y2)
# Out:
# [0, 1]

# %%
x1,x2=get_intersec_2func(y1,y2)

# %%
def get_intersec_2func(y1,y2,var=x):
    ee=MyEq(y1-y2,kshow=False)
    return ee.solve(var)

# %%
x1,x2=get_intersec_2func(y1,y2)

# %%
Vo=MyEq(y2*y2*pi-y1*y1*pi,'Vo',var2=x,x1=x1,x2=x2,ktype='I')
# Out:
# $\displaystyle Vo =\int\limits_{0}^{1} \left(\pi x^{4} - \pi x\right)\, dx$

# %%
Vo.doitI()
# Out:
# $\displaystyle Vo =\frac{3 \pi}{10}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:570f1ca8-f673-4560-809f-80dbae361c5b.png)

# %%
from physic_lib2 import *

# %%
y=MyEq(x*x,'y')
# Out:
# $\displaystyle y =x^{2}$

# %%
dA= MyEq(y,'A',ktype='Diff')
# Out:
# $\displaystyle dA=x^{2}d_x$

# %%
dV= MyEq(2*pi*x*dA,'V',ktype='Diff')
# Out:
# $\displaystyle dV=2 \pi x^{3}d_x$

# %%
dV.integral(x1=0,x2=2)
# Out:
# $\displaystyle V =\int\limits_{0}^{2} 2 \pi x^{3}\, dx$

# %%
dV.doitI()
# Out:
# $\displaystyle V =8 \pi$

# %% [markdown]
# ![imagen.png](attachment:d5c5aa61-e97a-4d40-bc00-3ff3e72a199a.png)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![al1.png](attachment:7cd123d1-f2b1-443a-aabd-28dc894ad9e1.png)

# %%
from physic_lib2 import *
y=MyEq(kpow(x**2+2,frs(3,2))/3,'y',x1=0,x2=3,var2=x)
# Out:
# $\displaystyle y =\frac{\left(x^{2} + 2\right)^{\frac{3}{2}}}{3}$

# %%
y.length_arc()
# Out:
# $\displaystyle dy=\frac{\left(x^{2} + 2\right)^{\frac{3}{2}}}{3}d_x$
# $\displaystyle dy =x \sqrt{x^{2} + 2}$
# $\displaystyle dL=x^{2} + 1d_x$
# $\displaystyle L =\int\limits_{0}^{3} \left(x^{2} + 1\right)\, dx$
# $\displaystyle L =12$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![al2.png](attachment:80b5d832-dc41-49a7-9a0b-f9224f578f6f.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6) 
e1(9*y*y-4*x*x*x)
y=e1.solve(y,'y',korden=1)
# Out:
# $\displaystyle e1 =- 4 x^{3} + 9 y^{2}$
# $\displaystyle y =\frac{2 \sqrt{x^{3}}}{3}$

# %%
Y=MyEq(y,'Y',x1=0,x2=2*rpow(3),var2=x)
# Out:
# $\displaystyle Y =\frac{2 \sqrt{x^{3}}}{3}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![al3.png](attachment:41012d84-a620-4dab-b2d5-4b54fcd0e790.png)

# %%
from physic_lib2 import *
y=MyEq((x**4/4)+1/(8*x**2),'y',x1=1,x2=2,var2=x)
# Out:
# $\displaystyle y =\frac{x^{4}}{4} + \frac{1}{8 x^{2}}$

# %%
y.length_arc()
# Out:
# $\displaystyle dy=\frac{x^{4}}{4} + \frac{1}{8 x^{2}}d_x$
# $\displaystyle dy =x^{3} - \frac{1}{4 x^{3}}$
# $\displaystyle dL=\frac{4 x^{6} + 1}{4 x^{3}}d_x$
# $\displaystyle L =\int\limits_{1}^{2} \frac{4 x^{6} + 1}{4 x^{3}}\, dx$
# $\displaystyle L =\frac{123}{32}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![al4.png](attachment:5b1b8f4b-ab14-44b3-9c0d-8757c7531a1b.png)

# %%
from physic_lib2 import *
y=MyEq( rpow(4*x*x*x)-1,'y',x1=0,x2=1,var2=x)
# Out:
# $\displaystyle y =2 \sqrt{x^{3}} - 1$

# %%
y.length_arc()
# Out:
# $\displaystyle dy=2 \sqrt{x^{3}} - 1d_x$
# $\displaystyle dy =\frac{3 \sqrt{x^{3}}}{x}$
# $\displaystyle dL=\sqrt{9 x + 1}d_x$
# $\displaystyle L =\int\limits_{0}^{1} \sqrt{9 x + 1}\, dx$
# $\displaystyle L =- \frac{2}{27} + \frac{20 \sqrt{10}}{27}$

# %% [markdown]
# ![imagen.png](attachment:a4e67a71-0f17-4b49-bd35-5379763bdf55.png)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %% [markdown]
#  ![rcd1.png](attachment:24f343eb-add1-43f3-a66b-2faf6c700ffc.png)

# %%
dV=MyEq(-15,'dV')
# Out:
# $\displaystyle dV =-15$

# %%
V=MyEq(pi*r*r*h/3,'V')
# Out:
# $\displaystyle V =\frac{\pi h r^{2}}{3}$

# %%
r=MyEq(8*h/20,'r')
# Out:
# $\displaystyle r =\frac{2 h}{5}$

# %%
V.upgrade(r)
# Out:
# $\displaystyle V =\frac{4 \pi h^{3}}{75}$

# %%
e1(dV-V.diff(h)*dh)
# Out:
# $\displaystyle e1 =- \frac{4 \pi dh h^{2}}{25} - 15$

# %%
dh=e1.solve(dh,'dh')
# Out:
# $\displaystyle dh =- \frac{375}{4 \pi h^{2}}$

# %%
dh(h=10)
# Out:
# -15/(16*pi)

# %% [markdown]
#  ![rcd1b.png](attachment:03c83ee8-7c9f-4b9f-a98f-21f82465b25d.png)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![rcd2.png](attachment:00081ac9-3fc8-47b2-b1d1-2af69cff8303.png)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![rcd3.png](attachment:d6a1f89a-ff8f-4207-8540-a7cd1c2a586a.png)

# %%
from physic_lib2 import *
reset_ee(e1,e2,e3,e4,e5,e6)

# %% [markdown]
#  ![rcd3a.png](attachment:e423a903-57aa-4519-81e3-3f25020f59ef.png)

# %%
dh_dt=-2
dA_dt=-3
Bdt,b=symbols('Bdt b')

# %% [markdown]
#  ![rcd3B.png](attachment:08e1ddac-56d9-449b-846b-99e27bbc3c5f.png)

# %%
h=20
b=csolve(150-b*20/2,b) # replace A=150 and h=20 in A=b*h/2
show_res(b,'b')
# Out:
# $\displaystyle b =15$

# %% [markdown]
#  ![rcd3c.png](attachment:9f58f29c-a1ea-40e7-a863-633afb4e44b0.png)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)
