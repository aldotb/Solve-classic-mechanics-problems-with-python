# %%
from lib_Physics import *

# %% [markdown]
#  ![line.png](attachment:19ebcc74-4986-4312-945a-1991c80034b4.png)

# %% [markdown]
#  ![d020.png](attachment:c33933e6-bcc7-4054-b3de-8bff8ae715be.png)

# %%
A=mparticle(m=m,ac=a)
A.add_forza(T,0)

# %%
aA=A.acdynamic('aA')
# Out:
# $\displaystyle aA = \frac{T}{m}$

# %%
B=mparticle(m=m,ac=2*a)
B.add_forza(T/2,pi/2)
B.add_forza(m*g,-pi/2)

# %%
aB=B.acdynamic('aB',-pi/2)
# Out:
# $\displaystyle aB = \frac{g m - \frac{T}{2}}{m}$

# %%
Q=MyEqEq(2*aA,aB)
# Out:
# $\displaystyle \frac{2 T}{m} = \frac{g m - \frac{T}{2}}{m}$

# %%
Q.simplify()
# Out:
# $\displaystyle 2 T = g m - \frac{T}{2}$

# %%
T=Q.solve('T')
# Out:
# $\displaystyle T = \frac{2 g m}{5}$

# %%
aB.set(T)
# Out:
# $\displaystyle aB = \frac{4 g}{5}$

# %%
aB.set(g=10)
# Out:
# $\displaystyle aB = 8$

# %%
aA.set(T)
# Out:
# $\displaystyle aA = \frac{2 g}{5}$

# %%
aA.set(g=10)
# Out:
# $\displaystyle aA = 4$

# %% [markdown]
#  ![line.png](attachment:830a0017-2e5f-431a-aac9-60ab82dc96db.png)

# %%
from lib_Physics import *

# %% [markdown]
# ![imagen.png](attachment:66f13b70-717e-4125-80e9-b9061cf9721e.png)

# %%
A=mparticle(m=m1)
A.add_forza(m1*g,-pi/2)
A.add_forza(T+2*T1,pi/2)
aA=A.acdynamic(pi/2,'aA')
# Out:
# $\displaystyle aA = \frac{T + 2 T_{1} - g m_{1}}{m_{1}}$

# %%
B=mparticle(m=m2)
B.add_forza(m2*g,-pi/1)
B.add_forza(T1,pi/2)
aB=B.acdynamic(pi/2,'aB')
# Out:
# $\displaystyle aB = \frac{T_{1}}{m_{2}}$

# %%
Q=MyEqEq(2*aA,aB)
# Out:
# $\displaystyle \frac{2 \left(T + 2 T_{1} - g m_{1}\right)}{m_{1}} = \frac{T_{1}}{m_{2}}$

# %%
T1=Q.solve('T1')
# Out:
# $\displaystyle T1 = \frac{2 m_{2} \left(T - g m_{1}\right)}{m_{1} - 4 m_{2}}$

# %%
aA.set(T1)
# Out:
# $\displaystyle aA = \frac{T + \frac{4 m_{2} \left(T - g m_{1}\right)}{m_{1} - 4 m_{2}} - g m_{1}}{m_{1}}$

# %%
aA.simplify()
# Out:
# $\displaystyle aA = \frac{T - g m_{1}}{m_{1} - 4 m_{2}}$

# %%
aB.set(T1)
# Out:
# $\displaystyle aB = \frac{2 \left(T - g m_{1}\right)}{m_{1} - 4 m_{2}}$

# %% [markdown]
#  ![line.png](attachment:830a0017-2e5f-431a-aac9-60ab82dc96db.png)

# %% [markdown]
#  ![d030.png](attachment:d3b2039d-7842-4b26-8620-1a09efbc9ac9.png)

# %%
from lib_Physics import *

# %%
# wiltake axxis reference whit  mass move direcction refernce like x 
A=mparticle()
A.add_forza(m*g,-pi/2)
A.add_forza(T,pi-alpha)
A.add_forza(N1,pi/2-alpha)
A.add_forza(fr,-alpha)

# %% [markdown]
#  ![d031.png](attachment:1ad646c7-91c9-4a29-8c81-b911b4c127ac.png)

# %%
Fy=A.yres('Fy',-alpha)
# Out:
# $\displaystyle Fy = N_{1} - g m \cos{\left(\alpha \right)}$

# %%
N1=Fy.solve('N1')
# Out:
# $\displaystyle N1 = g m \cos{\left(\alpha \right)}$

# %%
aA=A.acdynamic('aA',pi-alpha)
# Out:
# $\displaystyle aA = \frac{T - f_{r} - g m \sin{\left(\alpha \right)}}{m}$

# %%
aA.set(fr,N1()*mu)
# Out:
# $\displaystyle aA = \frac{T - g m \sin{\left(\alpha \right)} - g m \mu \cos{\left(\alpha \right)}}{m}$

# %%
N2
# Out:
# N2

# %%
B=mparticle(m=4*m)
B.add_forza(4*m*g,-pi/2)
B.add_forza(T,alpha)
B.add_forza(N2,pi/2+alpha)
B.add_forza(fr,alpha)

# %%
Fy=B.yres('Fy',alpha)
# Out:
# $\displaystyle Fy = N_{2} - 4 g m \cos{\left(\alpha \right)}$

# %%
N2=Fy.solve('N2')
# Out:
# $\displaystyle N2 = 4 g m \cos{\left(\alpha \right)}$

# %%
aB=B.acdynamic('aB',pi+alpha)
# Out:
# $\displaystyle aB = \frac{4 g m \sin{\left(\alpha \right)} - T - f_{r}}{4 m}$

# %%
aB.set(fr=N2()*mu)
# Out:
# $\displaystyle aB = \frac{4 g m \sin{\left(\alpha \right)} - T - 4 g m \mu \cos{\left(\alpha \right)}}{4 m}$

# %%
Q=MyEqEq(aA,aB)
# Out:
# $\displaystyle \frac{T - g m \sin{\left(\alpha \right)} - g m \mu \cos{\left(\alpha \right)}}{m} = \frac{4 g m \sin{\left(\alpha \right)} - T - 4 g m \mu \cos{\left(\alpha \right)}}{4 m}$

# %%
Q.simplify()
# Out:
# $\displaystyle T - g m \sin{\left(\alpha \right)} - g m \mu \cos{\left(\alpha \right)} = g m \sin{\left(\alpha \right)} - \frac{T}{4} - g m \mu \cos{\left(\alpha \right)}$

# %%
Q.alone(T)
# Out:
# $\displaystyle T = \frac{8 g m \sin{\left(\alpha \right)}}{5}$

# %% [markdown]
#  ![line.png](attachment:830a0017-2e5f-431a-aac9-60ab82dc96db.png)
