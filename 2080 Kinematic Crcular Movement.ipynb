# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:058dc4d9-4772-4f0b-9fb2-60065d38e228.png)

# %%
from Libaldomath import *

# %%
e1=MyIntg(t**3-9*t**2+10,'e1',var=t)
# Out:
# $\displaystyle e1=\int \left(t^{3} - 9 t^{2} + 10\right)\, dt$

# %%
Q=MQI(x,e1)
# Out:
# $\displaystyle x = \int \left(t^{3} - 9 t^{2} + 10\right)\, dt$

# %%
Q.doit()
# Out:
# $\displaystyle x = C_{1} + \frac{t^{4}}{4} - 3 t^{3} + 10 t$

# %%
C1=Q.solve('C1','update',x=6,t=4)
# Out:
# $\displaystyle C1 =94$
# $\displaystyle x = \frac{t^{4}}{4} - 3 t^{3} + 10 t + 94$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# A wheel of radius 10 cm is rotating with an angular velocity of 120 r.p.m., the brakes are applied and it stops in 4 s. Calculate:
#
#     Angular acceleration (braking force assumed constant).
#     The angle rotated at 4 s.
#
# Calculate 1 s. after applying the brakes:
#
#     Angular velocity, the (linear) velocity of a point on the periphery of the wheel.
#     The tangential and normal components of acceleration.

# %% [markdown]
# ![image.png](attachment:4afbc4b3-1de6-4ca4-ae05-e49fc26c9191.png)

# %%
P=phybody(w1=rpm2rad(120),w2=0,r=cfrac(1,10),alpha1=0)

# %%
Q1=P.eQangularaceleration(4)
# Out:
# $\displaystyle a_{w} = - \frac{1}{\pi}$

# %%
aw=simplesolve(Q1)
# Out:
# $\displaystyle a_w =- \frac{1}{\pi}$

# %%
P.setaw(aw)

# %%
P.angle_pos(4)

# %%
P.angle_pos(4)
# Out:
# 8⋅a_w

# %%
Q1=eQangularaceleration(P,4)
# Out:
# $\displaystyle a_{w} = - \frac{1}{\pi}$

# %%
aw=simplesolve(Q1)
# Out:
# $\displaystyle a_w =- \frac{1}{\pi}$

# %%
type(aw)
# Out:
# lib_MyEq.MyEq

# %%
anglet(P,4)
# Out:
# 8⋅a_w + 16⋅π

# %%
def xvel(self,*args,**kwargs):
        tt=get_tvar(*args)
        if self.ax!=ax:
            kres=self.v1*cos(self.ang)+self.ax*tt 
        else:
            kres=2*(self.x2-self.x1)/tt-self.v1*tt
        return smartanswer(kres, *args,**kwargs)

# %%
aw=eQangularaceleration(P)
# Out:
# $\displaystyle a_{w} = - \frac{1}{\pi}$

# %%
rpm2rad(120)
# Out:
# 4⋅π

# %%
alpha1+4*pi*t+aw*t*t/2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 alpha1+4*pi*t+aw*t*t/2
#
# TypeError: unsupported operand type(s) for *: 'Equality' and 'int'

# %%
cfrac(10)
# Out:
# 1
# ──
# 10

# %%
P=phybody(w1=rpm2rad(120),w2=0,r=0.1,alpha1=0)
# Out:
# -π

# %%
def anglet(var=t):
    w1=self.w1
    w2=self.w2
    alpha1=self.alpha1
    alpha2=alpha1+w1*t+aw*t*t/2
    if alpha2>2*pi:
# Out:
#   Cell In[6], line 1
#     def anglet():
#                  ^
# SyntaxError: incomplete input

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
r=10
w1=120
w2=0
t=4

# %%
aw=(w2-w1)/t

# %%
aw
# Out:
# -30.0

# %%
x=Q1.dsolve('F')
# Out:
# $\displaystyle x =C_{1} - \cos{\left(2 t \right)}$

# %%
C1=x.solve('C1','update',x=-1,t=0)
# Out:
# $\displaystyle x =- \cos{\left(2 t \right)}$
# $\displaystyle C1 =0$

# %%
dx=x.diff(t,'dx')
d2x=x.diff(t,t,'d2x')
# Out:
# $\displaystyle dx =2 \sin{\left(2 t \right)}$
# $\displaystyle d2x =4 \cos{\left(2 t \right)}$

# %%
Q2=MyEqDiff("y'","4*t",t,y)
# Out:
# $\displaystyle y' = 4 t$

# %%
y=Q2.dsolve('F')
# Out:
# $\displaystyle y =C_{1} + 2 t^{2}$

# %%
C1=y.solve('C1','update',y=-0,t=0)
# Out:
# $\displaystyle y =2 t^{2}$
# $\displaystyle C1 =0$

# %%
dy=y.diff(t,'dy')
d2y=y.diff(t,t,'d2y')
# Out:
# $\displaystyle dy =4 t$
# $\displaystyle d2y =4$

# %%
alpha1=atan(dy/dx) 
alpha2=atan(d2y/d2x)

# %%
a=sqrt(d2y()**2+d2x()**2)
a
# Out:
#    ___________________
#   ╱       2
# ╲╱  16⋅cos (2⋅t) + 16

# %%
at=MyEq(a*cos(alpha1-alpha2),'at',var=t)
# Out:
# $\displaystyle at =\sqrt{16 \cos^{2}{\left(2 t \right)} + 16} \cos{\left(\operatorname{atan}{\left(\frac{2 t}{\sin{\left(2 t \right)}} \right)} - \operatorname{atan}{\left(\frac{1}{\cos{\left(2 t \right)}} \right)} \right)}$

# %%
float(at(8))
# Out:
# 4.068269771182187

# %%
an=MyEq(a*sin(alpha2-alpha1),'an',var=t)
# Out:
# $\displaystyle an =- \sqrt{16 \cos^{2}{\left(2 t \right)} + 16} \sin{\left(\operatorname{atan}{\left(\frac{2 t}{\sin{\left(2 t \right)}} \right)} - \operatorname{atan}{\left(\frac{1}{\cos{\left(2 t \right)}} \right)} \right)}$

# %%
float(an(8))
# Out:
# 3.758053745349754

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:91ea4501-3849-427f-aa08-9fe0bcf5defa.png)

# %%
from Libaldomath import *
