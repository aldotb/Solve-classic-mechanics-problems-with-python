# %%
import sys
sys.path.insert(0, 'C:/Libaldo/')
from lib_MyVector import *

# %% [markdown]
# ![imagen.png](attachment:27e967c2-0648-40dd-9811-3eabfd1c356c.png)

# %%
A = Point3D(3, 0, -1)
B = Point3D(2, 10, 6)
C = Point3D(1, 2, 1)
O = Point3D(0, 0, 0)

# %%
M=A.midpoint(C)
G=B+2*(M-B)/3

# %%
OM=MyVector(O,M)
OG=MyVector(O,G)

# %%
OM.angle(OG)
# Out:
# acos(2*sqrt(30)/15)

# %% [markdown]
# ![imagen.png](attachment:8caa78ce-ca1f-406a-b3e4-a27f0f8a7ab3.png)

# %%
import sys
sys.path.insert(0, 'C:/Libaldo/')
from lib_MyVector import *
from lib_MyEqEq import *

# %% [markdown]
# ![imagen.png](attachment:c5ac5f2c-44a5-41e4-8a2c-524f3321f2fd.png)

# %%
Q=MQ(cos(pi/3)**2+cos(pi/4)**2+cos(alpha)**2,1)
# Out:
# $\displaystyle \cos^{2}{\left(\alpha \right)} + \frac{3}{4} = 1$

# %%
Q.Add(cf(-3,4))
# Out:
# $\displaystyle \cos^{2}{\left(\alpha \right)} = \frac{1}{4}$

# %%
Q.Rpow()
# Out:
# $\displaystyle \sqrt{\cos^{2}{\left(\alpha \right)}} = \frac{1}{2}$

# %%
Q.rsimplify()
# Out:
# $\displaystyle \cos{\left(\alpha \right)} = \frac{1}{2}$

# %% [markdown]
# ![imagen.png](attachment:8caa78ce-ca1f-406a-b3e4-a27f0f8a7ab3.png)

# %%
# solve whit MyVector lib

# %% [markdown]
# ![imagen.png](attachment:c5ac5f2c-44a5-41e4-8a2c-524f3321f2fd.png)

# %%
x,y,z = symbols('x y z', positive=True)

# %%
V=MyVector(x,y,z)

# %%
V1=MyVector(1,0,0)

# %%
V.angle(V1)
# Out:
# acos(x/sqrt(x**2 + y**2 + z**2))

# %%
Q1=MQ(cos(V.angle(V1)),cos(pi/3))
# Out:
# $\displaystyle \frac{x}{\sqrt{x^{2} + y^{2} + z^{2}}} = \frac{1}{2}$

# %%
Q1.crosmul()
# Out:
# $\displaystyle 2 x = \sqrt{x^{2} + y^{2} + z^{2}}$

# %%
Q1.Pow(2)
# Out:
# $\displaystyle 4 x^{2} = x^{2} + y^{2} + z^{2}$

# %%
Q1.alone(x*x)
# Out:
# $\displaystyle x^{2} = \frac{y^{2}}{3} + \frac{z^{2}}{3}$

# %%
V2=MyVector(0,1,0)

# %%
Q2=MQ(cos(V.angle(V2)),cos(pi/4))
# Out:
# $\displaystyle \frac{y}{\sqrt{x^{2} + y^{2} + z^{2}}} = \frac{\sqrt{2}}{2}$

# %%
Q2.crosmul()
# Out:
# $\displaystyle 2 y = \sqrt{2} \sqrt{x^{2} + y^{2} + z^{2}}$

# %%
Q2.Pow(2)
# Out:
# $\displaystyle 4 y^{2} = 2 x^{2} + 2 y^{2} + 2 z^{2}$

# %%
Q2.set(Q1)
# Out:
# $\displaystyle 4 y^{2} = \frac{8 y^{2}}{3} + \frac{8 z^{2}}{3}$

# %%
Q2.alone(y*y)
# Out:
# $\displaystyle y^{2} = 2 z^{2}$

# %%
Q1.set(Q2)
# Out:
# $\displaystyle x^{2} = z^{2}$

# %%
V3=MyVector(0,0,1)

# %%
Q3=MQ(cos(V.angle(V3)),cos(theta))
# Out:
# $\displaystyle \frac{z}{\sqrt{x^{2} + y^{2} + z^{2}}} = \cos{\left(\theta \right)}$

# %%
Q3.set(Q1)
# Out:
# $\displaystyle \frac{z}{\sqrt{y^{2} + 2 z^{2}}} = \cos{\left(\theta \right)}$

# %%
Q3.set(Q2)
# Out:
# $\displaystyle \frac{z}{2 \sqrt{z^{2}}} = \cos{\left(\theta \right)}$

# %%
Q3.simplify()
# Out:
# $\displaystyle \frac{z}{2 \sqrt{z^{2}}} = \cos{\left(\theta \right)}$

# %%
Q3.rsimplify()
# Out:
# $\displaystyle \frac{1}{2} = \cos{\left(\theta \right)}$

# %% [markdown]
# ![imagen.png](attachment:8caa78ce-ca1f-406a-b3e4-a27f0f8a7ab3.png)

# %%
import sys
sys.path.insert(0, 'C:/Libaldo/')
from Libaldomath import *
from lib_MyVector import *

# %% [markdown]
# ![imagen.png](attachment:89be203f-6f97-47f3-9bf5-325897d5d755.png)

# %%
a=MyVector(1,1,sqrt(2))
b=MyVector(b1,b2,sqrt(2))
c=MyVector(5,1,sqrt(2))

# %%
b.projection(a)
# Out:
# (b1/4 + b2/4 + 1/2)i+(b1/4 + b2/4 + 1/2)j+(sqrt(2)*(b1 + b2 + 2)/4)k

# %%
Vp=b.projection(a)

# %%
(Vp-a).components[0] # = cero
# Out:
# b1/4 + b2/4 - 1/2

# %%
c.dot(a+b) # igual a cero
# Out:
# 5*b1 + b2 + 10

# %%
b1,b2=simplesolve((Vp-a).components[0] ,c.dot(a+b),b1,b2)
# Out:
# $\displaystyle b1 = -3$
# $\displaystyle b2 = 5$

# %%
b=MyVector(b1,b2,sqrt(2))
b
# Out:
# (-3)i+(5)j+(sqrt(2))k

# %%
b.module
# Out:
# 6

# %% [markdown]
# ![imagen.png](attachment:8caa78ce-ca1f-406a-b3e4-a27f0f8a7ab3.png)

# %%
import sys
sys.path.insert(0, 'C:/Libaldo/')
from Libaldomath import *
from lib_MyVector import *

# %% [markdown]
# ![imagen.png](attachment:87f85182-8d50-45d4-ac15-ffbf294eee21.png)

# %%
beta,alpha=symbols('beta alpha')
 
a=MyVector(1,1,1)
b=MyVector(1,-1,1)
c=MyVector(1,-1,-1)
v1=a*alpha+b*beta
v1
# Out:
# (alpha + beta)i+(alpha - beta)j+(alpha + beta)k

# %%
vp=v1.projection(c)

# %%
Q=MQ(vp.module,1/sqrt(3))
# Out:
# $\displaystyle \sqrt{\left(- \frac{\alpha}{3} + \frac{\beta}{3}\right)^{2} + 2 \left(\frac{\alpha}{3} - \frac{\beta}{3}\right)^{2}} = \frac{\sqrt{3}}{3}$

# %%
Q.Pow(2)
# Out:
# $\displaystyle \left(- \frac{\alpha}{3} + \frac{\beta}{3}\right)^{2} + 2 \left(\frac{\alpha}{3} - \frac{\beta}{3}\right)^{2} = \frac{1}{3}$

# %%
Q.expand()
# Out:
# $\displaystyle \frac{\alpha^{2}}{3} - \frac{2 \alpha \beta}{3} + \frac{\beta^{2}}{3} = \frac{1}{3}$

# %%
Q.Mul(3)
# Out:
# $\displaystyle \alpha^{2} - 2 \alpha \beta + \beta^{2} = 1$

# %%
Q.factor()
# Out:
# $\displaystyle \left(\alpha - \beta\right)^{2} = 1$

# %%
Q.Rpow()
# Out:
# $\displaystyle \sqrt{\left(\alpha - \beta\right)^{2}} = 1$

# %%
Q.rsimplify()
# Out:
# $\displaystyle \alpha - \beta = 1$

# %%
alpha=1+beta

# %%
v1=a*alpha+b*beta

# %%
v1
# Out:
# (2*beta + 1)i+j+(2*beta + 1)k
