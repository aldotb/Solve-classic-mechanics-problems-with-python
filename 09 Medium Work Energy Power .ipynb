# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:b6059efa-6959-489e-af7d-f2f257962695.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
Fx,Fy,N1,fr,alpha,t,x,V=symbols('Fx Fy N1 fr alpha t x V',positive=True,real=True)

# %%
m,g,L,a1,=2,10,2,pi/4
xx1,yy1,xx2,yy2=sin(pi/4),cos(pi/4),1,0
P=mparticle(m=2,g=10,x1=xx1,x2=xx2,y1=yy1,y2=yy2,v1=0,v2=V)

# %% [markdown]
# ![imagen.png](attachment:9042bf3d-0727-4b1a-88b7-feec2fc4a6c8.png)

# %%
Fx=MyEq(3*m*g*sin(alpha)*(3*cos(a1)-cos(alpha)),'Fx',kope='x') # 'x' trig_expand
Fy=MyEq(m*g-3*m*g*(1+2*cos(alpha)*cos(a1)-3*kpow(cos(alpha),2))/4,'Fy',kope='x')
# Out:
# $\displaystyle Fx =\left(- 60 \cos{\left(\alpha \right)} + 90 \sqrt{2}\right) \sin{\left(\alpha \right)}$
# $\displaystyle Fy =45 \cos^{2}{\left(\alpha \right)} - 15 \sqrt{2} \cos{\left(\alpha \right)} + 5$

# %%
x1=5*sin(alpha) # x pos in alpha function..
y1=5*cos(alpha) # y pos in alpha function..

# %%
W=MyEq(Fx*x1,'W',var2=alpha,x1=pi/4,x2=pi/2,ktype='I')
# Out:
# $\displaystyle W =\int\limits_{\frac{\pi}{4}}^{\frac{\pi}{2}} \left(- 300 \cos{\left(\alpha \right)} + 450 \sqrt{2}\right) \sin^{2}{\left(\alpha \right)}\, d\alpha$

# %%
W.doit()
# Out:
# $\displaystyle W =-100 + \frac{275 \sqrt{2}}{2} + \frac{225 \sqrt{2} \pi}{4}$

# %%
# Ok what happend with solve integers... I think that sympy  have somes problems with angles
# Ok again... but using my all solve integrate..whit....
Wx=MyEq(Fx*x1,'Wx',var2=alpha,x1=pi/4,x2=pi/2,ktype='I')
# Out:
# $\displaystyle Wx =\int\limits_{\frac{\pi}{4}}^{\frac{\pi}{2}} \left(- 300 \cos{\left(\alpha \right)} + 450 \sqrt{2}\right) \sin^{2}{\left(\alpha \right)}\, d\alpha$

# %%
# and............ ahora pe conchatuma.....re
Wx.doitI()
# Out:
# $\displaystyle Wx =-100 + \frac{275 \sqrt{2}}{2}$

# %%
Wx.opemat('N')
# Out:
# $\displaystyle Wx =94.4543648263006$

# %%
Wy=MyEq(Fy*y1,'Wy',var2=alpha,x1=pi/4,x2=pi/2,ktype='I')
# Out:
# $\displaystyle Wy =\int\limits_{\frac{\pi}{4}}^{\frac{\pi}{2}} \left(225 \cos^{2}{\left(\alpha \right)} - 75 \sqrt{2} \cos{\left(\alpha \right)} + 25\right) \cos{\left(\alpha \right)}\, d\alpha$

# %%
Wy.doitI(kope='N')
# Out:
# $\displaystyle Wy =51.2563132923542$

# %%
Wt=Wx+Wy;Wt
# Out:
# 145.710678118655

# %%
# Energy in tha system is equal to Total Work.. ??? humm let me if are good
V=csolve(P.energia()-Wt,V,'V_f',korden=1)
# Out:
# $\displaystyle V_f =12.6432912543525$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:653cd4cc-f61f-48fe-823c-f119678c3659.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,g,nx = symbols('m g nx',positive=True)

# %%
m=4
g=10
d=2
mu=1/4
N1=m*g
fr=N1*mu

# %%
# Work when pass one time
W=fr*d;W
# Out:
# 20.0

# %%
# Work when pass nx time
Wn=W*nx;Wn
# Out:
# 20.0*nx

# %%
P=mparticle(m=4,g=10,y1=10,y2=0) # only y pos data is relevant

# %%
# Total work will be equal to Potential Energy Total
P.energia('P')
# Out:
# 400

# %%
nn=csolve(Wn-P.energia('P'),nx,'n_t')
# Out:
# $\displaystyle n_t =20.0$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:3ca4d091-353f-4d97-b2eb-ea13feab2ec5.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,g,Fx,fr,N1,b,mu,x,V=symbols('m g Fx fr N1 b mu x V',positive=True)

# %%
# Total work generate by fricction 
mu=frs(1,2)
N1=m*(b-x)*g
fr=N1*mu
W=integrate(fr,(x,b,0))
show_res(W,'W_t')
# Out:
# $\displaystyle W_t =- \frac{b^{2} g m}{4}$

# %%
# a little trick to solve quicky
def Tenergy(m,g,h,v):
    Ek=m*v*v/2
    Ep=m*g*h
    kres=Ek+Ep
    show_res(kres,'E_t')
    return Ek+Ep

# %%
# Total Energy when is droped b long
E1=Tenergy(m*b,g,-b/2,0)
# Out:
# $\displaystyle E_t =- \frac{b^{2} g m}{2}$

# %%
# Total Energy when is droped 2*b long
E2=Tenergy(m*b*2,g,-b,V)
# Out:
# $\displaystyle E_t =V^{2} b m - 2 b^{2} g m$

# %%
show_res(E2-E1,'final_e')
# Out:
# $\displaystyle final_e =V^{2} b m - \frac{3 b^{2} g m}{2}$

# %%
#$create Eq to solve , Et = Wt, find V
e1=e1Q(E2-E1)
# Out:
# $\displaystyle e1 =V^{2} b m - \frac{3 b^{2} g m}{2}$

# %%
V=e1.solve(V,'V',korden=1)
# Out:
# $\displaystyle V =\frac{\sqrt{6} \sqrt{b g}}{2}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:857d7b14-9b21-4573-94ed-c2ef99ceb4e9.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,g,F1,F2,x,V=symbols('m g F1 F2 x V',positive=True)

# %%
F1=15
F2=(2*x+5)
P=mparticle(m=2,g=10,x1=0,x2=x,y1=0,y2=0,v1=0,v2=V)

# %%
P.add_forza(F1,0)
P.add_forza(F2,pi)

# %%
W=MyEq(P.x_res(),'W',var2=x,ktype='I')
# Out:
# $\displaystyle W =\int \left(10 - 2 x\right)\, dx$

# %%
W.doitI()
# Out:
# $\displaystyle W =x \left(10 - 2 x\right)$

# %%
e1=e1Q(W-P.energia(),var2=x)
# Out:
# $\displaystyle e1 =- V^{2} + x \left(10 - 2 x\right)$

# %%
V=e1.solveR(V,'V')
# Out:
# $\displaystyle V =\sqrt{2} \sqrt{x \left(5 - x\right)}$

# %%
ve=V.get_diff('ve')
# Out:
# $\displaystyle ve =- \frac{\sqrt{2} \sqrt{x}}{2 \sqrt{5 - x}} + \frac{\sqrt{2} \sqrt{5 - x}}{2 \sqrt{x}}$

# %%
ve.reduFac()
# Out:
# $\displaystyle ve =2 x - 5$

# %%
x=ve.solve(x,'x')
# Out:
# $\displaystyle x =\frac{5}{2}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:8500fc54-a997-4738-9c8b-d5974d5f268c.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,g,r,alpha,V=symbols('m g r alpha V',positive=True,real=True)

# %%
# Part one.. On circle....
P=mparticle(m=m,g=g,x1=-r,y1=0,x2=r*sin(alpha),y2=-r*cos(alpha),v1=0,v2=V)

# %%
# Total Energy on circle equal cero, find out_V and store
V=MyEq(csolve(P.energia(),V,korden=1),'V')
# Out:
# $\displaystyle V =\sqrt{2} \sqrt{g r \cos{\left(\alpha \right)}}$

# %%
# Part two fly Ball fly..... kinematic seting
B=mparticle(v=V,x1=0,y1=0,a=alpha,y2=0,g=g)

# %%
L=B.x_max();L
# Out:
# 2*r*(sin(alpha) + Abs(sin(alpha)))*cos(alpha)**2

# %%
L=killAbs(L);L # JA jA.....
# Out:
# 4*r*sin(alpha)*cos(alpha)**2

# %%
# Equation of d in alpha function
e1=e1Q(kdiff(L,alpha) )
# Out:
# $\displaystyle e1 =- 8 r \sin^{2}{\left(\alpha \right)} \cos{\left(\alpha \right)} + 4 r \cos^{3}{\left(\alpha \right)}$

# %%
e1.reduFac() # take e1, divide by 4*r and simpli.. and factor
# Out:
# $\displaystyle e1 =- 2 \sin^{2}{\left(\alpha \right)} + \cos^{2}{\left(\alpha \right)}$

# %%
e1.Div(kpow(cos(alpha),2))
# Out:
# $\displaystyle e1 =- \frac{2 \sin^{2}{\left(\alpha \right)}}{\cos^{2}{\left(\alpha \right)}} + 1$

# %%
e1.tsimplify()
# Out:
# $\displaystyle e1 =1 - 2 \tan^{2}{\left(\alpha \right)}$

# %%
e1.solve(alpha,korden=1)
# Out:
# atan(sqrt(2)/2)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:1b7b48c4-1cb9-4801-af76-020c26a4f464.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
V,V1,V2,alpha,L,m,g,h,d1,d2=symbols('V,V1 V2 alpha L m,g h d1 d2',positive=True)
g=10
h=4
m=1
V=rpow(144,2)
Pa=mparticle(m=m,g=g,x1=0,x2=d1,y1=0,y2=0,v1=V,v2=V1)
Pb=mparticle(m=m,g=g,x1=L,x2=d2,y1=0,y2=h,v1=V,v2=V2)

# %% [markdown]
# ![imagen.png](attachment:572d688c-fdc7-42c4-a836-7f468b76de80.png)

# %%
# E1 = Energy Total Initial
E1=Pa.energia('1')+Pb.energia('1') 
E1
# Out:
# 144

# %%
# E1 = Energy Total final
E2=Pa.energia('2')+Pb.energia('2') 
E2
# Out:
# V1**2/2 + V2**2/2 + 40

# %% [markdown]
# ![imagen.png](attachment:1b761939-ec44-4068-9e36-df073e11c589.png)

# %%
# create Equa Velocity same direcction are equal module 
e2=e2Q(V1*cos(pi/4)-V2*cos(alpha-pi/4))
# Out:
# $\displaystyle e2 =\frac{\sqrt{2} V_{1}}{2} - V_{2} \sin{\left(\alpha + \frac{\pi}{4} \right)}$

# %%
e2.texpand()
# Out:
# $\displaystyle e2 =\frac{\sqrt{2} V_{1}}{2} - V_{2} \left(\frac{\sqrt{2} \sin{\left(\alpha \right)}}{2} + \frac{\sqrt{2} \cos{\left(\alpha \right)}}{2}\right)$

# %%
e2.set(sin(alpha),frs(3,5))
# Out:
# $\displaystyle e2 =\frac{\sqrt{2} V_{1}}{2} - V_{2} \left(\frac{\sqrt{2} \cos{\left(\alpha \right)}}{2} + \frac{3 \sqrt{2}}{10}\right)$

# %%
e2.set(cos(alpha),frs(4,5))
# Out:
# $\displaystyle e2 =\frac{\sqrt{2} V_{1}}{2} - \frac{7 \sqrt{2} V_{2}}{10}$

# %%
V2=e2.solve(V2,'V2')
# Out:
# $\displaystyle V2 =\frac{5 V_{1}}{7}$

# %%
e3=e3Q(E1-E2)
# Out:
# $\displaystyle e3 =- \frac{V_{1}^{2}}{2} - \frac{V_{2}^{2}}{2} + 104$

# %%
e3.upgrade(V2)
# Out:
# $\displaystyle e3 =104 - \frac{37 V_{1}^{2}}{49}$

# %%
V1=e3.solve(V1,'V1',korden=1,kope='v')
# Out:
# $\displaystyle V1 =11.7358310199887$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)
