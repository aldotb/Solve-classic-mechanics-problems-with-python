# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:a221421f-1c32-4ebe-93b1-141a393f7ce2.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
# follow steiner formule

# %% [markdown]
# ![imagen.png](attachment:48e2427f-947f-4aa7-b72c-5d6978596556.png)

# %%
P=mparticle()
P.add_Inerce(m,R,R,'c')

# %%
P.get_InerTotal()
# Out:
# 3*R**2*m/2

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:8e1e5be4-4df5-4ad2-9f36-31e3c6c6def9.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %% [markdown]
# ![imagen.png](attachment:82f09ab5-6101-49a9-8356-802d7bb6db99.png)

# %%
In=MyEq(y*y/2,'I',var2=m,ktype='I')
# Out:
# $\displaystyle I =\int \frac{y^{2}}{2}\, dm$

# %%
In.changediffI(V,rho)
# Out:
# $\displaystyle I =\int \frac{\rho y^{2}}{2}\, dV$

# %%
In.changediffI(z,pi*y*y,x1=-R,x2=R)
# Out:
# $\displaystyle I =\int\limits_{- R}^{R} \frac{\pi \rho y^{4}}{2}\, dz$

# %%
In.set(y,rpow(R*R-z*z))
# Out:
# $\displaystyle I =\int\limits_{- R}^{R} \frac{\pi \rho \left(R^{2} - z^{2}\right)^{2}}{2}\, dz$

# %%
In.doitI()
# Out:
# $\displaystyle I =\frac{8 \pi R^{5} \rho}{15}$

# %%
p=pQ(M,4*pi*R*R*R/3)
# Out:
# $\displaystyle \rho\;=\;\frac{3 M}{4 \pi R^{3}}\;$

# %%
In.set(rho,p)
# Out:
# $\displaystyle I =\frac{2 M R^{2}}{5}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:ec08404e-8f49-42c0-ab92-fd361471e8b3.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
P1=mparticle(m=m1,g=g,v1=0)
P1.add_forza(T1,0)
P2=mparticle(m=m2,g=g,v1=0)
P2.addF((T2,pi/2),(m2*g,-pi/2))
P3=mparticle(m=m3,r=R)
P3.addF((T1,pi,0,R),(T2,-pi/2,R,0))

# %%
e1=e1Q(P1.x_res()-m1*a) 
T1=e1.solve(T1,'T1')
# Out:
# $\displaystyle e1 =T_{1} - a m_{1}$
# $\displaystyle T1 =a m_{1}$

# %%
e2=e2Q(P2.y_res()-m2*a) 
T2=e2.solve(T2,'T2')
# Out:
# $\displaystyle e2 =T_{2} - a m_{2} - g m_{2}$
# $\displaystyle T2 =m_{2} \left(a + g\right)$

# %%
To=ToQ(P3)
# Out:
# $\displaystyle To =R T_{1} - R T_{2}$

# %%
To.upgrade(T2,T1)
# Out:
# $\displaystyle To =R a m_{1} - R m_{2} \left(a + g\right)$

# %%
e3=e3Q(To-In*a/(R*R))
# Out:
# $\displaystyle e3 =- \frac{In a}{R^{2}} + R a m_{1} - R m_{2} \left(a + g\right)$

# %%
e3.reduFac()
# Out:
# $\displaystyle e3 =- In a + R^{3} a m_{1} - R^{3} a m_{2} - R^{3} g m_{2}$

# %%
a=e3.solve(a,'a')
# Out:
# $\displaystyle a =\frac{R^{3} g m_{2}}{- In + R^{3} m_{1} - R^{3} m_{2}}$

# %%
T1.upgrade(a)
# Out:
# $\displaystyle T1 =\frac{R^{3} g m_{1} m_{2}}{- In + R^{3} m_{1} - R^{3} m_{2}}$

# %%
T2.upgrade(a)
# Out:
# $\displaystyle T2 =m_{2} \left(\frac{R^{3} g m_{2}}{- In + R^{3} m_{1} - R^{3} m_{2}} + g\right)$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:117c5e8a-c9ac-4f4e-aac0-75d86a24d6ee.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
# first analisis Block P1
B=mparticle()
B.add_forza(F,0)
B.add_forza(fr,pi)
Fx=FxQ(B)
e1=e1Q(Fx-m*a1)
fr=e1.solve(fr,'fr')
# Out:
# $\displaystyle Fx =F - fr$
# $\displaystyle e1 =F - a_{1} m - fr$
# $\displaystyle fr =F - a_{1} m$

# %%
# cylinder P2
C=mparticle(m=M,g=g)
C.add_forza(fr,0,0,-R)
C.add_Inerce(M,r,0,'c')

# %%
eQr=eQrot(C)
# Out:
# $\displaystyle eqR =- \frac{M aw r^{2}}{2} + R \left(F - a_{1} m\right)$

# %%
a2=MyEq(fr/M,'a2')
# Out:
# $\displaystyle a2 =\frac{F - a_{1} m}{M}$

# %%
aw=MyEq((a1-a2)/R,'aw')
# Out:
# $\displaystyle aw =\frac{- a_{1} + \frac{F - a_{1} m}{M}}{R}$

# %%
eQr.upgrade(aw)
# Out:
# $\displaystyle eqR =- \frac{M r^{2} \left(- a_{1} + \frac{F - a_{1} m}{M}\right)}{2 R} + R \left(F - a_{1} m\right)$

# %%
a1=eQr.solve(a1,'a1')
# Out:
# $\displaystyle a1 =\frac{F \left(- 2 R^{2} + r^{2}\right)}{M r^{2} - 2 R^{2} m + m r^{2}}$

# %%
fr.upgrade(a1)
# Out:
# $\displaystyle fr =- \frac{F m \left(- 2 R^{2} + r^{2}\right)}{M r^{2} - 2 R^{2} m + m r^{2}} + F$

# %%
aw.upgrade(a1)
# Out:
# $\displaystyle aw =\frac{- \frac{F \left(- 2 R^{2} + r^{2}\right)}{M r^{2} - 2 R^{2} m + m r^{2}} + \frac{- \frac{F m \left(- 2 R^{2} + r^{2}\right)}{M r^{2} - 2 R^{2} m + m r^{2}} + F}{M}}{R}$

# %%
aw.simplify()
fr.simplify()
a1.simplify()
a2.upgrade(a1,kope='s')
# Out:
# $\displaystyle aw =\frac{2 F R}{M r^{2} - 2 R^{2} m + m r^{2}}$
# $\displaystyle fr =\frac{F M r^{2}}{M r^{2} - 2 R^{2} m + m r^{2}}$
# $\displaystyle a1 =\frac{F \left(- 2 R^{2} + r^{2}\right)}{M r^{2} - 2 R^{2} m + m r^{2}}$
# $\displaystyle a2 =\frac{F r^{2}}{M r^{2} - 2 R^{2} m + m r^{2}}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:9926d9e6-084b-441e-8b1b-aca75b38218b.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %% [markdown]
# ![imagen.png](attachment:8b47558f-0127-490a-9528-a74f0ca6110b.png)

# %%
# From A to B 
AB=mparticle(m=m,g=g,r=R,x1=0,x2=R*sin(alpha),y1=2*R,y2=R*cos(alpha),v1=0,v2=v2,w1=0,w2=w,w=w,Ti=0)

# %%
AB.add_forza(m*g,-pi/2)

# %%
# in B  
e1=e1Q(AB.fcen_due_vel_tang()-AB.fcen_res(pi/2-alpha))
# Out:
# $\displaystyle e1 =- g m \cos{\left(\alpha \right)} + \frac{m v^{2}}{R}$

# %%
v2=e1.solveR(v,'v2')
# Out:
# $\displaystyle v2 =\sqrt{R g \cos{\left(\alpha \right)}}$

# %%
# From B to C  Energy Potential and Rotatory
BC=mparticle(m=m,g=g,r=R,x1=R*sin(alpha),y1=R-R*cos(alpha),y2=0,v1=v2,v=v2,ac=0,w1=v2/R)

# %%
Po=PoQ(BC) # delta Potential Energy of B to C in MyEq format EkP(B)= delta kinetic  Energy
# Out:
# $\displaystyle Po =g m \left(- R \cos{\left(\alpha \right)} + R\right)$

# %%
Er=MyEq(BC.energiaRot('ro1'),'E_r')
# Out:
# $\displaystyle E_r =\frac{In g \cos{\left(\alpha \right)}}{2 R}$

# %%
Ek=MyEq(BC.energia('k1'),'E_k')
# Out:
# $\displaystyle E_k =\frac{R g m \cos{\left(\alpha \right)}}{2}$

# %%
e3=e3Q(Po-Er-Ek)
# Out:
# $\displaystyle e3 =\frac{In g \cos{\left(\alpha \right)}}{2 R} + \frac{R g m \cos{\left(\alpha \right)}}{2} - g m \left(- R \cos{\left(\alpha \right)} + R\right)$

# %%
e3.reduFac()
# Out:
# $\displaystyle e3 =In \cos{\left(\alpha \right)} + 3 R^{2} m \cos{\left(\alpha \right)} - 2 R^{2} m$

# %%
e3.solve(cos(alpha))
# Out:
# 2*R**2*m/(In + 3*R**2*m)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:39239c73-6304-42b7-9063-dd990dc09fd2.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
e1=e1Q(m*v1-v*(m+M))
# Out:
# $\displaystyle e1 =m v_{1} - v \left(M + m\right)$

# %%
v=e1.solve(v,'v')
# Out:
# $\displaystyle v =\frac{m v_{1}}{M + m}$

# %%
C=mparticle()
C.add_cg(m,0,d)
C.add_cg(M,0,L/2)
y=MyEq(C.cgravedad('y'),'y')
# Out:
# $\displaystyle y =\frac{\frac{L M}{2} + d m}{M + m}$

# %%
y.factor()
# Out:
# $\displaystyle y =\frac{L M + 2 d m}{2 M + 2 m}$

# %%
alpha=pi/3
P=mparticle(m=m+M,x1=0,x2=y*sin(alpha),y1=0,y2=y-y*cos(alpha),v1=v,v2=0)

# %%
Et=EtQ(P)
# Out:
# $\displaystyle E_t =\frac{g \left(M + m\right) \left(L M + 2 d m\right)}{4 M + 4 m} - \frac{m^{2} v_{1}^{2}}{2 M + 2 m}$

# %%
Et.reduFac()
# Out:
# $\displaystyle E_t =L M^{2} g + L M g m + 2 M d g m + 2 d g m^{2} - 2 m^{2} v_{1}^{2}$

# %%
V=Et.solveR(v1,'V')
# Out:
# $\displaystyle V =\frac{\sqrt{2} \sqrt{\frac{g \left(L M^{2} + M m \left(L + 2 d\right) + 2 d m^{2}\right)}{m^{2}}}}{2}$

# %%
V.opemat('r')
# Out:
# $\displaystyle V =\frac{\sqrt{2} \sqrt{g} \sqrt{M + m} \sqrt{L M + 2 d m}}{2 m}$
