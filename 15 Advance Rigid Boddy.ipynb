# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %%
from physic_lib2 import * # run this to reset all variablesmm=from physic_lib2 import * # run this to reset all variables

# %% [markdown]
# ![e13_100.png](attachment:721a2966-30a4-454c-bc4d-e425d2c679f0.png)

# %%
A=mparticle()
A.addF((F,0),(m*g,-pi/2-alpha),(N1,pi/2),(f1,pi))
B=mparticle()
B.addF((f1,0),(2*m*g,-pi/2-alpha),(N1,-pi/2),(N2,pi/2),(f2,pi))

# %%
f1=MyEq(N1*mu1,'f1')
f2=MyEq(N2*mu2,'f2')
# Out:
# $\displaystyle f1 =N_{1} \mu_{1}$
# $\displaystyle f2 =N_{2} \mu_{2}$

# %%
Fya=FyQ(A)
N1=Fya.ssolve('N1')
# Out:
# $\displaystyle Fy =N_{1} - g m \cos{\left(\alpha \right)}$
# $\displaystyle N1 =g m \cos{\left(\alpha \right)}$

# %%
Fxa=FxQ(A)
# Out:
# $\displaystyle Fx =F - f_{1} - g m \sin{\left(\alpha \right)}$

# %%
Upgrade(N1,N2,f1,f2,Fxa)
# Out:
# $\displaystyle N1 =g m \cos{\left(\alpha \right)}$
# $\displaystyle f1 =g m \mu_{1} \cos{\left(\alpha \right)}$
# $\displaystyle f2 =N_{2} \mu_{2}$
# $\displaystyle Fx =F - g m \mu_{1} \cos{\left(\alpha \right)} - g m \sin{\left(\alpha \right)}$

# %% [markdown]
# ![imagen.png](attachment:53b518fd-4965-4e58-97ab-c29847c4e0f0.png)

# %%
F=Fxa.ssolve('F')
# Out:
# $\displaystyle F =g m \left(\mu_{1} \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)$

# %%
Fyb=FyQ(B)
# Out:
# $\displaystyle Fy =- N_{1} + N_{2} - 2 g m \cos{\left(\alpha \right)}$

# %%
N2=Fyb.ssolve('N2')
# Out:
# $\displaystyle N2 =N_{1} + 2 g m \cos{\left(\alpha \right)}$

# %%
Upgrade(N1,N2,f1,f2,Fxa,Fyb,F)
# Out:
# $\displaystyle N1 =g m \cos{\left(\alpha \right)}$
# $\displaystyle N2 =3 g m \cos{\left(\alpha \right)}$
# $\displaystyle f1 =g m \mu_{1} \cos{\left(\alpha \right)}$
# $\displaystyle f2 =3 g m \mu_{2} \cos{\left(\alpha \right)}$
# $\displaystyle Fx =- g m \mu_{1} \cos{\left(\alpha \right)} + g m \left(\mu_{1} \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right) - g m \sin{\left(\alpha \right)}$
# $\displaystyle F =g m \left(\mu_{1} \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![e13_200.png](attachment:60635d24-8052-4fc2-a5a6-258eabdd1df9.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
# create and adding  forzas with pos to use torque

fr1=r1*mu
fr2=r2*mu
A=mparticle(m=m,g=g)
A.addF((r2,pi/2),(fr2,0),(4*m*g,-pi/2,2*L*sin(alpha),2*L*cos(alpha)),(m*g,-pi/2,2*L*cos(alpha)-L/2,2*L*sin(alpha)))
A.addF((r1,pi,4*L*cos(alpha),4*L*sin(alpha)),(fr1,pi/2,4*L*cos(alpha),4*L*sin(alpha)))

# %%
Fx=FxQ(A,kope='x')
Fy=FyQ(A,kope='x') # = cero
# Out:
# $\displaystyle Fx =\mu r_{2} - r_{1}$
# $\displaystyle Fy =- 5 g m + \mu r_{1} + r_{2}$

# %% [markdown]
# ![imagen.png](attachment:64572766-414a-4d94-8c09-924a2a119f84.png)

# %%
r1,r1=solvelin(Fx,Fy,r1,r2)  # return MyEq
# Out:
# $\displaystyle r1 =\frac{5 g m \mu}{\mu^{2} + 1}$
# $\displaystyle r2 =\frac{5 g m}{\mu^{2} + 1}$

# %%
To=ToQ(A)
# Out:
# $\displaystyle To =8 L g m \sin{\left(\alpha \right)} - 4 L \mu r_{1} \cos{\left(\alpha \right)} - 4 L r_{1} \sin{\left(\alpha \right)} + g m \left(2 L \cos{\left(\alpha \right)} - \frac{L}{2}\right)$

# %%
To.set('r1',0)
# Out:
# $\displaystyle To =8 L g m \sin{\left(\alpha \right)} + g m \left(2 L \cos{\left(\alpha \right)} - \frac{L}{2}\right)$

# %%
To.reduFac()
# Out:
# $\displaystyle To =16 \sin{\left(\alpha \right)} + 4 \cos{\left(\alpha \right)} - 1$

# %%
#little help because sympy hurt asterisk  when try whit angles..

# %%
To.list() # args list to see what choise...
# Out:
# [-1, 4*cos(alpha), 16*sin(alpha)]

# %%
ToQ=To.toEqual([1])
# Out:
# $\displaystyle 4 \cos{\left(\alpha \right)} = 16 \sin{\left(\alpha \right)} - 1$

# %%
ToQ.Div(4)
# Out:
# $\displaystyle \cos{\left(\alpha \right)} = 4 \sin{\left(\alpha \right)} - \frac{1}{4}$

# %%
ToQ.Pow(2)
# Out:
# $\displaystyle \cos^{2}{\left(\alpha \right)} = \left(4 \sin{\left(\alpha \right)} - \frac{1}{4}\right)^{2}$

# %%
ToQ.expand()
# Out:
# $\displaystyle \cos^{2}{\left(\alpha \right)} = 16 \sin^{2}{\left(\alpha \right)} - 2 \sin{\left(\alpha \right)} + \frac{1}{16}$

# %%
ToQ.cos2sin(alpha)
# Out:
# $\displaystyle 1 - \sin^{2}{\left(\alpha \right)} = 16 \sin^{2}{\left(\alpha \right)} - 2 \sin{\left(\alpha \right)} + \frac{1}{16}$

# %%
To=ToQ.toMyEq('To')
# Out:
# $\displaystyle To =- 17 \sin^{2}{\left(\alpha \right)} + 2 \sin{\left(\alpha \right)} + \frac{15}{16}$

# %%
To.reduFac()
# Out:
# $\displaystyle To =- 272 \sin^{2}{\left(\alpha \right)} + 32 \sin{\left(\alpha \right)} + 15$

# %%
sA=To.solve(sin(alpha),'sA',korden=1,kope='N')
# Out:
# $\displaystyle sA =0.300912906369917$

# %%
alpha=MyEq(rad2sex(asin(sA)),alphaname('alpha'))
# Out:
# $\displaystyle α =17.5124426389433$

# %%
alphaname(beta)
# Out:
# 'ß'

# %%
alphaname(tetha)
# Out:
# 'θ'

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![e13_300.png](attachment:6bfa6c98-0f0e-4509-9967-cd4c3bfcd941.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
P=mparticle()

# %%
P.addF((m*g,-pi/2-alpha,L/2,0),(N1,pi/2,L+x,0),(N2,-pi/2,L+x+d,0),(N1*mu,0,L+x,0),(N2*mu,0,L+x+d,0))

# %%
Fx=FxQ(P);Fy=FyQ(P);To=ToQ(P) # = cero
# Out:
# $\displaystyle Fx =N_{1} \mu + N_{2} \mu - g m \sin{\left(\alpha \right)}$
# $\displaystyle Fy =N_{1} - N_{2} - g m \cos{\left(\alpha \right)}$
# $\displaystyle To =\frac{L g m \cos{\left(\alpha \right)}}{2} - N_{1} \left(L + x\right) + N_{2} \left(L + d + x\right)$

# %%
N1,N2=solvelin(Fx,Fy,N1,N2)
# Out:
# $\displaystyle N1 =\frac{g m \cos{\left(\alpha \right)}}{2} + \frac{g m \sin{\left(\alpha \right)}}{2 \mu}$
# $\displaystyle N2 =- \frac{g m \cos{\left(\alpha \right)}}{2} + \frac{g m \sin{\left(\alpha \right)}}{2 \mu}$

# %%
Upgrade(To,N1,N2,kope='s')
# Out:
# $\displaystyle To =\frac{g m \left(- L \mu \cos{\left(\alpha \right)} - d \mu \cos{\left(\alpha \right)} + d \sin{\left(\alpha \right)} - 2 \mu x \cos{\left(\alpha \right)}\right)}{2 \mu}$
# $\displaystyle N1 =\frac{g m \left(\mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{2 \mu}$
# $\displaystyle N2 =\frac{g m \left(- \mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{2 \mu}$

# %%
To.reduFac()
# Out:
# $\displaystyle To =L \mu \cos{\left(\alpha \right)} + d \mu \cos{\left(\alpha \right)} - d \sin{\left(\alpha \right)} + 2 \mu x \cos{\left(\alpha \right)}$

# %%
To.Div(cos(alpha))
# Out:
# $\displaystyle To =L \mu + d \mu - \frac{d \sin{\left(\alpha \right)}}{\cos{\left(\alpha \right)}} + 2 \mu x$

# %%
To.tsimplify()
# Out:
# $\displaystyle To =L \mu + d \mu - d \tan{\left(\alpha \right)} + 2 \mu x$

# %%
x=To.ssolve(x)
# Out:
# $\displaystyle x =\frac{- L \mu - d \mu + d \tan{\left(\alpha \right)}}{2 \mu}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![e13_400.png](attachment:8fe81986-89ef-4d51-b0ff-1de2168fba13.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
N1=eQsolve(N1*mu*r-m*g*3*r,'N1')
# Out:
# $\displaystyle N1 =\frac{3 g m}{\mu}$

# %%
e2=e2Q(N1*cos(alpha)-m*g)
# Out:
# $\displaystyle e2 =- g m + \frac{3 g m \cos{\left(\alpha \right)}}{\mu}$

# %%
cA=e2.solve(cos(alpha),alphaname('calpha'))
# Out:
# $\displaystyle cos(α) =\frac{\mu}{3}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:896b0132-4427-41c5-9f9c-138aa21de318.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
P=mparticle(m=m,g=g,y1=0,y2=L/2,v1=0,w1=0)
P.add_Inerce(M,L,L/2,'r')
P.add_forza(M*g,-pi/2,L*cos(alpha)/2,-L*sin(alpha)/2)

# %% [markdown]
# ![inerce_rota3.png](attachment:f4e4208c-59ce-4d3f-8414-8b7564f77d4b.png)

# %%
aw=eQrot(P,andsolve='aw')
# Out:
# $\displaystyle a_w =\frac{3 g \cos{\left(\alpha \right)}}{2 L}$

# %%
aw.evalif(alpha=0)
# Out:
# $\displaystyle a_w =\frac{3 g}{2 L}$

# %%
at=eQrot(P,andsolve='at')
# Out:
# $\displaystyle a_t =\frac{3 g \cos{\left(\alpha \right)}}{2}$

# %%
e1=e1Q(P.energia('P')+P.energia_rot())
# Out:
# $\displaystyle e1 =\frac{L^{2} M w_{2}^{2}}{6} - \frac{L M g}{2}$

# %%
w2=e1.ssolveR('w2')
# Out:
# $\displaystyle w2 =\sqrt{3} \sqrt{\frac{g}{L}}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:7e8aa5c0-355f-472d-8738-fc19024a87ca.png)

# %%
from physic_lib2 import * # run this to reset all variables
x1=-R*cos(alpha+tetha)
x2=R*cos(tetha-alpha)
y1=-R*sin(alpha+tetha)
y2=-R*sin(tetha-alpha)

# %%
P1=mparticle()
P1.add_forza(k*m*g,-pi/2)
P1.add_forza(F1,alpha+tetha)
P1.add_forza(Nm,pi-alpha)

# %%
Fx1=FxQ(P1,'Fx1')
Fy1=FyQ(P1,'Fy1')
# Out:
# $\displaystyle Fx1 =F_{1} \cos{\left(\alpha + \theta \right)} - Nm \cos{\left(\alpha \right)}$
# $\displaystyle Fy1 =F_{1} \sin{\left(\alpha + \theta \right)} + Nm \sin{\left(\alpha \right)} - g k m$

# %%
Nm,F1=solvelin(Fx1,Fy1,Nm,F1)
# Out:
# $\displaystyle Nm =\frac{g k m \cos{\left(\alpha + \theta \right)}}{\sin{\left(\alpha \right)} \cos{\left(\alpha + \theta \right)} + \sin{\left(\alpha + \theta \right)} \cos{\left(\alpha \right)}}$
# $\displaystyle F1 =\frac{g k m \cos{\left(\alpha \right)}}{\sin{\left(\alpha \right)} \cos{\left(\alpha + \theta \right)} + \sin{\left(\alpha + \theta \right)} \cos{\left(\alpha \right)}}$

# %%
P2=mparticle()
P2.add_forza(m*g,-pi/2)
P2.add_forza(F2,pi-tetha+alpha)
P2.add_forza(Nm,alpha)

# %%
Fx2=FxQ(P2,'Fx2')
Fy2=FyQ(P2,'Fy2')
# Out:
# $\displaystyle Fx2 =- F_{2} \cos{\left(\alpha - \theta \right)} + \frac{g k m \cos{\left(\alpha \right)} \cos{\left(\alpha + \theta \right)}}{\sin{\left(\alpha \right)} \cos{\left(\alpha + \theta \right)} + \sin{\left(\alpha + \theta \right)} \cos{\left(\alpha \right)}}$
# $\displaystyle Fy2 =- F_{2} \sin{\left(\alpha - \theta \right)} + \frac{g k m \sin{\left(\alpha \right)} \cos{\left(\alpha + \theta \right)}}{\sin{\left(\alpha \right)} \cos{\left(\alpha + \theta \right)} + \sin{\left(\alpha + \theta \right)} \cos{\left(\alpha \right)}} - g m$

# %%
F2=Fx2.ssolve('F2')
# Out:
# $\displaystyle F2 =\frac{g k m \cos{\left(\alpha \right)} \cos{\left(\alpha + \theta \right)}}{\sin{\left(2 \alpha + \theta \right)} \cos{\left(\alpha - \theta \right)}}$

# %%
P=mparticle()
P.add_forza(k*m*g,-pi/2,x1,y1)
P.add_forza(F1,alpha+tetha,x1,y1)
P.add_forza(m*g,-pi/2,x2,y2)
P.add_forza(F2,pi-tetha+alpha,x2,y2)

# %%
To=ToQ(P)
# Out:
# $\displaystyle To =- R g k m \cos{\left(\alpha + \theta \right)} + R g m \cos{\left(\alpha - \theta \right)}$

# %%
To.reduFac()
# Out:
# $\displaystyle To =k \cos{\left(\alpha + \theta \right)} - \cos{\left(\alpha - \theta \right)}$

# %%
To.texpand()
# Out:
# $\displaystyle To =k \left(- \sin{\left(\alpha \right)} \sin{\left(\theta \right)} + \cos{\left(\alpha \right)} \cos{\left(\theta \right)}\right) - \sin{\left(\alpha \right)} \sin{\left(\theta \right)} - \cos{\left(\alpha \right)} \cos{\left(\theta \right)}$

# %%
T3=MyTriang(hipo=R,cat2=L/2)

# %%
To.upTriang(tetha,T3)
# Out:
# $\displaystyle To =- \frac{L \cos{\left(\alpha \right)}}{2 R} + k \left(\frac{L \cos{\left(\alpha \right)}}{2 R} - \frac{\sqrt{- \frac{L^{2}}{4} + R^{2}} \sin{\left(\alpha \right)}}{R}\right) - \frac{\sqrt{- \frac{L^{2}}{4} + R^{2}} \sin{\left(\alpha \right)}}{R}$

# %%
To.expand()
# Out:
# $\displaystyle To =\frac{L k \cos{\left(\alpha \right)}}{2 R} - \frac{L \cos{\left(\alpha \right)}}{2 R} - \frac{k \sqrt{- \frac{L^{2}}{4} + R^{2}} \sin{\left(\alpha \right)}}{R} - \frac{\sqrt{- \frac{L^{2}}{4} + R^{2}} \sin{\left(\alpha \right)}}{R}$

# %%
To.factor()
# Out:
# $\displaystyle To =\frac{L k \cos{\left(\alpha \right)} - L \cos{\left(\alpha \right)} - k \sqrt{- L^{2} + 4 R^{2}} \sin{\left(\alpha \right)} - \sqrt{- L^{2} + 4 R^{2}} \sin{\left(\alpha \right)}}{2 R}$

# %%
To.reduFac()
# Out:
# $\displaystyle To =L k \cos{\left(\alpha \right)} - L \cos{\left(\alpha \right)} - k \sqrt{- L^{2} + 4 R^{2}} \sin{\left(\alpha \right)} - \sqrt{- L^{2} + 4 R^{2}} \sin{\left(\alpha \right)}$

# %%
To.factorSec(cos(alpha))
# Out:
# $\displaystyle To =- k \sqrt{- L^{2} + 4 R^{2}} \sin{\left(\alpha \right)} - \sqrt{- L^{2} + 4 R^{2}} \sin{\left(\alpha \right)} + \left(L k - L\right) \cos{\left(\alpha \right)}$

# %%
To.factorSec(sin(alpha))
# Out:
# $\displaystyle To =\left(L k - L\right) \cos{\left(\alpha \right)} + \left(- k \sqrt{- L^{2} + 4 R^{2}} - \sqrt{- L^{2} + 4 R^{2}}\right) \sin{\left(\alpha \right)}$

# %%
To.Div(cos(alpha))
# Out:
# $\displaystyle To =L k - L + \frac{\left(- k \sqrt{- L^{2} + 4 R^{2}} - \sqrt{- L^{2} + 4 R^{2}}\right) \sin{\left(\alpha \right)}}{\cos{\left(\alpha \right)}}$

# %%
To.tsimplify()
# Out:
# $\displaystyle To =L k - L + \left(- k \sqrt{- L^{2} + 4 R^{2}} - \sqrt{- L^{2} + 4 R^{2}}\right) \tan{\left(\alpha \right)}$

# %%
Ta=To.solve(tan(alpha),alphaname('talpha'))
# Out:
# $\displaystyle tan(α) =\frac{L \left(k - 1\right)}{\sqrt{- L^{2} + 4 R^{2}} \left(k + 1\right)}$

# %%
Ta.set(L,R)
# Out:
# $\displaystyle tan(α) =\frac{\sqrt{3} R \left(k - 1\right)}{\left(3 k + 3\right) \sqrt{R^{2}}}$

# %%
Ta.killSimpleRoot()
# Out:
# $\displaystyle tan(α) =\frac{\sqrt{3} \left(k - 1\right)}{3 k + 3}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)
