# %%
# load library
import sys
sys.path.insert(0, 'C:/Libaldo/')
from lib_Physics import *

# %% [markdown]
# ![image.png](attachment:dd64e8a2-2111-4e7f-ab38-12ee3380729e.png)

# %%
# for integrales include this library
from lib_MyIntegral import *

# %%
# integral expretion....
A=MyIntg(3*x+ln(sin(x)),'A',var=x)
# A=MyIntg(math expr, 'name', diff var)
# Out:
# $\displaystyle A = \int \left(3 x + \log{\left(\sin{\left(x \right)} \right)}\right)\, dx$

# %%
# or ...
A=MyIntg(3*x+ln(sin(x)),'A',var=x,x1=0,x2=pi/2)
# A=MyIntg(math expr, 'name', diff var, limit x1, limit x2)
# Out:
# $\displaystyle A = \int\limits_{0}^{\frac{\pi}{2}} \left(3 x + \log{\left(\sin{\left(x \right)} \right)}\right)\, dx$

# %%
# from MyEq...expretion...
A=MyEq(x*3+2*x**2+3*x-10,'A')
# Out:
# $\displaystyle A = 2 x^{2} + 6 x - 10$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from lib_Physics import *

# %% [markdown]
# ![image.png](attachment:cdc2fb4b-d248-4da8-8778-243828ad1249.png)![imagen.png](attachment:66e1eeb5-92fd-46f7-85cb-0c770374512a.png)

# %%
# K=MyEq(A,'eQ') : return equation called 'eQ' and value is A
v=MyEq(t**3-4*t*t+5,'v',var=t)
# Out:
# $\displaystyle v = t^{3} - 4 t^{2} + 5$

# %%
Q=MQ(v,dx/dt) # MQ(A,B) or MyEqEq(A,B) : return equation obj  as A = B
# Out:
# $\displaystyle t^{3} - 4 t^{2} + 5 = \frac{dx}{dt}$

# %%
Q.alone(dx) # alone is put dx in lkeft side and the rest in right side
# Out:
# $\displaystyle dx = dt \left(t^{3} - 4 t^{2} + 5\right)$

# %%
Q.Integral() # applied Integral both side
# Out:
# $\displaystyle \int 1\, dx = \int \left(t^{3} - 4 t^{2} + 5\right)\, dt$

# %%
Q.doitI() # sole the Integral
# Out:
# $\displaystyle x = C + \frac{t^{4}}{4} - \frac{4 t^{3}}{3} + 5 t$

# %%
Q.alone(C,x=4,t=2) # mean solve C when x=4 and t=2
# Out:
# $\displaystyle C = \frac{2}{3}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *

# %% [markdown]
# ![imagen.png](attachment:0b142c2c-bb08-420f-b35d-5281b2859c1c.png)

# %%
# V=MyEq(A,'eQ') : return equation called 'eQ' and value is A
v=MyEq(4-2*t*t,'v',var=t)
# Out:
# $\displaystyle v = 4 - 2 t^{2}$

# %%
Q=MQ(v,dx/dt) # MQ(A,B) or MyEqEq(A,B) : return equation obj  as A = B
# Out:
# $\displaystyle 4 - 2 t^{2} = \frac{dx}{dt}$

# %%
Q.alone(dx) # alone is put dx in lkeft side and the rest in right side
# Out:
# $\displaystyle dx = 2 dt \left(2 - t^{2}\right)$

# %%
Q.Integral() # applied Integral both side
# Out:
# $\displaystyle \int 1\, dx = \int \left(4 - 2 t^{2}\right)\, dt$

# %%
Q.doitI() # sole the Integral
# Out:
# $\displaystyle x = C - \frac{2 t^{3}}{3} + 4 t$

# %%
Q.alone(C,x=0,t=0) # mean solve C when x=4 and t=2
# Out:
# $\displaystyle C = 0$

# %%
# solution a
X=MyEq(4*t-2*t**3/3,'x',var=t)
# Out:
# $\displaystyle x = - \frac{2 t^{3}}{3} + 4 t$

# %%
v.diff()
# Out:
# -4*t

# %%
Q2=MQ(dv,v.diff()*dt)
# Out:
# $\displaystyle dv = - 4 dt t$

# %%
Q2.Div(dt)
# Out:
# $\displaystyle \frac{dv}{dt} = - 4 t$

# %%
# solution b
Q2.setL(a)
# Out:
# $\displaystyle a = - 4 t$

# %%
# solucion c
t1=simplesolve(v,t,positive=True)

# %%
# solucion c comprobation
v(t1)
# Out:
# 0

# %%
# solucion d:
Q2(t=sqrt(2))
# Out:
# $\displaystyle a = - 4 \sqrt{2}$
