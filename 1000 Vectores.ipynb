# %% [markdown]
# * Lib lib_MyVec:
#
#     * V=MyVector(direx,diry,dirz,origin=(ox,oy,oz),F=vector magnitud)
#     * V.x,V.y,V.z = gets components in i,j k
#     * V.one() vector unitario
#     * V.veccomp get componets(x,y,z)
#     * V.R Forza module
#     * V.Matriz convert to MyMatrix
#     * V.moment() get torque
#
# * Vector applications help
#
#     * find_unitary(vec)
#     * find_resultant(vec)
#     * find_moment(vec)

# %%
from Libaldomath import *
from lib_MyVec import *
from MyMatrix import *

# %% [markdown]
# ![image.png](attachment:f7d0a6f9-9e03-4d0d-b1bd-89a7df2858a8.png)

# %%
A=MyVector(1,2,2)

# %%
A.module
# Out:
# 3

# %%
A.x
# Out:
# 1

# %%
A.y
# Out:
# 2

# %%
A.z
# Out:
# 2

# %%
A.one()
# Out:
# (1/3) i_N + (2/3) j_N + (2/3) k_N

# %%
A.veccomp()
# Out:
# (1, 2, 2)

# %%
A.Matrix()
# Out:
# [1  2  2]

# %% [markdown]
# ![image.png](attachment:f7d0a6f9-9e03-4d0d-b1bd-89a7df2858a8.png)

# %%
B1=MyVector(1,2,2)
B2=MyVector(2,0,-2,origin=(0,0,2))
B3=MyVector(2,1,0,origin=(0,1,2))

# %%
find_resultant(B1,B2,B3)
# Out:
# $\displaystyle \;\;find\;V1+V2+V3\;$
# $\displaystyle \;for\;each\;vector\;include\;in\;args:\;we\;will\;separate\;by\;type\;axes\;i,\;j,\;k$
# $\displaystyle \;Rx,\;Ry,\;Rz\;=\;0,0,0$
# $\displaystyle \;for\;i\;in\;args:$
# $\displaystyle \;\;\;\;\;\;\;\;x\;,y\;,z\;=\left( 1, \  2, \  2\right)$
# $\displaystyle \;\;\;\;\;\;\;\;Rx\;,Ry\;,Rz\;=1\;,\;\;2\;,\;\;2$
# $\displaystyle \;next..$
# $\displaystyle \;\;\;\;\;\;\;\;x\;,y\;,z\;=\left( 2, \  0, \  -2\right)$
# $\displaystyle \;\;\;\;\;\;\;\;Rx\;,Ry\;,Rz\;=3\;,\;\;2\;,\;\;0$
# $\displaystyle \;next..$
# $\displaystyle \;\;\;\;\;\;\;\;x\;,y\;,z\;=\left( 2, \  1, \  0\right)$
# $\displaystyle \;\;\;\;\;\;\;\;Rx\;,Ry\;,Rz\;=5\;,\;\;3\;,\;\;0$
# $\displaystyle \;next..$
# $\displaystyle \;kres\;=\;MyVector(Rx,Ry,Rz)$
# $\displaystyle \left(5\right)\mathbf{\hat{i}_{N}} + \left(3\right)\mathbf{\hat{j}_{N}}$

# %%
B1+(B2+B3)
# Out:
# (5) i_N + (3) j_N

# %% [markdown]
# ![image.png](attachment:f7d0a6f9-9e03-4d0d-b1bd-89a7df2858a8.png)

# %%
from Libaldomath import *
from lib_MyVec import *
from MyMatrix import *

# %%
C=MyVector(2,1,0,origin=(0,1,2),F=400)

# %%
C.moment()
# Out:
# (-160⋅√5) i_N + (320⋅√5) j_N + (-160⋅√5) k_N

# %%
find_moment(C)
# Out:
# $\displaystyle \;whith\;this\;sample\;Vector$
# $\displaystyle \;\;\;\;\;\;\;\;V=\;MyVector(2\;,1\;,0\;origin=\left( 0, \  1, \  2\right)\;F=400\;)$
# $\displaystyle \;direction\;=2\;\;\;,1\;\;\;,0$
# $\displaystyle \;N\;=\;CoordSys3D('N')$
# $\displaystyle \;Uv\;=\;[N.i,N.j,N.k]$
# $\displaystyle \;\;creatibg\;matrix\;to\;find\;determinant$
# $\displaystyle \;H\;=\;MyMat(Uv,vec.MatrixO()\;,vec.Matrix())$
# $\displaystyle \;\;result\;=\;H.D$
# $\displaystyle \left(- 160 \sqrt{5}\right)\mathbf{\hat{i}_{N}} + \left(320 \sqrt{5}\right)\mathbf{\hat{j}_{N}} + \left(- 160 \sqrt{5}\right)\mathbf{\hat{k}_{N}}$
# $\displaystyle \;call:\;vec.moment()$

# %%
C.moment()
# Out:
# (-160⋅√5) i_N + (320⋅√5) j_N + (-160⋅√5) k_N

# %% [markdown]
# ![image.png](attachment:85ee9ec6-a845-4f88-9052-2154dc5b30a7.png)

# %% [markdown]
# ![image.png](attachment:dfdcab34-8abf-45b4-bdce-c3709ea52b65.png)

# %%
from Libaldomath import *
from lib_MyVec import *
from MyMatrix import *

# %%
Q1=MQ(x,a+2*k)
Q2=MQ(x+6*k,b)
# Out:
# $\displaystyle x = a + 2 k$
# $\displaystyle 6 k + x = b$

# %%
x=Q1.solve('x',k=Q2.solve(k))
# Out:
# $\displaystyle x =\frac{3 a}{4} + \frac{b}{4}$

# %% [markdown]
# ![image.png](attachment:85ee9ec6-a845-4f88-9052-2154dc5b30a7.png)

# %% [markdown]
# ![image.png](attachment:0c9ac388-f7bc-4946-ae51-590320efaf61.png)

# %%
from Libaldomath import *
from lib_MyVec import *

# %%
Q1=MQ(a+b+c+d,0)
Q2=MQ(2*x,a/2+b+c/2)
# Out:
# $\displaystyle a + b + c + d = 0$
# $\displaystyle 2 x = \frac{a}{2} + b + \frac{c}{2}$

# %%
Q1.Substrac(b+d)
# Out:
# $\displaystyle a + c = - b - d$

# %%
Q2.Mul(2)
# Out:
# $\displaystyle 4 x = a + 2 b + c$

# %%
Q2.Substrac(2*b)
# Out:
# $\displaystyle - 2 b + 4 x = a + c$

# %%
Q2.setR(Q1.R)
# Out:
# $\displaystyle - 2 b + 4 x = - b - d$

# %%
x=Q2.solve('x')
# Out:
# $\displaystyle x =\frac{b}{4} - \frac{d}{4}$

# %% [markdown]
# ![image.png](attachment:85ee9ec6-a845-4f88-9052-2154dc5b30a7.png)

# %%
from Libaldomath import *
from lib_MyVec import *

# %% [markdown]
# ![image.png](attachment:2b99f78e-65ef-498f-be56-0f047a5a282c.png)

# %%
A=MyVector(2,3,0)
B=MyVector(1,1,0)

# %%
A+B
# Out:
# (3) i_N + (4) j_N

# %%
find_resultant(A,B)
# Out:
# $\displaystyle \;\;find\;V1+V2+V3\;$
# $\displaystyle \;for\;each\;vector\;include\;in\;args:\;we\;will\;separate\;by\;type\;axes\;i,\;j,\;k$
# $\displaystyle \;Rx,\;Ry,\;Rz\;=\;0,0,0$
# $\displaystyle \;for\;i\;in\;args:$
# $\displaystyle \;\;\;\;\;\;\;\;x\;,y\;,z\;=\left( 2, \  3, \  0\right)$
# $\displaystyle \;\;\;\;\;\;\;\;Rx\;,Ry\;,Rz\;=2\;,\;\;3\;,\;\;0$
# $\displaystyle \;next..$
# $\displaystyle \;\;\;\;\;\;\;\;x\;,y\;,z\;=\left( 1, \  1, \  0\right)$
# $\displaystyle \;\;\;\;\;\;\;\;Rx\;,Ry\;,Rz\;=3\;,\;\;4\;,\;\;0$
# $\displaystyle \;next..$
# $\displaystyle \;kres\;=\;MyVector(Rx,Ry,Rz)$
# $\displaystyle \left(3\right)\mathbf{\hat{i}_{N}} + \left(4\right)\mathbf{\hat{j}_{N}}$

# %% [markdown]
# ![image.png](attachment:85ee9ec6-a845-4f88-9052-2154dc5b30a7.png)

# %%
from Libaldomath import *
from lib_MyVec import *

# %% [markdown]
# ![image.png](attachment:6e789b63-595c-4049-9f40-e01ac49f1bea.png)

# %%
A=MyVector(0,-2,0)
B=MyVector(2,2,2)
C=MyVector(-2,2,0)
D=MyVector(-2,0,0)
F=MyVector(2,0,-2)

# %%
(A+B)+(C+D)+F()
# Out:
# (2) j_N

# %% [markdown]
# ![image.png](attachment:85ee9ec6-a845-4f88-9052-2154dc5b30a7.png)

# %%
from Libaldomath import *
from lib_MyVec import *

# %% [markdown]
# ![image.png](attachment:08140425-4f71-40ed-911d-505d8d92234c.png)

# %%
P=MyVector(x,y,z)
A=MyVector(-4,-2,2)

# %%
find_unitary(A)
# Out:
# $\displaystyle \;vec.one()$
# $\displaystyle \;if\;\;\;vec=\;\;xi\;+yj\;+zk\;\;\;then:$
# $\displaystyle \;R=\sqrt{x^{2} + y^{2} + z^{2}}$
# $\displaystyle \;VecUnitary\;\;\;is\;:\frac{x}{\sqrt{x^{2} + y^{2} + z^{2}}}\;+\frac{y}{\sqrt{x^{2} + y^{2} + z^{2}}}\;+\frac{z}{\sqrt{x^{2} + y^{2} + z^{2}}}$
# $\displaystyle \;finding\;\;\;\;\;\;components\;\;\;i,j,k\;\;of\;\;vec$
# $\displaystyle \;x=-4\;,y=-2\;,z=2$
# $\displaystyle \;R=2 \sqrt{6}$
# $\displaystyle \;componets\;\;unitary\;\;are\;\;:\;x=- \frac{\sqrt{6}}{3}\;,y=- \frac{\sqrt{6}}{6}\;,z=\frac{\sqrt{6}}{6}$
# $\displaystyle \left(- \frac{\sqrt{6}}{3}\right)\mathbf{\hat{i}_{N}} + \left(- \frac{\sqrt{6}}{6}\right)\mathbf{\hat{j}_{N}} + \left(\frac{\sqrt{6}}{6}\right)\mathbf{\hat{k}_{N}}$
# $\displaystyle \;type\;\;\;Vec.one()$

# %%
A.one()
# Out:
# ⎛-√6 ⎞       ⎛-√6 ⎞       ⎛√6⎞
# ⎜────⎟ i_N + ⎜────⎟ j_N + ⎜──⎟ k_N
# ⎝ 3  ⎠       ⎝ 6  ⎠       ⎝6 ⎠

# %%
B=MyVector(k*A.one())
Q=MQ(rsimplify(B.module),sqrt(6))
# Out:
# $\displaystyle k = \sqrt{6}$

# %%
B=MyVector(sqrt(6)*A.one())

# %%
B.s()
# Out:
# $\displaystyle - 2 i - j + k$

# %% [markdown]
# ![image.png](attachment:85ee9ec6-a845-4f88-9052-2154dc5b30a7.png)

# %%
from Libaldomath import *
from lib_MyVec import *

# %% [markdown]
# ![image.png](attachment:08140425-4f71-40ed-911d-505d8d92234c.png)

# %%
A=MyVector(-6,4,2)
A1=MyVector(a*A.one())
Q1=MQ(rsimplify(A1.module),sqrt(14))
# Out:
# $\displaystyle a = \sqrt{14}$

# %%
A1=MyVector(sqrt(14)*A.one())
A1.s()
# Out:
# $\displaystyle - 3 i + 2 j + k$

# %%
B=MyVector(-6,4,0)
B1=MyVector(b*B.one())
Q2=MQ(rsimplify(B1.module),sqrt(13))
# Out:
# $\displaystyle b = \sqrt{13}$

# %%
B1=MyVector(sqrt(13)*B.one())
B1.s()
# Out:
# $\displaystyle - 3 i + 2 j$

# %%
A-B
# Out:
# (2) k_N
