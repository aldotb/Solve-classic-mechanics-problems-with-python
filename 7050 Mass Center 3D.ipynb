# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:5f1eaaa0-d188-4222-bc0d-2c3234f18e9c.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P1=MyIntg(z*dm,'P1',var=m,x1=0,x2=h)
# Out:
# $\displaystyle P1=\int\limits_{0}^{h} z\, dm$

# %%
P1.setdiff(z,rho*pi*x*x)
# Out:
# $\displaystyle P1=\int\limits_{0}^{h} \pi \rho x^{2} z\, dz$

# %%
P2=MyIntg(dm,'P2',var=m,x1=0,x2=h)
# Out:
# $\displaystyle P2=\int\limits_{0}^{h} \,dm$

# %%
P2.setdiff(z,rho*pi*x*x)
# Out:
# $\displaystyle P2=\int\limits_{0}^{h} \pi \rho x^{2}\, dz$

# %%
Q1=MQ(x/(h-z),R/h)
# Out:
# $\displaystyle \frac{x}{h - z} = \frac{R}{h}$

# %%
x=Q1.solve('x')
# Out:
# $\displaystyle x =\frac{R \left(h - z\right)}{h}$

# %%
Cy=MyEq(P1()/P2(),'Cy')
# Out:
# $\displaystyle Cy =\frac{\int\limits_{0}^{h} \pi \rho x^{2} z\, dz}{\int\limits_{0}^{h} \pi \rho x^{2}\, dz}$

# %%
Cy.set(x)
# Out:
# $\displaystyle Cy =\frac{\int\limits_{0}^{h} \frac{\pi R^{2} \rho z \left(h - z\right)^{2}}{h^{2}}\, dz}{\int\limits_{0}^{h} \frac{\pi R^{2} \rho \left(h - z\right)^{2}}{h^{2}}\, dz}$

# %%
Cy.doit()
# Out:
# $\displaystyle Cy =\frac{h}{4}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:2d890804-ade8-4afe-b59d-56491f4d5406.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
V=4*r**3/3
rho=M/(2*V)

# %%
P1=MyIntg(z*dm,'P1',var=m,x1=0,x2=r)
# Out:
# $\displaystyle P1=\int\limits_{0}^{r} z\, dm$

# %%
# dm=rho*dv thren...
P1.setdiff(v,rho*dv)
# Out:
# $\displaystyle P1=\int\limits_{0}^{r} \frac{3 M z}{8 r^{3}}\, dv$

# %%
# dv=area * espesor..., 
# espezor = dz
# area = pi*x*x.... but put x in x(z)..then
# x=sqrt(r*r-z*z)
# then dv = pi*(r*r-z*z)*dz

# %%
P1.setdiff(z,pi*(r*r-z*z)*dz)
# Out:
# $\displaystyle P1=\int\limits_{0}^{r} \frac{3 \pi M z \left(r^{2} - z^{2}\right)}{8 r^{3}}\, dz$

# %%
P2=MyIntg(dm,'P2',var=m,x1=0,x2=r)
# Out:
# $\displaystyle P2=\int\limits_{0}^{r} \,dm$

# %%
P2.setdiff(v,rho*dv)
# Out:
# $\displaystyle P2=\int\limits_{0}^{r} \frac{3 M}{8 r^{3}}\, dv$

# %%
P2.setdiff(z,pi*(r*r-z*z)*dz)
# Out:
# $\displaystyle P2=\int\limits_{0}^{r} \frac{3 \pi M \left(r^{2} - z^{2}\right)}{8 r^{3}}\, dz$

# %%
P1.doit()/P2.doit()
# Out:
# 3⋅r
# ───
#  8

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:28d75e36-df33-48d3-b814-98c9037ebc17.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P1=My2Intg(y,'P1',varx=y,vary=x,x1=sin(x),x2=cos(x),y1=0,y2=pi/4)
# Out:
# $\displaystyle P1=\int\limits_{0}^{\frac{\pi}{4}}\int\limits_{\sin{\left(x \right)}}^{\cos{\left(x \right)}} y\, dy\, dx$

# %%
P1.doit()
# Out:
# 1/4

# %%
df=MyEq(cos(x)-sin(x),'df')
# Out:
# $\displaystyle df =- \sin{\left(x \right)} + \cos{\left(x \right)}$

# %%
Cy=My2Intg(x*y*dx*dy,'Cy',varx=y,vary=x,x1=sin(x),x2=cos(x),y1=0,y2=pi/4)
# Out:
# $\displaystyle Cy=\int\limits_{0}^{\frac{\pi}{4}}\int\limits_{\sin{\left(x \right)}}^{\cos{\left(x \right)}} x y\, dy\, dx$

# %%
Cy.doit()
# Out:
#   1   π
# - ─ + ──
#   8   16

# %%
Yc=Cy.doit()/P1.doit()

# %%
Yc
# Out:
#   1   π
# - ─ + ─
#   2   4
