# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:6f6601a8-9505-41c7-9fa0-3ec791e1b098.png)

# %%
P=phybody(r=L*sin(alpha))

# %%
P.add_weight()
P.add_forza(T,pi/2-alpha)

# %%
Fy=P.Fy()
# Out:
# $\displaystyle Fy =T \cos{\left(\alpha \right)} - g m$

# %%
T=Fy.solve('T')
# Out:
# $\displaystyle T =\frac{g m}{\cos{\left(\alpha \right)}}$

# %%
P.set(T)

# %%
Fc=P.Fx()
# Out:
# $\displaystyle Fx =\frac{g m \sin{\left(\alpha \right)}}{\cos{\left(\alpha \right)}}$

# %%
Q=MQ(Fc,m*P.v*P.v/P.r)
# Out:
# $\displaystyle \frac{g m \sin{\left(\alpha \right)}}{\cos{\left(\alpha \right)}} = \frac{m v^{2}}{L \sin{\left(\alpha \right)}}$

# %%
Q.simplify()
# Out:
# $\displaystyle \frac{g}{\cos{\left(\alpha \right)}} = \frac{v^{2}}{L \sin^{2}{\left(\alpha \right)}}$

# %%
v=Q.solve(v,'positive')
# Out:
# $\displaystyle v=\sqrt{\frac{L g}{\cos{\left(\alpha \right)}}} \sin{\left(\alpha \right)}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:f90d56f6-96fc-47fb-a911-2dfe12cbe0c8.png)

# %%
P=phybody()

# %%
P.add_weight()

# %%
P.add_forza(T,pi/2+tetha2)

# %%
Q1=MQ(P.fyrelative(tetha2),v*v*m/L)
# Out:
# $\displaystyle T - g m \cos{\left(𝜃_{2} \right)} = \frac{m v^{2}}{L}$

# %%
P.fxrelative(tetha2+pi)
# Out:
# g⋅m⋅sin(𝜃₂)

# %%
Q2=MQ(P.fxrelative(tetha2+pi),m*at)
# Out:
# $\displaystyle g m \sin{\left(𝜃_{2} \right)} = a_{t} m$

# %%
Q2.simplify()
# Out:
# $\displaystyle g \sin{\left(𝜃_{2} \right)} = a_{t}$

# %%
Q2.swap()
# Out:
# $\displaystyle a_{t} = g \sin{\left(𝜃_{2} \right)}$

# %%
Q3=MQ(v,g*sin(tetha)*L)
# Out:
# $\displaystyle v = L g \sin{\left(\theta \right)}$

# %%
Q3.integral(v,tetha,'',[tetha2,tetha1])
# Out:
# $\displaystyle \int v\, dv = \int\limits_{𝜃_{2}}^{𝜃_{1}} L g \sin{\left(\theta \right)}\, d\theta$

# %%
Q3.doit()
# Out:
# $\displaystyle \frac{v^{2}}{2} = - L g \cos{\left(𝜃_{1} \right)} + L g \cos{\left(𝜃_{2} \right)}$

# %%
v=Q3.solve('v','pos')
# Out:
# $\displaystyle v =- \sqrt{2} \sqrt{- L g \left(\cos{\left(𝜃_{1} \right)} - \cos{\left(𝜃_{2} \right)}\right)}$

# %%
Q1.set(v)
# Out:
# $\displaystyle T - g m \cos{\left(𝜃_{2} \right)} = - 2 g m \left(\cos{\left(𝜃_{1} \right)} - \cos{\left(𝜃_{2} \right)}\right)$

# %%
T=Q1.solve('T')
# Out:
# $\displaystyle T =g m \left(- 2 \cos{\left(𝜃_{1} \right)} + 3 \cos{\left(𝜃_{2} \right)}\right)$

# %%
Q4=MQ(P.fyrelative(tetha2),an*m)
# Out:
# $\displaystyle T - g m \cos{\left(𝜃_{2} \right)} = a_{n} m$

# %%
Q4.set(T)
# Out:
# $\displaystyle g m \left(- 2 \cos{\left(𝜃_{1} \right)} + 3 \cos{\left(𝜃_{2} \right)}\right) - g m \cos{\left(𝜃_{2} \right)} = a_{n} m$

# %%
Q4.alone(an)
# Out:
# $\displaystyle a_{n} = 2 g \left(- \cos{\left(𝜃_{1} \right)} + \cos{\left(𝜃_{2} \right)}\right)$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:98b68228-379f-481d-9846-8f3e2f48d514.png)

# %%
P=phybody()
tetha=pi/2-alpha

# %%
P.add_weight()
P.add_forza(N1,tetha)

# %%
Q1=MQ(m*v*v/R,P.fyrelative(-tetha))
# Out:
# $\displaystyle \frac{m v^{2}}{R} = \left(2 N_{1} \cos{\left(\alpha \right)} - g m\right) \sin{\left(\alpha \right)}$

# %%
def eQtangencial(self,ang=alpha):
    QQ=MQ(self.fxrelative(-pi/2+ang),self.m*self.at)
    return QQ

# %%
Qt=eQtangencial(P,ang=tetha)
# Out:
# $\displaystyle g m \sin{\left(\alpha \right)} = a_{t} m$

# %%
def eQnormal(self,ang=alpha):
    QQ=MQ(self.fyrelative(-pi/2+ang),-1*self.m*self.an)
    return QQ

# %%
Qn=eQnormal(P,ang=tetha)
# Out:
# $\displaystyle N_{1} - g m \cos{\left(\alpha \right)} = - a_{n} m$

# %%
Qt.simplify()
# Out:
# $\displaystyle g \sin{\left(\alpha \right)} = a_{t}$

# %%
Qt.swap()
# Out:
# $\displaystyle a_{t} = g \sin{\left(\alpha \right)}$

# %%
Qt.set(at=dv/dt)
# Out:
# $\displaystyle \frac{dv}{dt} = g \sin{\left(\alpha \right)}$

# %%
Qt.Mul(ds)
# Out:
# $\displaystyle \frac{ds dv}{dt} = ds g \sin{\left(\alpha \right)}$

# %%
Qt.subs(ds/dt,v)
# Out:
# $\displaystyle dv v = ds g \sin{\left(\alpha \right)}$

# %%
Qt.subs(ds,R*dalpha)
# Out:
# $\displaystyle dv v = R d𝛼 g \sin{\left(\alpha \right)}$

# %%
Qt.integral(v,alpha)
# Out:
# $\displaystyle \int v\, dv = \int R g \sin{\left(\alpha \right)}\, d\alpha$

# %%
Qt.doit()
# Out:
# $\displaystyle \frac{v^{2}}{2} = - R g \cos{\left(\alpha \right)}$

# %%
Qt.subs(cos(alpha),cos(pi/2-alpha))
# Out:
# $\displaystyle \frac{v^{2}}{2} = - R g \sin{\left(\alpha \right)}$

# %%
str(Qt.R)
# Out:
# '-R*g*cos(alpha)'

# %%
dtetha
# Out:
# d𝜃

# %%
Qt.doit()
# Out:
# $\displaystyle \frac{v^{2}}{2} = R g \sin{\left(\alpha \right)}$

# %%
v=Qt.solve('v','pos')
# Out:
# $\displaystyle v =\sqrt{2} \sqrt{R g \sin{\left(\alpha \right)}}$

# %%
Qn=eQnormal(P,ang=alpha)
# Out:
# $\displaystyle N_{1} - g m \sin{\left(\alpha \right)} = - a_{n} m$

# %%
Q1()
# Out:
# $\displaystyle \frac{m v^{2}}{R} = \frac{m v^{2}}{R}$

# %%
Q1=MQ(m*v*v/R,P.fyrelative(-alpha))
# Out:
# $\displaystyle 2 g m \sin{\left(\alpha \right)} = \left(2 N_{1} \sin{\left(\alpha \right)} - g m\right) \cos{\left(\alpha \right)}$

# %%
N1=Qn.solve(N1)
# Out:
# $\displaystyle N1=g m \left(1 - 2 m\right) \sin{\left(\alpha \right)}$

# %%
alpha
# Out:
# α
