# %%
from physic_lib2 import * # run this to reset all variables

# %% [markdown]
#  ![aclara1.png](attachment:0c19e7a7-8725-4c6f-ad96-0d0772e0af6d.png)

# %% [markdown]
# ### Medium Dynamic Mechanic Physics Problems

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![dM010.png](attachment:287ee3fa-0a9d-492b-9b1f-5b925cc6796f.png)

# %%
# creating variables 
m,F1,Na,Nb=symbols('m F1 Na Nb')

# %%
# creating A object and adding  Forces
A=mparticle()
A.addF((10*m,-pi/3),(F,pi),(Na,pi/2))

# %%
# F_1=  solve F1 from Fx/mass = 1 and convert in MyEq
F=MyEq(csolve(A.simple_ac()-1,F),'F')
# Out:
# $\displaystyle F =4 m$

# %%
# creating B object and adding  Forces
B=mparticle()   
B.add_forza(F.v,-pi/6)# = F1 =F_1.v, value of Eq F1
B.add_forza(Nb,pi/2)
B.add_forza(10*m,-pi/2)

# %%
Ac=MyEq(B.simple_ac(),'Ac')
# Out:
# $\displaystyle Ac =2 \sqrt{3}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![dM020.png](attachment:8de09ab2-9e61-44cd-b5dc-4b58cd679655.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,M,g,T,V,ac,h,x=symbols('m M g T V a_c h x',positive=True)

# %%
A=mparticle(m=m,g=g,y1=0,y2=-h,a=pi/2,ac=0,v1=0,v2=-V)
B=mparticle(m=M,g=g,y1=0,y2=h,a=pi/2,ac=0,v1=0,v2=V)

# %%
A.add_forza(m*g,-pi/2) #weight
A.add_forza(T,pi/2) # Tension
B.add_forza(M*g,-pi/2) #weight
B.add_forza(T,pi/2) # Tension

# %%
e1=e1Q(A.energia()-A.y_res()*h)
e2=e2Q(B.energia()-B.y_res()*h,kope='r')
# Out:
# $\displaystyle e1 =\frac{V^{2} m}{2} - g h m - h \left(T - g m\right)$
# $\displaystyle e2 =\frac{M V^{2}}{2} + M g h - h \left(- M g + T\right)$

# %%
h=e2.solve(h,'h')
# Out:
# $\displaystyle h =- \frac{M V^{2}}{4 M g - 2 T}$

# %%
e1.upgrade(h)
# Out:
# $\displaystyle e1 =\frac{M V^{2} g m}{4 M g - 2 T} + \frac{M V^{2} \left(T - g m\right)}{4 M g - 2 T} + \frac{V^{2} m}{2}$

# %%
T=e1.solve(T,'T')
# Out:
# $\displaystyle T =\frac{2 M g m}{- M + m}$

# %%
e2.upgrade(T)
# Out:
# $\displaystyle e2 =\frac{M V^{2}}{2} + M g h - h \left(\frac{2 M g m}{- M + m} - M g\right)$

# %%
V=e2.solveR(V,'V')
# Out:
# $\displaystyle V =2 \sqrt{\frac{M g h}{- M + m}}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![dM030.png](attachment:f8e3ee9e-79a9-40f6-b658-674f1eedd6af.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
alpha,L,m,g,mu,N1,fr,L2=symbols('alpha L m g mu N1 fr L2',positive=True)

# %%
#  take note that  we take  AB like axis X
A=mparticle(v1=0,m=m,g=g,x1=0,x2=L,y1=0,y2=0)
A.add_forza(m*g,-pi/2+alpha) # adding weight
A.add_forza(fr,pi)# adding fr

# %%
A.set(fr,-A.y_res()*mu) # inside class A replace fr by Fy_res

# %%
#  set W like MyEq(Fx* dist('x') also applied factor() and name W_1... y ya..
W_1=MyEq(A.work_due_forza('x',kope='f'),'W_1') # Work1 from A 2 B = Fx*L
# Out:
# $\displaystyle W_1 =- L g m \left(\mu \cos{\left(\alpha \right)} - \sin{\left(\alpha \right)}\right)$

# %%
B=mparticle(m=m,g=g,x1=0,x2=L2,y1=0,y2=0) 
B.add_forza(m*g*mu,pi)

# %%
W_2=MyEq(B.work_due_forza('x',kope='f'),'W_2') # Work= Fx*(x2-x1)
# Out:
# $\displaystyle W_2 =- L_{2} g m \mu$

# %%
# Total Work = cero because Vel ini and Vel final equal cero
L2=csolve(W_1.v+W_2.v,L2,'L2') # Find L2
# Out:
# $\displaystyle L2 =\frac{L \left(- \mu \cos{\left(\alpha \right)} + \sin{\left(\alpha \right)}\right)}{\mu}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![dM040.png](attachment:134e5cc4-c52b-4f78-8cb1-506ce4193930.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
M,m,g,N1,Fr,ac=symbols('M m g N_1 F_r a_c',positive=True)

# %%
A=mparticle(m=m)
A.add_forza(m*g,-pi/2)
A.add_forza(N1,0)
A.add_forza(8*N1/10,pi/2)

# %%
A.set(N1,csolve(A.y_res(),N1)) # set is short form of setValue.. take note

# %%
Ac=MyEq(A.simple_ac(),'A_c')
# Out:
# $\displaystyle A_c =\frac{5 g}{4}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  <img src="images/dM050.png" alt="ml" style="width : 60%;"/>

# %% [markdown]
#  <img src="images/tip3.png" alt="ml" style="width : 100%;"/>

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m, w=symbols('m w',positive=True)

# %%
P=mparticle(m=m,g=10,r=10,w=w) # mass ,gravity, radio , velo angl.

# %% [markdown]
#  ![fc_due.png](attachment:fb33ce36-87cf-4dcd-9934-789b9a59c288.png)

# %%
P.fcen_due_vel_ang()  # a ñlittle sample upper function
# Out:
#       2
# 10⋅m⋅w

# %%
# F centripeta = Normal = Frozz/mu = m*s/mu
W=csolve(P.fcen_due_vel_ang()-10*m*4,w,'w_a',kpositive=True)
# Out:
# $\displaystyle w_a =2$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![dM060.png](attachment:cc5c6a38-082c-4d30-83f7-931dc60d53ce.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
F1,T,m,g,a,fr,fr2,mu,N1=symbols('F1 T m g a fr fr2 mu N1',positive=True)

# %%
# in A ...first Eq F = mass * accelll
a_1=MyEq(F1/(5*m+m+m),'a_1')
f_r=MyEq(-m*g*mu,'f_r')
T_1=MyEq(m*a-fr,'T_1')
# Out:
# $\displaystyle a_1 =\frac{F_{1}}{7 m}$
# $\displaystyle f_r =- g m \mu$
# $\displaystyle T_1 =a m - fr$

# %%
T_1.set([fr,a],[f_r.v,a_1.v])
# Out:
# $\displaystyle T_1 =\frac{F_{1}}{7} + g m \mu$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![dM070.png](attachment:bbb5a91e-027c-43e9-8e00-3ec76498452f.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,g,T,Aa,Ab=symbols('m g T Aa Ab',positive=True)

# %%
#relation between mass
ma=m
mb=5*m/3
Aa=3*Ab # for gromrtry

# %%
A_a=MyEq((T-ma*g)/ma,'A_a')
# Out:
# $\displaystyle A_a =\frac{T - g m}{m}$

# %%
A_b=MyEq((mb*g-3*T)/mb,'A_b')
# Out:
# $\displaystyle A_b =\frac{- 9 T + 5 g m}{5 m}$

# %%
e1=e1Q(A_a.v-3*A_b.v)
# Out:
# $\displaystyle e1 =\frac{T - g m}{m} + \frac{27 T - 15 g m}{5 m}$

# %%
T1=MyEq(e1.solve(T),'T_1')
# Out:
# $\displaystyle T_1 =\frac{5 g m}{8}$

# %%
A_a.setValue(T,T1.v)
A_b.setValue(T,T1.v)
# Out:
# $\displaystyle A_a =- \frac{3 g}{8}$
# $\displaystyle A_b =- \frac{g}{8}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![dM080.png](attachment:ec8f10f5-a6bc-4647-9f02-6f55e49c3cd7.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
L,m,g,F1,alpha,x,h,V2=symbols('L m g F1 alpha x h V2',positive=True)

# %% [markdown]
#  ![MyTriang.png](attachment:69f4d319-e8f9-489c-8c97-ad3a1a5756d8.png)

# %%
get_hipo(h,L-x)
# Out:
#    _______________
#   ╱  2          2
# ╲╱  h  + (L - x)

# %%
T3=MyTriang(cat1=h,cat2=L-x)
T3.sin()
# Out:
#         h
# ──────────────────
#    _______________
#   ╱  2          2
# ╲╱  h  + (L - x)

# %%
T3.cos()
# Out:
#       L - x
# ──────────────────
#    _______________
#   ╱  2          2
# ╲╱  h  + (L - x)

# %%
W=MyInteger(F1*T3.cos(),x,'W_o',x1=0,x2=L)
# Out:
# $\displaystyle W_o\;=\;\int\limits_{0}^{L} \frac{F_{1} \left(L - x\right)}{\sqrt{h^{2} + \left(L - x\right)^{2}}}\, dx\;$

# %% [markdown]
#  <img src="images/dM080a.png" alt="ml" style="width : 60%;"/>

# %%
P=mparticle(m=m,x1=0,y1=0,x2=L,y2=0,v1=0,v2=V2)

# %%
P.energia()
# Out:
#   2
# V₂ ⋅m
# ─────
#   2

# %%
# Work Total = Energy Total, whit this find V final
Vf=csolve(P.energia()-W.doit(),V2,'V_f',korden=0)
# Out:
# $\displaystyle V_f =- \sqrt{2} \sqrt{\frac{F_{1} h \left(\sqrt{\frac{L^{2} + h^{2}}{h^{2}}} - 1\right)}{m}}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![J200.png](attachment:597124d8-471a-4240-97ef-7fa8523d1ccb.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,M,g,T,fr1,fr2,mu,N1,N2,F1=symbols(' m M g T fr1 fr2 mu N! N2 F1')

# %% [markdown]
#  ![J200a.png](attachment:258352a4-8624-4c2e-a7ec-52b56f100c9b.png)

# %%
e1=e1Q(T-m*g*mu-m*2*a) # from P1
e2=e2Q(F1-T-m*g*mu-(m+M)*g*mu -(M+m)*a)  # from P2
# Out:
# $\displaystyle e1 =T - 2 a m - g m \mu$
# $\displaystyle e2 =F_{1} - T - a \left(M + m\right) - g m \mu - g \mu \left(M + m\right)$

# %%
a1=e2.set(T,e1.solve(T),andsolve=(a,'a_c'))
# Out:
# $\displaystyle a_c =\frac{F_{1} - M g \mu - 3 g m \mu}{M + 3 m}$

# %%
T1=e1.set(a,a_1.v,andsolve=(T,'T'))
# Out:
# $\displaystyle T =\frac{2 F_{1}}{7} + g m \mu$

# %%
Q=MyBag()
Q.store([m,M,g,F1,mu],[2,5,frs(98,10),30,frs(2,10)])
# Out:
# $\displaystyle m\;=\;2\;$
# $\displaystyle M\;=\;5\;$
# $\displaystyle g\;=\;\frac{49}{5}\;$
# $\displaystyle F_{1}\;=\;30\;$
# $\displaystyle \mu\;=\;\frac{1}{5}\;$

# %%
a_1.upBag(Q)
T1.upBag(Q)
# Out:
# $\displaystyle a_1 =\frac{15}{7}$
# $\displaystyle T =\frac{2186}{175}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![G100.png](attachment:482b523d-acb0-4b81-b5f1-2ada03336add.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,M,g,T1,T2,f1,f2,a1,a2,Tx,Ty =symbols(' m M g T1 T2 f1 f2 a1 a2 Tx Ty')

# %% [markdown]
#  ![G100a.png](attachment:0429e37e-c1e1-49d1-a593-34094d8c0ab3.png)

# %%
# from A T1=Tx+Ty vectors
Ty=m*g
Tx=m*a1

# %%
e0=e0Q(M*a1-(T1+T2-m*a1))  # from B
e1=e1Q(m*g-T2-m*a1) # from D
e2=e2Q(M*g-T1-M*a2) # from C
e3=e3Q(T1-get_hipo(Tx,Ty,kope='r'))
# Out:
# $\displaystyle e0 =M a_{1} - T_{1} - T_{2} + a_{1} m$
# $\displaystyle e1 =- T_{2} - a_{1} m + g m$
# $\displaystyle e2 =- M a_{2} + M g - T_{1}$
# $\displaystyle e3 =T_{1} - m \sqrt{a_{1}^{2} + g^{2}}$

# %% [markdown]
# ![MyEqSys1.png](attachment:254b09bb-a288-47ee-8a35-20c43ef0ecaa.png)

# %%
# [ M,g,m] are know variable or ther will be solve in function of these
A=MyEqSys([e0,e1,e2,e3],[M,g,m])
# Out:
# $\displaystyle e0 =M a_{1} - T_{1} - T_{2} + a_{1} m$
# $\displaystyle e1 =- T_{2} - a_{1} m + g m$
# $\displaystyle e2 =- M a_{2} + M g - T_{1}$
# $\displaystyle e3 =T_{1} - m \sqrt{a_{1}^{2} + g^{2}}$

# %% [markdown]
# ![MyEqSys2.png](attachment:5f168a72-972c-42c6-9a33-11d25a0f29bb.png)

# %%
A.solvefrom(T2,1)
# Out:
# $\displaystyle e0 =M a_{1} - T_{1} + 2 a_{1} m - g m$
# $\displaystyle e1 =- T_{2} - a_{1} m + g m$
# $\displaystyle e2 =- M a_{2} + M g - T_{1}$
# $\displaystyle e3 =T_{1} - m \sqrt{a_{1}^{2} + g^{2}}$

# %%
A.solvefrom(T1,0)
# Out:
# $\displaystyle e0 =- M^{2} T_{1} + M^{2} g m - 4 M T_{1} m + 4 M g m^{2} - 3 T_{1} m^{2} + 5 g m^{3}$
# $\displaystyle e1 =M^{2} T_{2} - M^{2} g m + 4 M T_{2} m - 2 M g m^{2} + 3 T_{2} m^{2} + g m^{3}$
# $\displaystyle e2 =M^{3} a_{2} - M^{3} g + 4 M^{2} a_{2} m - 3 M^{2} g m + 3 M a_{2} m^{2} + M g m^{2} + 5 g m^{3}$
# $\displaystyle a1 =\frac{2 g m \left(M + 2 m\right)}{M^{2} + 4 M m + 3 m^{2}}$

# %%
A.solvefrom(a2,2)
# Out:
# $\displaystyle a1 =\frac{2 g m \left(M + 2 m\right)}{M^{2} + 4 M m + 3 m^{2}}$
# $\displaystyle a2 =\frac{g \left(M^{3} + 3 M^{2} m - M m^{2} - 5 m^{3}\right)}{M \left(M^{2} + 4 M m + 3 m^{2}\right)}$
# $\displaystyle T1 =\frac{g m \left(M^{2} + 4 M m + 5 m^{2}\right)}{M^{2} + 4 M m + 3 m^{2}}$
# $\displaystyle T2 =\frac{g m \left(M^{2} + 2 M m - m^{2}\right)}{M^{2} + 4 M m + 3 m^{2}}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![we7.png](attachment:0029eae0-3f2f-47e8-a4cf-c4512c4a12a6.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,g,alpha,L,a1,a2,Vb,Vc,t,T,x,h =symbols('m g alpha L a1 a2  Vb Vc t T x h')

# %% [markdown]
#  ![we7a.png](attachment:bb3ff53b-24fb-4dde-8199-57bd0927e633.png)

# %%
# Accek C ) A1, Accel B=a2 
e1=e1Q(a1/x-a2/(121*L-h))
# Out:
# $\displaystyle e1 =\frac{a_{1}}{x} - \frac{a_{2}}{121 L - h}$

# %%
Tr3=MyTriang(cat1=11*L,cat2=x)

# %%
e1.set(h,Tr3.hipo)
# Out:
# $\displaystyle e1 =\frac{a_{1}}{x} - \frac{a_{2}}{121 L - \sqrt{121 L^{2} + x^{2}}}$

# %%
e1.reduFac()
# Out:
# $\displaystyle e1 =- 121 L a_{1} + a_{1} \sqrt{121 L^{2} + x^{2}} + a_{2} x$

# %%
a_1=MyEq(e1.solve(a1),'a_1')
# Out:
# $\displaystyle a_1 =\frac{a_{2} x}{121 L - \sqrt{121 L^{2} + x^{2}}}$

# %%
# anlisis of  C 
# In this case is neccesary reput.. all args... note y2=60 geometry deducc..
C=mparticle(m=4*m,g=g,x1=0,x2=0,y1=121*L,y2=60,v1=0,v2=Vc,ac=0)
# Forzas in C..
C.add_weight()
C.add_forza(T,alpha)
C.add_forza(T,pi-alpha)

# %%
# anlisis of  B 
# also is neccesary fill all args... note y2=60 geometry deducc..
B=mparticle(m=m,g=-g,x1=0,x2=0,y1=0,y2=61,v1=0,v2=Vb,ac=0)
# Forzas in C..
B.add_weight()
B.add_forza(T,pi/2)

# %%
V_c=MyEq(csolveR(C.energia(),Vc),'V_c')
# Out:
# $\displaystyle V_c =\sqrt{2} \sqrt{g \left(121 L - 60\right)}$

# %%
V_b=MyEq(csolveR(B.energia(),Vb),'V_b')
# Out:
# $\displaystyle V_b =\sqrt{122} \sqrt{g}$

# %%
e2=e2Q(61-a1*t*t/2) # X=Xo+Vi*t-a*t*t/2
# Out:
# $\displaystyle e2 =- \frac{a_{1} t^{2}}{2} + 61$

# %%
a_1=MyEq(e2.solve(a1),'a_1',)
# Out:
# $\displaystyle a_1 =\frac{122}{t^{2}}$

# %%
e3=e3Q(60-a2*t*t/2) # X=Xo+Vi*t-a*t*t/2
# Out:
# $\displaystyle e3 =- \frac{a_{2} t^{2}}{2} + 60$

# %%
a_2=MyEq(e3.solve(a2),'a_2',)
# Out:
# $\displaystyle a_2 =\frac{120}{t^{2}}$

# %%
sE([' Solution a_1/a_2 =',a_1.v/a_2.v])
# Out:
# $\displaystyle Solution\;a_1/a_2\;=\;\frac{61}{60}\;$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![centri1.png](attachment:d6fe77f9-e4df-4c7f-b3b6-1691fc46bc15.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,g,w,an,theta,N1,x=symbols('m g w a_n  theta N_1 x')

# %%
e0=e0Q(N1*cos(theta)-m*g)
e1=e1Q(N1*sin(theta)-m*w*w*x*cos(theta))
# Out:
# $\displaystyle e0 =N_{1} \cos{\left(\theta \right)} - g m$
# $\displaystyle e1 =N_{1} \sin{\left(\theta \right)} - m w^{2} x \cos{\left(\theta \right)}$

# %%
x1=e1.set(N1,e0.solve(N1),andsolve=(x,'x'))
# Out:
# $\displaystyle x =\frac{g \sin{\left(\theta \right)}}{w^{2} \cos^{2}{\left(\theta \right)}}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![centri2.png](attachment:83b2e286-9870-4613-9a95-dbbfacda901c.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,g,w,R,L,alpha,x,T=symbols('m g w R L alpha x T')

# %%
P=mparticle(m=m,g=g,r=x) # is important declare radius in circular dynamic
P.add_forza(m*g,-pi/2)
P.add_forza(T,pi/2-alpha)

# %%
Fx=FxQ(P)
Fy=FyQ(P)
# Out:
# $\displaystyle Fx =T \sin{\left(\alpha \right)}$
# $\displaystyle Fy =T \cos{\left(\alpha \right)} - g m$

# %%
# if Fy=0 then cos(alpha)=g*m/T
# My Triang to set sin and cos...
T3=MyTriang(hipo=T,cat2=g*m)
# teh sin(alpha) wll be..
T3.sin()
# Out:
#    ____________
#   ╱  2    2  2
# ╲╱  T  - g ⋅m
# ───────────────
#        T

# %%
e0=e0Q(P.fcen_due_vel_ang()-Fx.v) # Fcent=Fx=m*w*w*r
e1=e1Q(Fy.v) # sFy=0
e2=e2Q(x-L*cos(alpha)) # X=radio total
# Out:
# $\displaystyle e0 =- T \sin{\left(\alpha \right)} + m w^{2} x$
# $\displaystyle e1 =T \cos{\left(\alpha \right)} - g m$
# $\displaystyle e2 =- L \cos{\left(\alpha \right)} + x$

# %%
A=MyEqSys([e0,e1,e2],[m,g,L,w,]);
# Out:
# $\displaystyle e0 =- T \sin{\left(\alpha \right)} + m w^{2} x$
# $\displaystyle e1 =T \cos{\left(\alpha \right)} - g m$
# $\displaystyle e2 =- L \cos{\left(\alpha \right)} + x$

# %%
A.set(sin(alpha),T3.sin())
# Out:
# $\displaystyle e0 =m w^{2} x - \sqrt{T^{2} - g^{2} m^{2}}$
# $\displaystyle e1 =T \cos{\left(\alpha \right)} - g m$
# $\displaystyle e2 =- L \cos{\left(\alpha \right)} + x$

# %%
A.solvefrom(cos(alpha),1)
# Out:
# $\displaystyle e0 =m w^{2} x - \sqrt{T^{2} - g^{2} m^{2}}$
# $\displaystyle e1 =T \cos{\left(\alpha \right)} - g m$
# $\displaystyle e2 =- L g m + T x$

# %%
x1=e2.solve(x,'x_1')
# Out:
# $\displaystyle x_1 =\frac{L g m}{T}$

# %%
e0.set(x,x1.v)
# Out:
# $\displaystyle e0 =\frac{L g m^{2} w^{2}}{T} - \sqrt{T^{2} - g^{2} m^{2}}$

# %%
A.ss()
# Out:
# $\displaystyle e0 =\frac{L g m^{2} w^{2}}{T} - \sqrt{T^{2} - g^{2} m^{2}}$
# $\displaystyle e1 =T \cos{\left(\alpha \right)} - g m$
# $\displaystyle e2 =- L g m + T x$

# %%
e3=e3Q(e0.list(1))
e4=e4Q(e0.list(0))
# Out:
# $\displaystyle e3 =\frac{L g m^{2} w^{2}}{T}$
# $\displaystyle e4 =- \sqrt{T^{2} - g^{2} m^{2}}$

# %%
B=MyEqEq(e3,e4)
# Out:
# $\displaystyle \frac{L g m^{2} w^{2}}{T} = - \sqrt{T^{2} - g^{2} m^{2}}\;$

# %%
B.Pow(2)
# Out:
# $\displaystyle \frac{L^{2} g^{2} m^{4} w^{4}}{T^{2}} = T^{2} - g^{2} m^{2}\;$

# %%
T2=B.solve(T*T,'T_2',korden=1)
# Out:
# $\displaystyle T_2 =\frac{g m^{2} \left(g + \sqrt{4 L^{2} w^{4} + g^{2}}\right)}{2}$

# %%
T1=MyEq(rpow(T2.v),'T')
# Out:
# $\displaystyle T =\frac{\sqrt{2} \sqrt{g m^{2} \left(g + \sqrt{4 L^{2} w^{4} + g^{2}}\right)}}{2}$

# %%
e2.s()
# Out:
# $\displaystyle e2 =- L g m + T x$

# %%
x1=e2.solve(x,'X')
# Out:
# $\displaystyle X =\frac{L g m}{T}$

# %%
x1.set(T,T1.v)
# Out:
# $\displaystyle X =\frac{\sqrt{2} L g m}{\sqrt{g m^{2} \left(g + \sqrt{4 L^{2} w^{4} + g^{2}}\right)}}$

# %%
T3.cos()
# Out:
# g⋅m
# ───
#  T

# %%
ac=MyEq(T3.cos(),'cos_a')
# Out:
# $\displaystyle cos_a =\frac{g m}{T}$

# %%
ac.set(T,T1.v)
# Out:
# $\displaystyle cos_a =\frac{\sqrt{2} g m}{\sqrt{g m^{2} \left(g + \sqrt{4 L^{2} w^{4} + g^{2}}\right)}}$

# %%
T1.s();x1.s();ac.s()
# Out:
# $\displaystyle T =\frac{\sqrt{2} \sqrt{g m^{2} \left(g + \sqrt{4 L^{2} w^{4} + g^{2}}\right)}}{2}$
# $\displaystyle X =\frac{\sqrt{2} L g m}{\sqrt{g m^{2} \left(g + \sqrt{4 L^{2} w^{4} + g^{2}}\right)}}$
# $\displaystyle cos_a =\frac{\sqrt{2} g m}{\sqrt{g m^{2} \left(g + \sqrt{4 L^{2} w^{4} + g^{2}}\right)}}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![centri3.png](attachment:6b3dab33-888f-4e70-ba17-7c2c8edce27d.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
m,M,g,L,k,x,alpha,Fc,T1,T2=symbols('m M g L k x alpha Fc T1 T2')

# %%
# with A
A=mparticle(m=m,g=g,r=L*cos(alpha),w=w)
A.add_forza(T1,alpha)
A.add_forza(T2,-alpha)
A.add_forza(m*g,-pi/2)

# %%
Fx=FxQ(A)
Fy=FyQ(A)
# Out:
# $\displaystyle Fx =T_{1} \cos{\left(\alpha \right)} + T_{2} \cos{\left(\alpha \right)}$
# $\displaystyle Fy =T_{1} \sin{\left(\alpha \right)} - T_{2} \sin{\left(\alpha \right)} - g m$

# %%
e0=e0Q(A.fcentripeta()-Fx.v) # Fcentri in A  = Fx
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - T_{2} \cos{\left(\alpha \right)}$

# %%
e1=e1Q(Fy.v)
# Out:
# $\displaystyle e1 =T_{1} \sin{\left(\alpha \right)} - T_{2} \sin{\left(\alpha \right)} - g m$

# %%
# with B
B=mparticle(m=M,g=g)
B.add_forza(T2,alpha)
B.add_forza(T2,pi-alpha)
B.add_forza(M*g,-pi/2)

# %%
e2=e2Q(B.y_res()+k*x)
# Out:
# $\displaystyle e2 =- M g + 2 T_{2} \sin{\left(\alpha \right)} + k x$

# %%
e3=e3Q(2*L-2*L*sin(alpha)-x)
# Out:
# $\displaystyle e3 =- 2 L \sin{\left(\alpha \right)} + 2 L - x$

# %% [markdown]
# ![MyEqSys2.png](attachment:edcc8274-f823-4305-9889-becab4fb169a.png)

# %%
e0.s();e1.s();e2.s();e3.s()
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - T_{2} \cos{\left(\alpha \right)}$
# $\displaystyle e1 =T_{1} \sin{\left(\alpha \right)} - T_{2} \sin{\left(\alpha \right)} - g m$
# $\displaystyle e2 =- M g + 2 T_{2} \sin{\left(\alpha \right)} + k x$
# $\displaystyle e3 =- 2 L \sin{\left(\alpha \right)} + 2 L - x$

# %%
upgrade(e0,e1,e2,e3,x,T1,T2)
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - T_{2} \cos{\left(\alpha \right)}$
# $\displaystyle e1 =T_{1} \sin{\left(\alpha \right)} - T_{2} \sin{\left(\alpha \right)} - g m$
# $\displaystyle e2 =- M g + 2 T_{2} \sin{\left(\alpha \right)} + k x$
# $\displaystyle e3 =- 2 L \sin{\left(\alpha \right)} + 2 L - x$

# %%
x=e3.solve(x,'x')
# Out:
# $\displaystyle x =2 L \left(1 - \sin{\left(\alpha \right)}\right)$

# %%
upgrade(e0,e1,e2,e3,x,T1,T2)
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - T_{2} \cos{\left(\alpha \right)}$
# $\displaystyle e1 =T_{1} \sin{\left(\alpha \right)} - T_{2} \sin{\left(\alpha \right)} - g m$
# $\displaystyle e2 =2 L k \left(1 - \sin{\left(\alpha \right)}\right) - M g + 2 T_{2} \sin{\left(\alpha \right)}$
# $\displaystyle e3 =- 2 L \left(1 - \sin{\left(\alpha \right)}\right) - 2 L \sin{\left(\alpha \right)} + 2 L$
# $\displaystyle x =2 L \left(1 - \sin{\left(\alpha \right)}\right)$

# %%
T2=e2.solve(T2,'T2')
# Out:
# $\displaystyle T2 =\frac{L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2}}{\sin{\left(\alpha \right)}}$

# %%
upgrade(e0,e1,e2,e3,x,T1,T2)
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - \frac{\left(L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2}\right) \cos{\left(\alpha \right)}}{\sin{\left(\alpha \right)}}$
# $\displaystyle e1 =- L k \sin{\left(\alpha \right)} + L k - \frac{M g}{2} + T_{1} \sin{\left(\alpha \right)} - g m$
# $\displaystyle e2 =2 L k \left(1 - \sin{\left(\alpha \right)}\right) + 2 L k \sin{\left(\alpha \right)} - 2 L k$
# $\displaystyle e3 =- 2 L \left(1 - \sin{\left(\alpha \right)}\right) - 2 L \sin{\left(\alpha \right)} + 2 L$
# $\displaystyle x =2 L \left(1 - \sin{\left(\alpha \right)}\right)$
# $\displaystyle T2 =\frac{L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2}}{\sin{\left(\alpha \right)}}$

# %%
T1=e1.solve(T1,'T1')
# Out:
# $\displaystyle T1 =\frac{L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2} + g m}{\sin{\left(\alpha \right)}}$

# %%
upgrade(e0,e1,e2,e3,x,T1,T2)
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - \frac{\left(L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2}\right) \cos{\left(\alpha \right)}}{\sin{\left(\alpha \right)}} - \frac{\left(L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2} + g m\right) \cos{\left(\alpha \right)}}{\sin{\left(\alpha \right)}}$
# $\displaystyle e2 =2 L k \left(1 - \sin{\left(\alpha \right)}\right) + 2 L k \sin{\left(\alpha \right)} - 2 L k$
# $\displaystyle e3 =- 2 L \left(1 - \sin{\left(\alpha \right)}\right) - 2 L \sin{\left(\alpha \right)} + 2 L$
# $\displaystyle x =2 L \left(1 - \sin{\left(\alpha \right)}\right)$
# $\displaystyle T1 =\frac{L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2} + g m}{\sin{\left(\alpha \right)}}$
# $\displaystyle T2 =\frac{L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2}}{\sin{\left(\alpha \right)}}$

# %%
e0.reduFac()
# Out:
# $\displaystyle e0 =- 2 L k \sin{\left(\alpha \right)} + 2 L k + L m w^{2} \sin{\left(\alpha \right)} - M g - g m$

# %%
alpha=e0.solve(alpha,'alpha')
# Out:
# $\displaystyle alpha1 =\operatorname{asin}{\left(\frac{- 2 L k + M g + g m}{L \left(2 k - m w^{2}\right)} \right)} + \pi$
# $\displaystyle alpha2 =- \operatorname{asin}{\left(\frac{- 2 L k + M g + g m}{L \left(2 k - m w^{2}\right)} \right)}$

# %%
upgrade([e0,e1,e2,e3],[x,T1,T2,sin(alpha)])
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - \frac{\left(L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2}\right) \cos{\left(\alpha \right)}}{\sin{\left(\alpha \right)}} - \frac{\left(L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2} + g m\right) \cos{\left(\alpha \right)}}{\sin{\left(\alpha \right)}}$
# $\displaystyle e1 =0$
# $\displaystyle e2 =2 L k \left(1 - \sin{\left(\alpha \right)}\right) + 2 L k \sin{\left(\alpha \right)} - 2 L k$
# $\displaystyle e3 =- 2 L \left(1 - \sin{\left(\alpha \right)}\right) - 2 L \sin{\left(\alpha \right)} + 2 L$
# $\displaystyle x =2 L \left(1 - \sin{\left(\alpha \right)}\right)$
# $\displaystyle T1 =\frac{L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2} + g m}{\sin{\left(\alpha \right)}}$
# $\displaystyle T2 =\frac{L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2}}{\sin{\left(\alpha \right)}}$

# %%
e0.reduFac()
# Out:
# $\displaystyle e0 =- 2 L k \sin{\left(\alpha \right)} + 2 L k + L m w^{2} \sin{\left(\alpha \right)} - M g - g m$

# %%
e1(T2=0)
# Out:
# T_1*sin(alpha) - T_2*sin(alpha) - g*m

# %%
e1.free()
# Out:
# [alpha, T_1, m, T_2, g]

# %%
T2=e2.solve(T2,'T2',kope='s')
# Out:
# $\displaystyle T2 =\frac{L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2}}{\sin{\left(\alpha \right)}}$

# %%
e2.solve(T2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Error from parse_expr with transformed code: ''
#
# The above exception was the direct cause of the following exception:
#
# SyntaxError                               Traceback (most recent call last)
# d:\python36\lib\site-packages\sympy\core\sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     471         a = a.replace('\n', '')
# --> 472         expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     473     except (TokenError, SyntaxError) as exc:
#
# d:\python36\lib\site-packages\sympy\parsing\sympy_parser.py in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1025             local_dict[i] = None
# -> 1026         raise e from ValueError(f"Error from parse_expr with transformed code: {code!r}")
#    1027
#
# ...

# %%
e0.upgrade(T2)
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - T_{2} \cos{\left(\alpha \right)}$

# %%
e0.upgrade(T2)
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - T_{2} \cos{\left(\alpha \right)}$

# %%
def upgradek(ee,*args,kope='',kshow=True,**kwargs ):
        for i in args:
            kname=i.name
            kprint(kname)
            ee.set(kname,i,kope=kope)
        if len(kwargs)>0:
            ee.set(**kwargs,kshow=False)
        if kshow:    
            ee.s()

# %%
upgradek(e0,T2)
# Out:
# $\displaystyle T2\;$
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - T_{2} \cos{\left(\alpha \right)}$
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - T_{2} \cos{\left(\alpha \right)}$

# %%
e0.set(T2,T2)
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - T_{2} \cos{\left(\alpha \right)}$

# %%
upgrade([e0,e1,e2,e3],[T2])
# Out:
# $\displaystyle e0 =L m w^{2} \cos{\left(\alpha \right)} - T_{1} \cos{\left(\alpha \right)} - T_{2} \cos{\left(\alpha \right)}$
# $\displaystyle e1 =T_{1} \sin{\left(\alpha \right)} - T_{2} \sin{\left(\alpha \right)} - g m$
# $\displaystyle e2 =2 L k \left(1 - \sin{\left(\alpha \right)}\right) - M g + 2 T_{2} \sin{\left(\alpha \right)}$
# $\displaystyle e3 =- 2 L \left(1 - \sin{\left(\alpha \right)}\right) - 2 L \sin{\left(\alpha \right)} + 2 L$
# $\displaystyle T2 =\frac{L k \sin{\left(\alpha \right)} - L k + \frac{M g}{2}}{\sin{\left(\alpha \right)}}$

# %%
A.solvefrom(SIN,3)
# Out:
# $\displaystyle e0 =L m w^{2} - T_{1} - T_{2}$
# $\displaystyle e1 =- 2 L T_{1} + 2 L T_{2} + 2 L g m + T_{1} x - T_{2} x$
# $\displaystyle e2 =- L M g + 2 L T_{2} + L k x - T_{2} x$
# $\displaystyle e3 =- 2 L \sin{\left(a \right)} + 2 L - x$

# %%
A.solvefrom(T2,0)
# Out:
# $\displaystyle e0 =L m w^{2} - T_{1} - T_{2}$
# $\displaystyle e1 =2 L^{2} m w^{2} - 4 L T_{1} + 2 L g m - L m w^{2} x + 2 T_{1} x$
# $\displaystyle e2 =2 L^{2} m w^{2} - L M g - 2 L T_{1} + L k x - L m w^{2} x + T_{1} x$
# $\displaystyle e3 =- 2 L \sin{\left(a \right)} + 2 L - x$

# %%
A.solvefrom(T1,1)
# Out:
# $\displaystyle e0 =- 2 L^{2} k m w^{2} + L M g m w^{2} + 4 L T_{2} k + 2 L g k m - 2 M T_{2} g - 2 T_{2} g m$
# $\displaystyle e1 =- 2 L^{2} k m w^{2} + L M g m w^{2} + 4 L T_{1} k - 2 L g k m + 2 L g m^{2} w^{2} - 2 M T_{1} g - 2 T_{1} g m$
# $\displaystyle e3 =- 2 L k \sin{\left(a \right)} + 2 L k + L m w^{2} \sin{\left(a \right)} - M g - g m$
# $\displaystyle x =\frac{- 2 L m w^{2} + 2 M g + 2 g m}{2 k - m w^{2}}$

# %%
A.solvefrom(SIN,3)
# Out:
# $\displaystyle x =\frac{- 2 L m w^{2} + 2 M g + 2 g m}{2 k - m w^{2}}$
# $\displaystyle sin(a) =\frac{2 L k - M g - g m}{L \left(2 k - m w^{2}\right)}$
# $\displaystyle T_2 =\frac{L m \left(- 2 L k w^{2} + M g w^{2} + 2 g k\right)}{- 4 L k + 2 M g + 2 g m}$
# $\displaystyle T_1 =\frac{L m \left(- 2 L k w^{2} + M g w^{2} - 2 g k + 2 g m w^{2}\right)}{- 4 L k + 2 M g + 2 g m}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)
