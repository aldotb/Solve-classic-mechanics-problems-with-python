# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:fd2771b4-855c-45c5-8ceb-93032a9f71ad.png)

# %%
P=phybody(x1=0,x2=L)
P.add_forza(F,0)

# %%
P.work_x()
# Out:
# F⋅L

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:ffea0470-2c1f-4547-976c-b8ae496961b0.png)

# %%
P=phybody(x1=0,x2=L)
P.add_forza(F,alpha)

# %%
P.work_x()
# Out:
# F⋅L⋅cos(α)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:0f3fdb99-e8fa-4ff7-aa2a-a3421697764a.png)

# %%
P=phybody(x1=0,x2=L)
P.add_forza(F,pi/2)

# %%
P.work_x()
# Out:
# 0

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:c241005a-c3c3-4237-b2bf-d5e113f1a667.png)

# %%
P=phybody(x1=0,x2=L)
P.add_forza(F,pi/2+alpha)

# %%
P.work_x()
# Out:
# -F⋅L⋅sin(α)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:60d9f5e0-54b1-4e7a-b80b-e6c497c55202.png)

# %%
P=phybody(x1=0,x2=L)
P.add_forza(F,pi)

# %%
P.work_x()
# Out:
# -F⋅L

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:6130b6fb-a1d7-4ee6-ac03-ed7974d0e9fd.png)

# %%
m=cfrac(2,10)
g=cfrac(98,10)
P=phybody(x1=0,x2=h/tan(pi/6),y1=0,y2=h,v1=12,v2=0,m=cfrac(2,10),g=cfrac(98,10))

# %%
P.add_forza(m*g,-pi/2)
P.add_forza(fr,pi+pi/6)
P.add_forza(N1,pi/2+pi/6)

# %%
W=P.work('W','simplify','rsimplify')
# Out:
# $\displaystyle W =\frac{h \left(- 50 f_{r} - 49\right)}{25}$

# %%
W.subs(fr,N1*mu)
# Out:
# $\displaystyle W =\frac{h \left(- 50 N_{1} \mu - 49\right)}{25}$

# %%
Fry=P.fyrelative(pi/6,'Fry')
# Out:
# $\displaystyle Fry =N_{1} - \frac{49 \sqrt{3}}{50}$

# %%
N1=Fry.solve('N1')
# Out:
# $\displaystyle N1 =\frac{49 \sqrt{3}}{50}$

# %%
W.set(N1)
# Out:
# $\displaystyle W =\frac{h \left(- 49 \sqrt{3} \mu - 49\right)}{25}$

# %%
P.energia('pk')
# Out:
#   2  98      2
# h⋅──⋅── - 72⋅──
#   10 10      10

# %%
Q1=MQ(W,P.energia('pk'))
# Out:
# $\displaystyle \frac{h \left(- 49 \sqrt{3} \mu - 49\right)}{25} = h \frac{2}{10} \cdot \frac{98}{10} - 72 \cdot \frac{2}{10}$

# %%
Q1.factor()
# Out:
# $\displaystyle - \frac{49 h \left(\sqrt{3} \mu + 1\right)}{25} = \frac{2}{10} \left(h \frac{98}{10} - 72\right)$

# %%
Q1.simplify()
# Out:
# $\displaystyle - \frac{49 \sqrt{3} \mu}{25} - \frac{49}{25} = \frac{49 h - 360}{25 h}$

# %%
Q1.subs(mu,cfrac(16,100))
# Out:
# $\displaystyle - \frac{49}{25} - \frac{49 \sqrt{3} \cdot \frac{16}{100}}{25} = \frac{49 h - 360}{25 h}$

# %%
Q1.simplify()
# Out:
# $\displaystyle - \frac{49}{25} - \frac{196 \sqrt{3}}{625} = \frac{49 h - 360}{25 h}$

# %%
h=Q1.solve('h','float')
# Out:
# $\displaystyle h =\frac{112500}{30037} - \frac{9000 \sqrt{3}}{30037}$

# %%
h.float()
# Out:
# $\displaystyle h =3.22640552424943$

# %%
smartanswer??
# Out:
# Signature: smartanswer(expr, *args, **kwargs)
# Docstring: <no docstring>
# Source:
# def smartanswer(expr, *args,**kwargs):
#     ops = ['simplify', 'factor', 'float', 'expand']
#     kname = ''
#     kops = []
#     kvar = ''
#     expr=real_subs(expr,**kwargs)
#
#     for i in args:
#         if type(i) == str:
#             if i in ops:
#                 kops.append(i)
#             else:
#                 kname = i
#         if type(i) == Symbol:
#             kvar = i
#     if len(kops)>0:
#         if 'expand' in kops:
#             try:
#                 expr = expand(expr)
#             except:
#                 pass
#         if 'simplify' in kops:
#             try:
#                 expr = simplify(expr)
#             except:
#                 pass
#         if 'factor' in kops:
#             try:
#                 expr = factor(expr)
#             except:
#                 pass
#         if 'float' in kops:
#             try:
#                 expr = float(expr)
# ...
