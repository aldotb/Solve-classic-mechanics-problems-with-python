# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %% [markdown]
# ![imagen.png](attachment:4fea295b-d6c9-4bca-b9cc-b83efe297428.png)

# %%
eq1=MyEq(m*g-sin(alpha)*w,'eQ_1')
# Out:
# $\displaystyle eQ_1 =g m - w \sin{\left(\alpha \right)}$

# %%
reset_eq(e1,e2,e3,e4,e5,e6) # initialize e1,e2....to e12 ,never I was use e7
e1(m)
e2(g)
e3(sin(alpha))
e4(w)
# Out:
# $\displaystyle e1 =m$
# $\displaystyle e2 =g$
# $\displaystyle e3 =\sin{\left(\alpha \right)}$
# $\displaystyle e4 =w$

# %%
e5(e1*e2-e3*e4)
# Out:
# $\displaystyle e5 =g m - w \sin{\left(\alpha \right)}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:9afaeecf-e5c2-4f25-bc15-b5918dd574b4.png)

# %%
# defaut independent variable is t
x=MyEq(t*t*t+4*t-6,'x',ktype='F')
# Out:
# $\displaystyle x_{(t)} =t^{3} + 4 t - 6$

# %%
# defaut independent variable is t
y=MyEq(x*x*x+4*x-6,'y',ktype='F')
# Out:
# $\displaystyle y_{(t)} =4 t^{3} + 16 t + \left(t^{3} + 4 t - 6\right)^{3} - 30$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:f629ce70-6cc0-47da-b5a0-a80ad785d147.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
# eq  posicion respect time
x=MyEq(3*t*t+2*t-10,'x')
# Out:
# $\displaystyle x =3 t^{2} + 2 t - 10$

# %%
# or....
x=MyEq(3*t*t+2*t-10,'x',ktype='F')
# Out:
# $\displaystyle x_{(t)} =3 t^{2} + 2 t - 10$

# %%
v=eQdiff(x,'v') # velocity = dx/dt
# Out:
# $\displaystyle \frac{d}{d t} x{\left(t \right)} = 3 t^{2} + 2 t - 10$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:75fb55ba-29d3-45ef-bd8b-67bdad28d361.png)

# %%
v.doit()
# Out:
# $\displaystyle v_{(t)} =6 t + 2$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:4dcd7fc8-8d71-4e48-8541-8095e42d97eb.png)

# %%
x=MyEq(3*t*t+2*t-10,'x',ktype='I') # if not include var2= then t var indp
# Out:
# $\displaystyle x =\int \left(3 t^{2} + 2 t - 10\right)\, dt$

# %%
#with diff use doit() with integrate use...
x.doitI()
# Out:
# $\displaystyle x =t^{3} + t^{2} - 10 t$

# %%
from physic_lib2 import * # definite Integral
x=MyEq(3*t*t+2*t-10,'x',ktype='I',x1=0,x2=10)
# Out:
# $\displaystyle x =\int\limits_{0}^{10} \left(3 t^{2} + 2 t - 10\right)\, dt$

# %%
x.doitI()
# Out:
# $\displaystyle x =1000$

# %%
from physic_lib2 import * # run this to reset all variables

# %%
x=MyEq(3*t*t+2*t-10,'x',ktype='I') # if not include var2= then t var indp
# Out:
# $\displaystyle x =\int \left(3 t^{2} + 2 t - 10\right)\, dt$

# %%
# before x.doitI() set limits
x.doitI(x1=0,x2=10)
# Out:
# $\displaystyle x =t^{3} + t^{2} - 10 t$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:e3309a70-2597-4fb3-b376-13d199835c2c.png)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %% [markdown]
#  ![id_500.png](attachment:6bfb62c1-b300-45df-9f4f-c8c6342fefd7.png)

# %%
F=MyEq(6*x*x-2*x+8,'F',ktype='F',var2=x)
# Out:
# $\displaystyle F_{(x)} =6 x^{2} - 2 x + 8$

# %%
W=MyEq(F,'W',ktype='I',var2=x,x1=0,x2=L)
# Out:
# $\displaystyle W =\int\limits_{0}^{L} \left(6 x^{2} - 2 x + 8\right)\, dx$

# %%
W.doitI()
# Out:
# $\displaystyle W =2 L^{3} - L^{2} + 8 L$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %% [markdown]
#  ![id_200.png](attachment:404245e9-08e7-4744-9ff5-13f798d855a7.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
P=mparticle(v1=0,x1=0,x2=L,y1=0,y2=0)
P.add_forza(m1*g,-pi/2)
P.add_forza(F1,alpha)

# %%
Fx=FxQ(P)
# Out:
# $\displaystyle Fx =F_{1} \cos{\left(\alpha \right)}$

# %%
W=MyEq(Fx,'W',ktype='I',var2=x,x1=0,x2=L)
# Out:
# $\displaystyle W =\int\limits_{0}^{L} F_{1} \cos{\left(\alpha \right)}\, dx$

# %%
W.doitI()
# Out:
# $\displaystyle W =F_{1} L \cos{\left(\alpha \right)}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![id_300.png](attachment:0dc62e34-2fee-416b-852e-abdaca39ab4e.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
# Our P mparticle object
m2=4*m1
P=mparticle(m=m1,g=g,v1=0,x1=0,x2=4*L,y1=0,y2=0) #  set initial data
P.add_forza(m1*g,-pi/2)  #  weight
P.add_forza(m2*g,alpha)  #  T= m2*g..

# %%
Fx=FxQ(P) # X forces in MyEq format
# Out:
# $\displaystyle Fx =4 g m_{1} \cos{\left(\alpha \right)}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
#  ![id_300a.png](attachment:28582b41-c8e3-42f0-85cb-75e384e76e58.png)

# %%
#  some times is very usefull..... up is a general example down is used whit symbols...
T3=MyTriang(cat1=3*L,cat2=4*L-x)

# %%
Fx.set(cos(alpha),T3.cos())
# Out:
# $\displaystyle Fx =\frac{4 g m_{1} \left(4 L - x\right)}{\sqrt{9 L^{2} + \left(4 L - x\right)^{2}}}$

# %%
Fx.set(4*L-x,mu)
# Out:
# $\displaystyle Fx =\frac{4 g m_{1} \mu}{\sqrt{9 L^{2} + \mu^{2}}}$

# %%
du=diff(4*L-x,x);du
# Out:
# -1

# %%
#  Ok  work = Fx*dx....
W=MyEq(Fx*du,'W',ktype='I',var2=mu,x1=4*L,x2=0)
# Out:
# $\displaystyle W =\int\limits_{4 L}^{0} \left(- \frac{4 g m_{1} \mu}{\sqrt{9 L^{2} + \mu^{2}}}\right)\, d\mu$

# %%
W.doitI(kope='r')
# Out:
# $\displaystyle W =8 L g m_{1}$

# %%
e2=e2Q(P.energia()-W)
# Out:
# $\displaystyle e2 =8 L g m_{1} - \frac{m_{1} v_{2}^{2}}{2}$

# %%
e2.reduFac()
# Out:
# $\displaystyle e2 =- 16 L g + v_{2}^{2}$

# %%
v2=e2.solveR(v2,'v2')
# Out:
# $\displaystyle v2 =4 \sqrt{L g}$

# %%
e3=e3Q(P.kine_vf_x()-v2)
# Out:
# $\displaystyle e3 =- 8 L ac + 4 \sqrt{L g}$

# %%
ac=e3.solve(ac,'ac')
# Out:
# $\displaystyle ac =\frac{\sqrt{L g}}{2 L}$

# %%
t=MyEq(P.kine_t(),'t')
# Out:
# $\displaystyle t =\frac{v_{2}}{ac}$

# %%
t.upgrade(v2,ac)
# Out:
# $\displaystyle t =8 L$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %%
from physic_lib2 import * # run this to reset all variables

# %%
# puntual presion
p=pQ(rho*g*h,1)  # densid*grav*profu...
# Out:
# $\displaystyle \rho\;=\;g h \rho\;$

# %% [markdown]
#  ![id_400c.png](attachment:c30a277b-c7af-4137-b185-fad653b05d80.png)

# %%
# presin in area profun h
P=MyEq(p,'P',var2=A,ktype='I',x1=0,x2=L)
# Out:
# $\displaystyle P =\int\limits_{0}^{L} g h \rho\, dA$

# %%
P.changediffI(y,L)
# Out:
# $\displaystyle P =\int\limits_{0}^{L} L g h \rho\, dy$

# %%
h=MyEq(L-y,'h')
# Out:
# $\displaystyle h =L - y$

# %%
P.upgrade(h)
# Out:
# $\displaystyle P =\int\limits_{0}^{L} L g \rho \left(L - y\right)\, dy$

# %%
P.doitI()
# Out:
# $\displaystyle P =\frac{L^{3} g \rho}{2}$
