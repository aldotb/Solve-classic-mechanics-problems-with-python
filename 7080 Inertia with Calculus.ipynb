# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![image.png](attachment:aa48beaf-9efa-4447-9ed0-eb022ef046be.png)

# %%
Ar=MyIntg(dA,'Ar',var=A)
# Out:
# $\displaystyle Ar=\int \, dA$

# %%
Ar.setdiff(x,h*x,x1=0,x2=b)
# Out:
# $\displaystyle Ar=\int\limits_{0}^{b} h\, dx$

# %%
Ar.doit()
# Out:
# b⋅h

# %% [markdown]
# ![image.png](attachment:3047a15c-6679-4b0d-95d7-a594a3a429aa.png)
# ![image.png](attachment:a8b1639b-7c64-4deb-b371-14e2513f8e21.png)

# %%
Ix=My2Intg(y*y,'Ix',x,y,0,h,0,b)
# Out:
# $\displaystyle Ix=\int\limits_{0}^{b}\int\limits_{0}^{h} y^{2}\, dx\, dy$

# %%
Ix.doit()
# Out:
#  3
# b ⋅h
# ────
#  3

# %%
Iy=My2Intg(x*x,'Iy',y,x,0,b,0,b)
# Out:
# $\displaystyle Iy=\int\limits_{- \frac{h}{2}}^{\frac{h}{2}}\int\limits_{- \frac{b}{2}}^{\frac{b}{2}} x^{2}\, dy\, dx$

# %%
Iy.doit()
# Out:
#    3
# b⋅h
# ────
#  12

# %%
Ixy=My2Intg(x*x+y*y,'Ixy',y,x,-b/2,b/2,-h/2,h/2)
# Out:
# $\displaystyle Ixy=\int\limits_{- \frac{h}{2}}^{\frac{h}{2}}\int\limits_{- \frac{b}{2}}^{\frac{b}{2}} \left(x^{2} + y^{2}\right)\, dy\, dx$

# %%
Ixy.doit()
# Out:
# $\displaystyle Ixy=\frac{b^{3} h}{12} + \frac{b h^{3}}{12}$

# %%
Ixy.factor()
# Out:
# $\displaystyle Ixy=\frac{b h \left(b^{2} + h^{2}\right)}{12}$

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![image.png](attachment:e176c4b3-664c-4b78-8366-3cf29ef15cfb.png)

# %%
Ix=My2Intg(r*y*y,'Ix',r,alpha,0,R,0,pi/2)
# Out:
# $\displaystyle Ix=\int\limits_{0}^{\frac{\pi}{2}}\int\limits_{0}^{R} r y^{2}\, dr\, d\alpha$

# %%
Ix.set(y=r*sin(alpha))
# Out:
# $\displaystyle Ix=\int\limits_{0}^{\frac{\pi}{2}}\int\limits_{0}^{R} r^{3} \sin^{2}{\left(\alpha \right)}\, dr\, d\alpha$

# %%
Ix.doit()
# Out:
# $\displaystyle Ix=\frac{\pi R^{4}}{16}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![image.png](attachment:16a9d975-d701-4287-80e8-2795910a3f21.png)

# %%
Io=My2Intg(r*(y*y+x*x),'Io',r,alpha,2.5,3,0,2*pi)
# Out:
# $\displaystyle Io=\int\limits_{0}^{2 \pi}\int\limits_{2.5}^{3} r \left(x^{2} + y^{2}\right)\, dr\, d\alpha$

# %%
Io.set(y=r*sin(alpha),x=r*cos(alpha))
# Out:
# $\displaystyle Io=\int\limits_{0}^{2 \pi}\int\limits_{2.5}^{3} r \left(r^{2} \sin^{2}{\left(\alpha \right)} + r^{2} \cos^{2}{\left(\alpha \right)}\right)\, dr\, d\alpha$

# %%
Io.doit()
# Out:
# $\displaystyle Io=20.96875 \pi$

# %%
Io.float()
# Out:
# $\displaystyle Io=65.875270954961$
