# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:058dc4d9-4772-4f0b-9fb2-60065d38e228.png)

# %%
from lib_Physics import *

# %%
# chage lib_MyImntegral in this problem
from lib_MyIntegral import *

# %%
# I=MyIntg(value,name,variable=x,name,x1=limit ops, x2= limit 2 ops)
e1=MyIntg(t**3-9*t**2+10,'e1',var=t)
# Out:
# $\displaystyle e_{1} = \int \left(t^{3} - 9 t^{2} + 10\right)\, dt$

# %%
# MQ(A,B) or MyEqEq(A,B) : return equation obj  as A = B
Q=MQ(x,e1())
# Out:
# $\displaystyle x = \int \left(t^{3} - 9 t^{2} + 10\right)\, dt$

# %%
Q.doitI()
# Out:
# $\displaystyle x = C + \frac{t^{4}}{4} - 3 t^{3} + 10 t$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from lib_Physics import *Q3.set(Q1)

# %% [markdown]
# ![imagen.png](attachment:e3e1aef2-c8c1-4a7e-98c7-ca23bf5302d9.png)

# %%
# in m
N1=m*g
Q1=MQ(T1,fr)
# Out:
# $\displaystyle T_{1} = f_{r}$

# %%
Q1.set(fr,N1*mu)
# Out:
# $\displaystyle T_{1} = g m \mu$

# %%
# in M
N2=M*g
Q2=MQ(T2,fr2)
# Out:
# $\displaystyle T_{2} = fr_{2}$

# %%
Q2.set(fr2,N2*mu)
# Out:
# $\displaystyle T_{2} = M g \mu$

# %%
# in Man
Q3=MQ(T1+T2,F)
# Out:
# $\displaystyle T_{1} + T_{2} = F$

# %%
Q3.set(Q1)
# Out:
# $\displaystyle T_{2} + g m \mu = F$

# %%
Q3.set(Q2)
# Out:
# $\displaystyle M g \mu + g m \mu = F$

# %%
Q3.alone(mu)
# Out:
# $\displaystyle \mu = \frac{F}{g \left(M + m\right)}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from lib_Physics import *Q3.set(Q1)
