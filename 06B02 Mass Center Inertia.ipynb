# %%
from lib_Physics import *

# %%
# somes easy samples to explain

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:16ef7c83-8292-4752-970b-e65b49f81250.png)

# %%
P=mparticle()

# %%
# P.add_cg( the sub mass ,sub area.. sub...,x center ,y center)
P.add_cg(3*L*L,L/2,3*L/2) # with 1
P.add_cg(3*L*L,5*L/2,3*L/2) # with 2

# %%
 P.cmass()
# Out:
# (3*L/2, 3*L/2)

# %%
P.cmass('x') # get x
# Out:
# 3*L/2

# %%
P.cmass('y') # get y
# Out:
# 3*L/2

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:15eb20c1-1b15-4fb9-8602-24a17767dc5a.png)

# %%
# CG = (CG BiG Circle) - (CG little Circle)
P=mparticle()
P.add_cg(pi*R*R,0,0)
P.add_cg(-pi*R*R/4,-R/2,0)
P.cmass()
# Out:
# (R/6, 0)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:e8cfbf61-cbef-4e71-b21e-5d1fa44647e8.png)

# %% [markdown]
# ![imagen.png](attachment:4a67f888-2a23-4ef8-a712-d630d43a0280.png)

# %%
from lib_MyIntegral import *

# %%
Iz=MyIntg(r*r*dm,'Iz',var=m,x1=0,x2=R)
# Out:
# $\displaystyle Iz = \int\limits_{0}^{R} r^{2}\, dm$

# %%
Iz.changediff(r,rho*L*2*pi*r*dr)
# Out:
# $\displaystyle Iz = \int\limits_{0}^{R} 2 \pi L r^{3} \rho\, dr$

# %%
Iz.doit()
# Out:
# $\displaystyle Iz = \frac{\pi L \rho R^{4}}{2}$

# %%
Iz.set(rho=M/(pi*R*R*L))
# Out:
# $\displaystyle Iz = \frac{M R^{2}}{2}$

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:72570e7f-4b45-4de1-a74f-4a7559f1fe10.png)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %%
# remmeber that... Take Note this is geo_mass3.png   ,also there is 1,2,4

# %% [markdown]
# ![imagen.png](attachment:fedc73cb-267c-4973-bbee-9e98557b6337.png)

# %%
P=mparticle()
P.add_cg(alpha*R*R,2*R*sin(alpha)/3,0)
P.add_cg(alpha*R*R/4,R*sin(alpha)/3,0)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![image.png](attachment:5cbf10a6-77cd-4ea6-8c6b-01ee4d040052.png)

# %%
from lib_Physics import *

# %%
Q1=MQ(3*m*g*sin(alpha)+m*g*sin(pi/3-alpha),2*m*g*cos(alpha-pi/6))
# Out:
# $\displaystyle g m \cos{\left(\alpha + \frac{\pi}{6} \right)} + 3 g m \sin{\left(\alpha \right)} = 2 g m \sin{\left(\alpha + \frac{\pi}{3} \right)}$

# %%
Q1.factor()
# Out:
# $\displaystyle g m \left(3 \sin{\left(\alpha \right)} + \cos{\left(\alpha + \frac{\pi}{6} \right)}\right) = 2 g m \sin{\left(\alpha + \frac{\pi}{3} \right)}$

# %%
Q1.simplify()
# Out:
# $\displaystyle m \left(3 \sin{\left(\alpha \right)} + \cos{\left(\alpha + \frac{\pi}{6} \right)}\right) = 2 m \sin{\left(\alpha + \frac{\pi}{3} \right)}$

# %%
Q1.texpand()
# Out:
# $\displaystyle m \left(\frac{5 \sin{\left(\alpha \right)}}{2} + \frac{\sqrt{3} \cos{\left(\alpha \right)}}{2}\right) = 2 m \left(\frac{\sin{\left(\alpha \right)}}{2} + \frac{\sqrt{3} \cos{\left(\alpha \right)}}{2}\right)$

# %%
Q1.Sub(sin(alpha))
# Out:
# $\displaystyle m \left(\frac{5 \sin{\left(\alpha \right)}}{2} + \frac{\sqrt{3} \cos{\left(\alpha \right)}}{2}\right) - \sin{\left(\alpha \right)} = 2 m \left(\frac{\sin{\left(\alpha \right)}}{2} + \frac{\sqrt{3} \cos{\left(\alpha \right)}}{2}\right) - \sin{\left(\alpha \right)}$

# %%
Q1.Sub(sqrt(3)*cos(alpha)/2)
# Out:
# $\displaystyle m \left(\frac{5 \sin{\left(\alpha \right)}}{2} + \frac{\sqrt{3} \cos{\left(\alpha \right)}}{2}\right) - \sin{\left(\alpha \right)} - \frac{\sqrt{3} \cos{\left(\alpha \right)}}{2} = 2 m \left(\frac{\sin{\left(\alpha \right)}}{2} + \frac{\sqrt{3} \cos{\left(\alpha \right)}}{2}\right) - \sin{\left(\alpha \right)} - \frac{\sqrt{3} \cos{\left(\alpha \right)}}{2}$

# %%
a=Q1.solve('alpha')
# Out:
# $\displaystyle alpha1 = - \frac{5 \pi}{6}$
# $\displaystyle alpha2 = \frac{\pi}{6}$

# %%
P=mparticle()

# %%
alpha=pi/6
P.add_cg(3*m ,-R*sin(alpha),-R*cos(alpha))
P.add_cg(2*m,R*cos(pi/6-alpha),R*sin(pi/6-alpha))
P.add_cg(m,-R*cos(alpha-pi/6),-R*sin(alpha-pi/6))

# %%
P.cmass()
# Out:
# (-R/12, -sqrt(3)*R/4)

# %% [markdown]
# ![line.png](attachment:2d984d64-4ed1-4ebe-be12-a4b1e9039eee.png)

# %% [markdown]
# ![imagen.png](attachment:32ebfd01-63cd-4fe7-af57-6ea92acbf0e1.png)

# %% [markdown]
# ![imagen.png](attachment:a8770859-7f6d-4da6-bfc9-66c5c5ad7bf1.png)

# %% [markdown]
# ![imagen.png](attachment:b7a1eed8-e297-4853-b43a-7733008ce4d1.png)

# %% [markdown]
# ![imagen.png](attachment:485bef65-27a6-48d5-ac6a-d91027192e72.png)
