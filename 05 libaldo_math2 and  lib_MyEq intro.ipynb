# %%
from sympy import symbols
from libaldo_math2 import *
from lib_MyEq import *
from libaldo_show import *
from IPython.display import display, Math
init_printing()

# %% [markdown]
# ![line.png](attachment:line.png)

# %% [markdown]
#  ![sympya.png](attachment:7143d7b2-2ed9-45fe-9edc-17f64890a2e7.png)

# %% [markdown]
# ### Introduccion to libaldo_math2 library

# %% [markdown]
# #### The libaldo_math library includes several functions that will make the handling of equations and their solution easier. Although there are several ways to apply regular functions I have decided to include a short explanation as they make my life easier when solving algebraic problems, it is worth mentioning that all these functions are based on the sympy library which until today I think is the best of it. better but I think or have not yet learned how to handle variables and try to express them without using the Latex language which for me is very complicated, I hope it will be helpful
#
# #### In this part I am going to separate it into 4 subparts and they are:
#       * regulars functions
#       * opemat()  used to simplify
#       * csolve() used to solve equations
#       * fpoly() to get a lot of equations propieties and change
#
# #### Of course i will try to compare whit sympy method..

# %% [markdown]
# ####  Regular functions()

# %% [markdown]
# ![math2.png](attachment:6fffa0c7-7b13-46bf-b239-94961894c510.png)

# %%
# frs():return numeric but symbolyc fraction
# regular form
3/5
# Out:
# 0.6

# %%
frs(3,5) # with libaldo_mat
# Out:
# 3/5

# %%
1+2/3
# Out:
# 1.6666666666666665

# %%
1+frs(2,3)
# Out:
# 5/3

# %%
# pow number
2**(2/7)
# Out:
# 1.2190136542044754

# %%
pow(2,2/7)
# Out:
# 1.2190136542044754

# %%
kpow(2,frs(2,7))# with libaldo_mat
# Out:
#  2/7
# 2

# %%
sqrt(2/32)
# Out:
# 0.250000000000000

# %%
rpow(2,32) # with libaldo_mat
# Out:
# 32___
# ╲╱ 2

# %%
sex2rad(90) # sexagesimal to radians
# Out:
# π
# ─
# 2

# %%
rad2sex(pi/2)
# Out:
# 90.0000000000000

# %% [markdown]
# ### opemat() function is used to simplyfy follo the secuense string...

# %% [markdown]
# ![line.png](attachment:line.png)

# %% [markdown]
# ![opemat2.png](attachment:62f53a7b-09d6-4664-b9ea-4019343d72dc.png)

# %%
x,y,alpha=symbols('x y alpha')

# %%
Eq1= kpow(3*x+y,2)+kpow(-x-2*y,2)
Eq1
# Out:
#           2            2
# (-x - 2⋅y)  + (3⋅x + y)

# %%
opemat(Eq1,'ef') # e=expand f=factor
# Out:
#   ⎛   2            2⎞
# 5⋅⎝2⋅x  + 2⋅x⋅y + y ⎠

# %%
opemat(Eq1,'es') # e=expand s=simplify
# Out:
#     2               2
# 10⋅x  + 10⋅x⋅y + 5⋅y

# %%
Eq2=2*sin(alpha)+3*cos(2*alpha)
Eq2
# Out:
# 2⋅sin(α) + 3⋅cos(2⋅α)

# %%
opemat(Eq2,'xt') # trig expand and simplify trig
# Out:
# 2⋅sin(α) + 3⋅cos(2⋅α)

# %% [markdown]
# ### csolve() is used to solve equations

# %% [markdown]
# ![line.png](attachment:line.png)

# %% [markdown]
# #### csolve() is based in solve and solveset from sympy but whit a little change to get most usefull answer and if you want nice answer.. for exaple

# %%
Eq3= 3*x+15*y-20; Eq3 # we know that in python and sympy single eq if like equal cero
# Out:
# 3⋅x + 15⋅y - 20

# %%
# with sympy the return is a list and maybe not are useful in this moment
solve(Eq3,x)
# Out:
# [20/3 - 5⋅y]

# %%
# with libaldo math
csolve(Eq3,x)
# Out:
# 20/3 - 5⋅y

# %%
# also we can store in new val and retun nice answer like
x=csolve(Eq3,x,'x')
# Out:
# $\displaystyle x =\frac{20}{3} - 5 y$

# %% [markdown]
# ![imagen.png](attachment:06946c2a-6b75-406b-ae29-2e7dc47280c7.png)

# %%
x,y,alpha=symbols('x y alpha')

# %%
Eq2=2*sin(alpha)+3*cos(2*alpha)-5*x
Eq2
# Out:
# -5⋅x + 2⋅sin(α) + 3⋅cos(2⋅α)

# %%
csolve(Eq2,x)
# Out:
# 2⋅sin(α)   3⋅cos(2⋅α)
# ──────── + ──────────
#    5           5

# %%
x=csolve(Eq2,x,'x',kope='x') # solve x ,nice 'x=', simplyfy expand and sim trig
# Out:
# $\displaystyle x =\frac{2 \sin{\left(\alpha \right)}}{5} + \frac{6 \cos^{2}{\left(\alpha \right)}}{5} - \frac{3}{5}$

# %% [markdown]
# ![MyEq_math2.png](attachment:81f43015-fc88-4afe-9174-634d54558d27.png)

# %%
x,y,m,g,alpha=symbols('x y m g alpha')
F=MyEq(kpow(x,3)*m*g*cos(3*alpha)+sin(2*alpha)/y+5*y,'F_x')
# Out:
# $\displaystyle F_x =g m x^{3} \cos{\left(3 \alpha \right)} + 5 y + \frac{\sin{\left(2 \alpha \right)}}{y}$

# %% [markdown]
# ![MyEq_math1.png](attachment:f7a6e03e-e4b5-449e-bd0e-efd8225c0b63.png)

# %%
# to call MyEq use Eq.s()
F
# Out:
# g*m*x**3*cos(3*alpha) + 5*y + sin(2*alpha)/y

# %%
# the proposed of MyEq is that auto update every time you change or call something..
F.texpand() # trigonometric expand or 3*alpha to.. alpha...
# Out:
# $\displaystyle F_x =g m x^{3} \left(4 \cos^{3}{\left(\alpha \right)} - 3 \cos{\left(\alpha \right)}\right) + 5 y + \frac{2 \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}}{y}$

# %%
# F was change due upper operations
F.s()
# Out:
# $\displaystyle F_x =g m x^{3} \left(4 \cos^{3}{\left(\alpha \right)} - 3 \cos{\left(\alpha \right)}\right) + 5 y + \frac{2 \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}}{y}$

# %%
F.expand()
# Out:
# $\displaystyle F_x =4 g m x^{3} \cos^{3}{\left(\alpha \right)} - 3 g m x^{3} \cos{\left(\alpha \right)} + 5 y + \frac{2 \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}}{y}$

# %%
# and the classic.... undo
F.undo()
# Out:
#      3 ⎛     3              ⎞         2⋅sin(α)⋅cos(α)
# g⋅m⋅x ⋅⎝4⋅cos (α) - 3⋅cos(α)⎠ + 5⋅y + ───────────────
#                                              y

# %%
F.expand()
# Out:
# $\displaystyle F_x =4 g m x^{3} \cos^{3}{\left(\alpha \right)} - 3 g m x^{3} \cos{\left(\alpha \right)} + 5 y + \frac{2 \sin{\left(\alpha \right)} \cos{\left(\alpha \right)}}{y}$

# %% [markdown]
# ![MyEqlist.png](attachment:038939c9-e7dd-4af6-8acc-dcc8eaf37682.png)

# %%
F.list()
# Out:
# ⎡     2⋅sin(α)⋅cos(α)          3                3    3   ⎤
# ⎢5⋅y, ───────────────, -3⋅g⋅m⋅x ⋅cos(α), 4⋅g⋅m⋅x ⋅cos (α)⎥
# ⎣            y                                           ⎦

# %%
F.free()
# Out:
# [y, α, g, x, m]

# %%
F.args()
# Out:
# ⎛     2⋅sin(α)⋅cos(α)          3                3    3   ⎞
# ⎜5⋅y, ───────────────, -3⋅g⋅m⋅x ⋅cos(α), 4⋅g⋅m⋅x ⋅cos (α)⎟
# ⎝            y                                           ⎠

# %% [markdown]
# ![set.png](attachment:4a89311b-84c6-4143-a60b-662ebfbf2f43.png)

# %%
theta=symbols('theta')
F.set(alpha,theta)
# Out:
# $\displaystyle F_x =4 g m x^{3} \cos^{3}{\left(\theta \right)} - 3 g m x^{3} \cos{\left(\theta \right)} + 5 y + \frac{2 \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{y}$

# %%
# also...
F.set([theta,y],[alpha/2,2*x+1])
# Out:
# $\displaystyle F_x =4 g m x^{3} \cos^{3}{\left(\frac{\alpha}{2} \right)} - 3 g m x^{3} \cos{\left(\frac{\alpha}{2} \right)} + 10 x + 5 + \frac{2 \sin{\left(\frac{\alpha}{2} \right)} \cos{\left(\frac{\alpha}{2} \right)}}{2 x + 1}$

# %%
F.factor()
# Out:
# $\displaystyle F_x =\frac{8 g m x^{4} \cos^{3}{\left(\frac{\alpha}{2} \right)} - 6 g m x^{4} \cos{\left(\frac{\alpha}{2} \right)} + 4 g m x^{3} \cos^{3}{\left(\frac{\alpha}{2} \right)} - 3 g m x^{3} \cos{\left(\frac{\alpha}{2} \right)} + 20 x^{2} + 20 x + 2 \sin{\left(\frac{\alpha}{2} \right)} \cos{\left(\frac{\alpha}{2} \right)} + 5}{2 x + 1}$

# %% [markdown]
# ![get_deno.png](attachment:ec5030b9-b514-4b12-b35b-79a7faf9f55a.png)

# %%
F.get_nume()
# Out:
#        4    3⎛α⎞          4    ⎛α⎞          3    3⎛α⎞          3    ⎛α⎞
# 8⋅g⋅m⋅x ⋅cos ⎜─⎟ - 6⋅g⋅m⋅x ⋅cos⎜─⎟ + 4⋅g⋅m⋅x ⋅cos ⎜─⎟ - 3⋅g⋅m⋅x ⋅cos⎜─⎟ + 20⋅x
#              ⎝2⎠               ⎝2⎠                ⎝2⎠               ⎝2⎠
#
# 2               ⎛α⎞    ⎛α⎞
#   + 20⋅x + 2⋅sin⎜─⎟⋅cos⎜─⎟ + 5
#                 ⎝2⎠    ⎝2⎠

# %%
F.get_deno()
# Out:
# 2⋅x + 1

# %% [markdown]
# # ..  solve()  ... solveR ... set() ... reduFac()

# %% [markdown]
# ![line.png](attachment:line.png)

# %%
# why have two equations  but before check especial MyEq

# %%
# e0Q(),e1Q()....  e9Q() are speciall MyEq only are defined the nice string name
e1=MyEq(x+y,'e1') # classic normal method
# Out:
# $\displaystyle e1 =x + y$

# %%
# but.. simplify is
e1=e1Q(x+y)  # only fill name 'e1' for you is use e1Q ..
# if use e7Q() tha name will be 'e7' capiche??
# Out:
# $\displaystyle e1 =x + y$

# %%
e1=e1Q(4*x+20*y-1)
e2=e2Q(x-y-4)
# Out:
# $\displaystyle e1 =4 x + 20 y - 1$
# $\displaystyle e2 =x - y - 4$

# %%
# for simple method maybe and I hope you can make this
e1.set(y,e2.solve(y)) # in e1 relace y fro the value finding in the other eq
# Out:
# $\displaystyle e1 =24 x - 81$

# %%
 # if you add a string args in solve return a new MyEq is not only net value
x=e1.solve(x,'x')
# Out:
# $\displaystyle x =\frac{27}{8}$

# %%
e2.upgrade(x)
# Out:
# $\displaystyle e2 =- y - \frac{5}{8}$

# %%
y1=e2.solve(y,'y')
# Out:
# $\displaystyle y =- \frac{5}{8}$

# %% [markdown]
# # ..  reduce  .solve() steps..?? ...

# %% [markdown]
# ![line.png](attachment:line.png)

# %%
e1=e1Q(4*x+20*y-1)
e2=e2Q(x-y-4)
# Out:
# $\displaystyle e1 =20 y + \frac{25}{2}$
# $\displaystyle e2 =- y - \frac{5}{8}$

# %%
# It seems stupid but the ideal is to use it in more complicated equations
x,y,alpha=symbols('x y alpha')
e3=e3Q(sin(alpha)*x+y*sin(alpha)/tan(alpha)-frs(3,4))
e4=e4Q(x-y*cos(alpha))
# Out:
# $\displaystyle e3 =x \sin{\left(\alpha \right)} + \frac{y \sin{\left(\alpha \right)}}{\tan{\left(\alpha \right)}} - \frac{3}{4}$
# $\displaystyle e4 =x - y \cos{\left(\alpha \right)}$

# %%
x=e3.set(y,e4.solve(y),andsolve=[x,'x'])
# Out:
# $\displaystyle x =\frac{3}{4 \sin{\left(\alpha \right)} + 4}$

# %%
e4.upgrade(x)
# Out:
# $\displaystyle e4 =- y \cos{\left(\alpha \right)} + \frac{3}{4 \sin{\left(\alpha \right)} + 4}$

# %%
y=e4.solve(y,'y')
# Out:
# $\displaystyle y =\frac{3}{\left(4 \sin{\left(\alpha \right)} + 4\right) \cos{\left(\alpha \right)}}$

# %% [markdown]
# ![Note2.png](attachment:acaeba84-7560-4d9d-be82-13935de5af8e.png)

# %% [markdown]
# ![line.png](attachment:line.png)

# %%
# more usefull functions
Eq= 3+x
allType(Eq)
# Out:
# $\displaystyle 3 + \frac{3}{4 \sin{\left(\alpha \right)} + 4}\;$
# $\displaystyle Is\;Polynomie\;=\;\text{True}\;$
# $\displaystyle Is\;Symbols=\;\text{False}\;$
# $\displaystyle Is\;Number=\;\text{False}\;$
# $\displaystyle Is\;Real=\;\text{False}\;$
# $\displaystyle Is\;Integer=\;\text{False}\;$
# $\displaystyle Is\;Even=\;\text{False}\;$
# $\displaystyle Is\;Odd=\;\text{False}\;$
# $\displaystyle Is\;Monomie=\;\text{False}\;$
# $\displaystyle Is\;Add=\;\text{True}\;$
# $\displaystyle Is\;Mul=\;\text{False}\;$
# $\displaystyle Is\;Pow=\;\text{False}\;$
# $\displaystyle Is\;Pow2=\;\text{False}\;$
# $\displaystyle Is\;Root=\;\text{False}\;$

# %%
allType(Eq,'resume')
# Out:
# $\displaystyle Is\;Polynomie\;=\;\text{True}\;Is\;Symbols=\;\text{False}\;Is\;Number=\;\text{False}\;$
# $\displaystyle Is\;Real=\;\text{False}\;Is\;Integer=\;\text{False}\;Is\;Even=\;\text{False}\;Is\;Odd=\;\text{False}\;$
# $\displaystyle Is\;Monomie=\;\text{False}\;Is\;Add=\;\text{True}\;Is\;Mul=\;\text{False}\;$
# $\displaystyle Is\;Pow=\;\text{False}\;Is\;Pow2=\;\text{False}\;Is\;Root=\;\text{False}\;$

# %%
allType(sin(alpha)*x+y*sin(alpha)/tan(alpha)-frs(3,4),'r')
# Out:
# $\displaystyle Is\;Polynomie\;=\;\text{True}\;Is\;Symbols=\;\text{False}\;Is\;Number=\;\text{False}\;$
# $\displaystyle Is\;Real=\;\text{False}\;Is\;Integer=\;\text{False}\;Is\;Even=\;\text{False}\;Is\;Odd=\;\text{False}\;$
# $\displaystyle Is\;Monomie=\;\text{False}\;Is\;Add=\;\text{True}\;Is\;Mul=\;\text{False}\;$
# $\displaystyle Is\;Pow=\;\text{False}\;Is\;Pow2=\;\text{False}\;Is\;Root=\;\text{False}\;$

# %%
x=symbols('x')
Is_Pow(kpow(x,4))
# Out:
# True

# %%
Is_Pow(kpow(x,4)+2)
# Out:
# False

# %%
Is_Poly(kpow(x,4)+2)
# Out:
# True

# %%
Is_Mono(kpow(x,4)+2)
# Out:
# False

# %%
Is_Mono(kpow(x,4))
# Out:
# True

# %% [markdown]
# #  ALGEBRA..?????

# %% [markdown]
# ![line.png](attachment:line.png)

# %% [markdown]
# #  see the problem example bellow and first get you pencil in hand and try solve yourself..

# %% [markdown]
# ![A_algebra.png](attachment:575742c2-0c71-4ee2-ac20-5dd537bd5322.png)

# %% [markdown]
# ![line.png](attachment:line.png)

# %% [markdown]
# #  if you find solution in less
#     * 30 minutes you are the one..
#     * 60 minutes ..is right because this problem es una mierda..or hard..
#     * 120 minutes... 1% of matemathic,enginiers.people .etc
#     * maybe one day ... wath ever... time if you solve is real good.

# %% [markdown]
# ![line.png](attachment:line.png)

# %%
# Lets Go...
x,y,z,a,b,c=symbols('x y z a b c')

# %% [markdown]
#  ![abc.png](attachment:c690f56c-4f09-423e-94d3-fb59e63bff37.png)

# %% [markdown]
# ##   MyEq in two forms but the same underwear
#     * MyEq is Eq=0
#     * MyEqEq is Eq1 = Eq2

# %%
e1=e1Q(a*a+b*b+c*c)
e2=e2Q(kpow((a-b),2)+kpow((b-c),2)+kpow((c-a),2))
# Out:
# $\displaystyle e1 =a^{2} + b^{2} + c^{2}$
# $\displaystyle e2 =\left(- a + c\right)^{2} + \left(a - b\right)^{2} + \left(b - c\right)^{2}$

# %%
e3=MyEqEq(e1,e2) #
# Out:
# $\displaystyle a^{2} + b^{2} + c^{2} = \left(- a + c\right)^{2} + \left(a - b\right)^{2} + \left(b - c\right)^{2}$

# %%
e3.expand()
# Out:
# $\displaystyle a^{2} + b^{2} + c^{2} = 2 a^{2} - 2 a b - 2 a c + 2 b^{2} - 2 b c + 2 c^{2}$

# %%
e3.Add(-a*a-b*b-c*c)
# Out:
# $\displaystyle 0 = a^{2} - 2 a b - 2 a c + b^{2} - 2 b c + c^{2}$

# %% [markdown]
# ![abc2.png](attachment:1fe6889f-e3e2-4e07-8f17-388e46bb551c.png)

# %%
e4=e4Q(a+b+c)
# Out:
# $\displaystyle e4 =a + b + c$

# %%
e4.Pow(2,kope='e')
# Out:
# $\displaystyle e4 =a^{2} + 2 a b + 2 a c + b^{2} + 2 b c + c^{2}$

# %%
e3.Add(-1*e4.v,'R')
# Out:
# $\displaystyle 0 = - 4 a b - 4 a c - 4 b c$

# %%
e3.Div(-4)
# Out:
# $\displaystyle 0 = a b + a c + b c$

# %%
e5=e5Q(a*b+a*c+b*c)
# Out:
# $\displaystyle e5 =a b + a c + b c$

# %%
e5.factorSec(b) # sympy can make this???
# Out:
# $\displaystyle e5 =a c + b \left(- y + z\right)$

# %%
e5.set(a+c,z-y)
# Out:
# $\displaystyle e5 =a c + b \left(- y + z\right)$

# %%
e5.set(b,y-z)
# Out:
# $\displaystyle e5 =a c + \left(- y + z\right) \left(y - z\right)$

# %%
e5.set(a*c,(x-y)*(z-x))
# Out:
# $\displaystyle e5 =\left(- x + z\right) \left(x - y\right) + \left(- y + z\right) \left(y - z\right)$

# %%
e5.expand()
# Out:
# $\displaystyle e5 =- x^{2} + x y + x z - y^{2} + y z - z^{2}$

# %%
e6=MyEqEq(e0Q(0,kshow=False),e5)
# Out:
# $\displaystyle 0 = - x^{2} + x y + x z - y^{2} + y z - z^{2}$

# %%
e6.Add(x*x+y*y+z*z)
# Out:
# $\displaystyle x^{2} + y^{2} + z^{2} = x y + x z + y z$

# %% [markdown]
# ![line.png](attachment:line.png)

# %% [markdown]
# ![abc3.png](attachment:ed5c5d15-d1f9-4b08-96a4-54635e5e2a19.png)

# %% [markdown]
# ![line.png](attachment:line.png)

# %% [markdown]
# ![A_algebra.png](attachment:575742c2-0c71-4ee2-ac20-5dd537bd5322.png)

# %% [markdown]
# ![line.png](attachment:line.png)

# %%
p1= (kpow(x,11)+kpow(y,11)+kpow(z,11) )
p2=11*(kpow(x,3)*kpow(y,3)*kpow(z,3)*(x*y+y*z+z*x))
p3=x*y*z*kpow((kpow(x,4)+kpow(y,4)+kpow(z,4)),2)

# %%
Solu=MyEq((p1+p2)/p3,'Solu')
# Out:
# $\displaystyle Solu =\frac{x^{11} + 11 x^{3} y^{3} z^{3} \left(x y + x z + y z\right) + y^{11} + z^{11}}{x y z \left(x^{4} + y^{4} + z^{4}\right)^{2}}$

# %%
Solu.set([y,z],[x,x]) #  VOILAAAAAA....................
# Out:
# $\displaystyle Solu =4$
