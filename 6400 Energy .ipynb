# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![dedic.png](attachment:c9fff4c9-2c42-4f2f-9214-9bfc1d497739.png)

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:04fd104f-9d89-4eda-a63a-0848a15e0111.png)

# %%
P=phybody(x1=sqrt(2*R*h-h*h),x2=R*cos(alpha),y1=R+h,y2=R*sin(alpha),v1=0)

# %%
eE=P.energy('kp','eE')
# Out:
# $\displaystyle eE =R g m \sin{\left(\alpha \right)} - g m \left(R + h\right) + \frac{m v_{2}^{2}}{2}$

# %%
P.add_forza(m*g,-pi/2)
P.add_forza(N1,alpha)

# %%
eQt=P.eQtraslation(alpha)
# Out:
# $\displaystyle - N_{1} + g m \sin{\left(\alpha \right)} = a_{c} m$

# %%
eQt.set(N1=0)
# Out:
# $\displaystyle g m \sin{\left(\alpha \right)} = a_{c} m$

# %%
eQt.set(ac=v2*v2/R)
# Out:
# $\displaystyle g m \sin{\left(\alpha \right)} = \frac{m v_{2}^{2}}{R}$

# %%
eQt.alone(v2*v2)
# Out:
# $\displaystyle v_{2}^{2} = R g \sin{\left(\alpha \right)}$

# %%
eE.subs(eQt.L,eQt.R)
# Out:
# $\displaystyle eE =\frac{3 R g m \sin{\left(\alpha \right)}}{2} - g m \left(R + h\right)$

# %%
eE.reducecero()
# Out:
# $\displaystyle eE =- 3 R \sin{\left(\alpha \right)} + 2 R + 2 h$

# %%
eE.set(h=R/5)
# Out:
# $\displaystyle eE =- 3 R \sin{\left(\alpha \right)} + \frac{12 R}{5}$

# %%
eE.reducecero()
# Out:
# $\displaystyle eE =5 \sin{\left(\alpha \right)} - 4$

# %%
eE.solve(sin(alpha))
# Out:
# 4/5

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %% [markdown]
# ![image.png](attachment:da9e8405-8e68-4248-8915-06709243359c.png)

# %%
P=phybody(y1=L/2,y2=L/4,v1=0)

# %%
E1=P.energy('pk','E1')
# Out:
# $\displaystyle E1 =- \frac{L g m}{4} + \frac{m v_{2}^{2}}{2}$

# %%
v2=E1.solve('v2','1')
# Out:
# $\displaystyle v_2 =\frac{\sqrt{2} \sqrt{L g}}{2}$

# %%
P.add_forza(m*g,-pi/2)
P.add_forza(T,pi/2+pi/3)

# %%
P.fyrelative(pi/3)
# Out:
#     g⋅m
# T - ───
#      2

# %%
Q1=MQ(P.fyrelative(pi/3),m*v2*v2/R)
# Out:
# $\displaystyle T - \frac{g m}{2} = \frac{L g m}{2 R}$

# %%
Q1.set(v2)
# Out:
# $\displaystyle T - \frac{g m}{2} = \frac{L g m}{2 R}$

# %%
Q1.set(R=L/2)
# Out:
# $\displaystyle T - \frac{g m}{2} = g m$

# %%
T=Q1.solve('T')
# Out:
# $\displaystyle T =\frac{3 g m}{2}$

# %% [markdown]
# ![line.png](attachment:baddecb4-e838-40d2-b5f0-cf399d0f02ce.png)

# %% [markdown]
# ![image.png](attachment:c8852d74-8e79-4b6e-b891-fb3cca30604e.png)

# %%
from Libaldomath import *
from lib_Mechanics import *

# %%
P=phybody(y1=1,y2=h,v1=0,g=10,m=4)

# %%
E1=P.energy('pk','E1')
# Out:
# $\displaystyle E1 =40 h + 2 v_{2}^{2} - 40$
